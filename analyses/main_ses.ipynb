# %% [markdown]
# # Compare sessions for same subjects acquired from same field strength
#  - Questions:
#     - How do maps compare between sessions? [help understand differences between 3T and 7T, are they due to raw data? If due to raw data then would expect]
#     - What is the reliability of MR features between sessions? How do field strength differences compare to differences expected by repeated acquisitions?
#     - Is this reliability moderated by sex/gender, time between sessions, patient grouping, MR strength?
#  - Outputs of interest:
#     - Subj by vertex matrix plots with columns being different sessions and rows having matched subject-MR strength combos
#     - Correlation between vertex values between sessions
#
# Steps:
# 0. CSV file with all participants and paths to smoothed data (see main.ipynb)
# 1. Make one df with list of all participant-features available per session number
# 1. Compute statistics on these dfs (cor between rows with the same ID-study)
# 1. Plot matrices

# %%
import os
import sys
import pandas as pd
import numpy as np

import importlib
import datetime
import matplotlib.pyplot as plot
import pickle

sys.path.append(os.getcwd())
#sys.path.append("/Users/danielmendelson/Library/CloudStorage/OneDrive-McGillUniversity/Documents/PhD/Boris/code")
sys.path.append("/host/verges/tank/data/daniel/")

import tTsTGrpUtils as tsutil
importlib.reload(tsutil)

import demo
importlib.reload(demo)

#from genUtils import id, gen, t1
# Out:
# <module 'demo' from '/host/verges/tank/data/daniel/3T7T/z/code/analyses/demo.py'>

# %%
# import csv, created from demographics processing (see main.ipynb)
# run parameters

# details of demographics file
demographics = { # should include UID
    "pth" : "/host/verges/tank/data/daniel/3T7T/z/outputs/03b_demoPths_clean_16Sep2025-104025.csv",
    # column names:
    'nStudies': True, # whether multiple studies are included
    "ID_7T" : "PNI_ID", 
    "ID_3T" : "MICS_ID",
    "SES" : "SES",
    "date": "Date", # scan date
    "age": "age",
    "sex": "sex",
    "grp" : "grp_detailed" # col name for participant grouping variable to use
}

# specify root directories
MICs = {
    "name": "MICs",
    "dir_root": "/data/mica3/BIDS_MICs",
    "dir_raw": "/rawdata",
    "dir_deriv": "/derivatives",
    "dir_mp": "/micapipe_v0.2.0",
    "dir_hu": "/hippunfold_v1.3.0/hippunfold",
    "dir_zb": "/DM_zb_37comp",
    "study": "3T",
    "ID_ctrl" : ["HC"], # patterns for control IDs in demographics file
    "ID_Pt" : ["PX"] # patterns for patient IDs in demographics file
    }

PNI = {
    "name": "PNI",
    "dir_root": "/data/mica3/BIDS_PNI",
    "dir_raw": "/rawdata",
    "dir_deriv": "/derivatives",
    "dir_mp": "/micapipe_v0.2.0",
    "dir_hu": "/hippunfold_v1.3.0/hippunfold",
    "dir_zb": "/DM_zb_37comp",
    "study": "7T",
    "ID_col" : ["PNC", "Pilot"], # column for ID in demographics file
    }

studies = [MICs, PNI]

ctrl_grp = {'ctrl' : ['CTRL']}

px_grps = { # specify patient group labels to compare to controls
    'allPX' : ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R'],
    'TLE' : ['TLE_L', 'TLE_R', 'TLE_U', 'mTLE_R', 'mTLE_L'],
    'TLE_L': ['TLE_L', 'mTLE_L', 'bTLE_L'],
    'TLE_R': ['TLE_R', 'mTLE_R', 'bTLE_R'],
    'FCD' : ['FLE_R', 'FLE_L'],
    'MFCL' : ['MFCL', 'bTLE'],
    'UKN' : ['UKN_L', 'UKN_U']
}

# Make list of dict items for group definitions
groups = [
    {'TLE_L': px_grps['TLE_L']},
    {'TLE_R': px_grps['TLE_R']},
    ctrl_grp
]

ses_specs  = { # session comparions ses_specs. Includes paths, what maps to run, statistics to compute, moderators, etc. NOTE. All moderators listed should be in demographics dictionary
    'prjDir_root' : "/host/verges/tank/data/daniel/3T7T/z", # output directory for smoothed cortical maps
    'prjDir_outs' : "/outputs/btwSES",
    'prjDir_out_figs': "/outputs/btwSES/figures",
    'prjDir_maps' : "/maps",
    
    'ctx': True, # whether to include cortical analyses
    'surf_ctx': ['fsLR-5k'],
    'lbl_ctx': ['midthickness', 'pial', 'white', 'swm1.0mm'], # pial, midthick, white, etc
    'ft_ctx': ['thickness', 'T1map', 'flair', 'ADC', 'FA'], # features: T1map, flair, thickness, FA, ADC
    'smth_ctx': [5, 10], # in mm
    
    'hipp': True, # whether to include hippocampal analyses
    'surf_hipp': ['0p5mm'],
    'lbl_hipp': ['midthickness', "inner", "outer"], # outer, inner, midthickness, etc
    'ft_hipp': ['thickness', 'T1map', 'flair', 'ADC', 'FA'], # features: T1map, flair, thickness, FA, ADC
    'smth_hipp': [2, 5], # in mm
    
    # within study comparisons
    'col_grp': 'grp_detailed',  # column in df_demo with group labels
    'cor': True,
    'moderators': [demographics['age'], demographics['sex'], demographics['date'], demographics['grp'], 'Seizure onset (yr)'],
}

# %%
importlib.reload(demo)
reimport = True
if 'df_demo' not in locals() or df_demo is None or reimport:
    df_demo = pd.read_csv(demographics['pth'])
    print(f"df_demo loaded from {demographics['pth']}")


df_demo[demographics['date']] = pd.to_datetime(df_demo[demographics['date']], errors='coerce', dayfirst=True) # format the date column
df_demo['ID_study'] = df_demo.apply(lambda row: row[demographics['ID_3T']] if row['study'] == '3T' else (row[demographics['ID_7T']] if row['study'] == '7T' else np.nan), axis=1) # create column assigning appropriate study ID for that row
demographics['col_studyID'] = 'ID_study' # add to demographics dict
print(df_demo[['UID','MICS_ID', 'PNI_ID', 'study', 'ID_study', 'SES', 'Date', 'grp_detailed']])
df_demo.columns
# Out:
# df_demo loaded from /host/verges/tank/data/daniel/3T7T/z/outputs/03b_demoPths_clean_16Sep2025-104025.csv
#          UID MICS_ID    PNI_ID study  ID_study SES       Date                                                                             grp_detailed
# 0    UID0001   HC129  Pilot013    7T  Pilot013  05 2024-04-18                                                                                     CTRL
# 1    UID0001   HC129  Pilot013    3T     HC129  01 2024-07-09                                                                                     CTRL
# 2    UID0002   HC082    PNC003    7T    PNC003  01 2022-05-06                                                                                     CTRL
# 3    UID0002   HC082    PNC003    7T    PNC003  03 2023-03-13                                                                                     CTRL
# 4    UID0002   HC082    PNC003    7T    PNC003  02 2022-06-13                                                                                     CTRL
# 5    UID0002   HC082    PNC003    7T    PNC003  04 2023-10-24                                                                                     CTRL
# 6    UID0002   HC082    PNC003    3T     HC082  01 2022-04-26                                                                                     CTRL
# 7    UID0002   HC082    PNC003    3T     HC082  02 2023-05-25                                                                                     CTRL
# 8    UID0003   HC081    PNC006    7T    PNC006  02 2022-11-05                                                                                     CTRL
# 9    UID0003   HC081    PNC006    7T    PNC006  01 2022-05-11                                                                                     CTRL
# 10   UID0003   HC081    PNC006    7T    PNC006  04 2023-10-17                                                                                     CTRL
# 11   UID0003   HC081    PNC006    7T    PNC006  03 2023-03-20                                                                                     CTRL
# 12   UID0003   HC081    PNC006    3T     HC081  01 2022-04-26                                                                                     CTRL
# 13   UID0003   HC081    PNC006    3T     HC081  02 2022-11-22                                                                                     CTRL
# 14   UID0003   HC081    PNC006    3T     HC081  03 2023-10-24                                                                                     CTRL
# 15   UID0004   HC135    PNC009    7T    PNC009  01 2022-06-02                                                                                     CTRL
# 16   UID0004   HC135    PNC009    7T    PNC009  03 2023-04-03                                                                                     CTRL
# 17   UID0004   HC135    PNC009    7T    PNC009  02 2022-06-09                                                                                     CTRL
# 18   UID0004   HC135    PNC009    7T    PNC009  04 2023-08-09                                                                                     CTRL
# 19   UID0004   HC135    PNC009    7T    PNC009  a1 2025-02-10                                                                                     CTRL
# 20   UID0004   HC135    PNC009    3T     HC135  01 2024-08-21                                                                                     CTRL
# 21   UID0004   HC135    PNC009    3T     HC135  02 2025-05-20                                                                                     CTRL
# 22   UID0005   HC083    PNC011    7T    PNC011  03 2023-03-01                                                                                     CTRL
# 23   UID0005   HC083    PNC011    7T    PNC011  04 2023-08-03                                                                                     CTRL
# 24   UID0005   HC083    PNC011    7T    PNC011  01 2022-10-05                                                                                     CTRL
# 25   UID0005   HC083    PNC011    7T    PNC011  02 2022-11-11                                                                                     CTRL
# 26   UID0005   HC083    PNC011    3T     HC083  01 2022-07-12                                                                                     CTRL
# 27   UID0005   HC083    PNC011    3T     HC083  02 2025-01-28                                                                                     CTRL
# 28   UID0006   HC076    PNC018    7T    PNC018  02 2023-05-05                                                                                     CTRL
# 29   UID0006   HC076    PNC018    7T    PNC018  a1 2025-02-10                                                                                     CTRL
# 30   UID0006   HC076    PNC018    7T    PNC018  03 2023-05-12                                                                                     CTRL
# 31   UID0006   HC076    PNC018    7T    PNC018  01 2023-04-19                                                                                     CTRL
# 32   UID0006   HC076    PNC018    7T    PNC018  04 2023-09-28                                                                                     CTRL
# 33   UID0006   HC076    PNC018    3T     HC076  01 2022-02-08                                                                                     CTRL
# 34   UID0006   HC076    PNC018    3T     HC076  02 2022-09-27                                                                                     CTRL
# 35   UID0006   HC076    PNC018    3T     HC076  03 2024-02-06                                                                                     CTRL
# 36   UID0006   HC076    PNC018    3T     HC076  04 2025-04-17                                                                                     CTRL
# 37   UID0007   HC062    PNC019    7T    PNC019  02 2023-05-03                                                                                     CTRL
# 38   UID0007   HC062    PNC019    7T    PNC019  04 2023-11-07                                                                                     CTRL
# 39   UID0007   HC062    PNC019    7T    PNC019  a1 2024-12-11                                                                                     CTRL
# 40   UID0007   HC062    PNC019    7T    PNC019  03 2023-05-17                                                                                     CTRL
# 41   UID0007   HC062    PNC019    7T    PNC019  01 2023-04-20                                                                                     CTRL
# 42   UID0007   HC062    PNC019    3T     HC062  01 2020-08-25                                                                                     CTRL
# 43   UID0007   HC062    PNC019    3T     HC062  02 2020-09-08                                                                                     CTRL
# 44   UID0007   HC062    PNC019    3T     HC062  03 2022-08-16                                                                                     CTRL
# 45   UID0008   HC132    PNC022    7T    PNC022  02 2023-11-02                                                                                     CTRL
# 46   UID0008   HC132    PNC022    7T    PNC022  a1 2025-06-03                                                                                     CTRL
# 47   UID0008   HC132    PNC022    7T    PNC022  05 2024-03-13                                                                                     CTRL
# 48   UID0008   HC132    PNC022    7T    PNC022  03 2023-11-15                                                                                     CTRL
# 49   UID0008   HC132    PNC022    7T    PNC022  04 2024-01-24                                                                                     CTRL
# 50   UID0008   HC132    PNC022    7T    PNC022  01 2023-09-26                                                                                     CTRL
# 51   UID0008   HC132    PNC022    3T     HC132  01 2024-07-30                                                                                     CTRL
# 52   UID0009   HC088    PNC024    7T    PNC024  02 2024-05-07                                                                                     CTRL
# 53   UID0009   HC088    PNC024    7T    PNC024  a1 2024-10-09                                                                                     CTRL
# 54   UID0009   HC088    PNC024    7T    PNC024  a2 2024-10-15                                                                                     CTRL
# 55   UID0009   HC088    PNC024    7T    PNC024  01 2024-04-23                                                                                     CTRL
# 56   UID0009   HC088    PNC024    3T     HC088  01 2022-07-19                                                                                     CTRL
# 57   UID0009   HC088    PNC024    3T     HC088  02 2023-10-31                                                                                     CTRL
# 58   UID0010   HC128    PNC025    7T    PNC025  a1 2024-09-11                                                                                     CTRL
# 59   UID0010   HC128    PNC025    7T    PNC025  a3 2024-09-11                                                                                     CTRL
# 60   UID0010   HC128    PNC025    7T    PNC025  02 2024-05-22                                                                                     CTRL
# 61   UID0010   HC128    PNC025    7T    PNC025  01 2024-04-30                                                                                     CTRL
# 62   UID0010   HC128    PNC025    3T     HC128  01 2024-06-02                                                                                     CTRL
# 63   UID0011   HC130    PNC026    7T    PNC026  01 2024-05-01                                                                                     CTRL
# 64   UID0011   HC130    PNC026    7T    PNC026  02 2024-06-06                                                                                     CTRL
# 65   UID0011   HC130    PNC026    7T    PNC026  a2 2025-05-13                                                                                     CTRL
# 66   UID0011   HC130    PNC026    7T    PNC026  a1 2024-10-16                                                                                     CTRL
# 67   UID0011   HC130    PNC026    7T    PNC026  a3 2025-02-18                                                                                     CTRL
# 68   UID0011   HC130    PNC026    3T     HC130  01 2024-07-09                                                                                     CTRL
# 69   UID0011   HC130    PNC026    3T     HC130  02 2025-01-15                                                                                     CTRL
# 70   UID0012   HC131    PNC029    7T    PNC029  a1 2025-02-11                                                                                     CTRL
# 71   UID0012   HC131    PNC029    3T     HC131  01 2024-07-09                                                                                     CTRL
# 72   UID0012   HC131    PNC029    3T     HC131  02 2025-01-10                                                                                     CTRL
# 73   UID0013   HC013    PNC030    7T    PNC030  a2 2025-03-06                                                                                     CTRL
# 74   UID0013   HC013    PNC030    7T    PNC030  a1 2025-02-12                                                                                     CTRL
# 75   UID0013   HC013    PNC030    3T     HC013  01 2018-07-24                                                                                     CTRL
# 76   UID0015   HC116    PNC037    7T    PNC037  a1 2025-05-15                                                                                     CTRL
# 77   UID0015   HC116    PNC037    3T     HC116  01 2023-07-04                                                                                     CTRL
# 78   UID0015   HC116    PNC037    3T     HC116  02 2025-06-25                                                                                     CTRL
# 79   UID0016   HC140    PNC038    7T    PNC038  a1 2025-05-14                                                                                     CTRL
# 80   UID0016   HC140    PNC038    3T     HC140  01 2024-10-23                                                                                     CTRL
# 81   UID0017   HC152    PNC039    7T    PNC039  a1 2025-05-21                                                                                     CTRL
# 82   UID0017   HC152    PNC039    3T     HC152  01 2025-01-29                                                                                     CTRL
# 83   UID0017   HC152    PNC039    3T     HC152  02 2025-04-08                                                                                     CTRL
# 84   UID0018   HC069    PNC040    7T    PNC040  a1 2025-05-27                                                                                     CTRL
# 85   UID0018   HC069    PNC040    3T     HC069  01 2021-04-20                                                                                     CTRL
# 86   UID0018   HC069    PNC040    3T     HC069  02 2022-06-09                                                                                     CTRL
# 87   UID0018   HC069    PNC040    3T     HC069  03 2023-01-10                                                                                     CTRL
# 88   UID0019   HC052    PNC041    7T    PNC041  a1 2025-06-03                                                                                     CTRL
# 89   UID0019   HC052    PNC041    3T     HC052  01 2019-11-05                                                                                     CTRL
# 90   UID0019   HC052    PNC041    3T     HC052  02 2021-08-03                                                                                     CTRL
# 91   UID0019   HC052    PNC041    3T     HC052  03 2022-05-11                                                                                     CTRL
# 92   UID0020   PX071    PNE001    7T    PNE001  01 2023-01-26                                                                                    TLE_U
# 93   UID0020   PX071    PNE001    3T     PX071  01 2022-06-01                                                                                    TLE_U
# 94   UID0020   PX071    PNE001    3T     PX071  02 2023-01-17                                                                                    TLE_U
# 95   UID0020   PX071    PNE001    3T     PX071  03 2023-04-11                                                                                    TLE_U
# 96   UID0020   PX071    PNE001    3T     PX071  04 2023-09-26                                                                                    TLE_U
# 97   UID0021   PX183    PNE002    7T    PNE002  a1 2024-11-14                                                                                     MFCL
# 98   UID0021   PX183    PNE002    3T     PX183  01 2024-10-16                                                                                     MFCL
# 99   UID0022   PX137    PNE003    7T    PNE003  a1 2024-11-14                                                                                    FLE_R
# 100  UID0022   PX137    PNE003    3T     PX137  01 2024-03-06                                                                                    FLE_R
# 101  UID0023   PX176    PNE004    7T    PNE004  a1 2024-11-20                                                                                   TLE_BL
# 102  UID0023   PX176    PNE004    3T     PX176  01 2024-09-05                                                                                   TLE_BL
# 103  UID0024   PX194    PNE005    7T    PNE005  a1 2024-11-29                                                                                    UKN_L
# 104  UID0024   PX194    PNE005    3T     PX194  01 2024-11-26                                                                                    UKN_L
# 105  UID0025   PX173    PNE006    7T    PNE006  a1 2024-12-04                                                                                    TLE_R
# 106  UID0025   PX173    PNE006    3T     PX173  01 2024-08-28                                                                                    TLE_R
# 107  UID0026   PX158    PNE007    7T    PNE007  a1 2024-12-11                                                                                    FLE_L
# 108  UID0026   PX158    PNE007    7T    PNE007  a2 2025-03-25                                                                                    FLE_L
# 109  UID0026   PX158    PNE007    3T     PX158  01 2024-06-11                                                                                    FLE_L
# 110  UID0027   PX199    PNE008    7T    PNE008  a1 2024-12-18                                                                                    UKN_U
# 111  UID0027   PX199    PNE008    3T     PX199  01 2024-12-03                                                                                    UKN_U
# 112  UID0028   PX153    PNE009    7T    PNE009  a1 2025-01-08                                                                                   TLE_BL
# 113  UID0028   PX153    PNE009    7T    PNE009  a2 2025-03-20                                                                                   TLE_BL
# 114  UID0028   PX153    PNE009    3T     PX153  01 2024-05-28                                                                                   TLE_BL
# 115  UID0029   PX168    PNE010    7T    PNE010  a1 2025-01-09                                                                                    TLE_L
# 116  UID0029   PX168    PNE010    3T     PX168  01 2024-08-20                                                                                    TLE_L
# 117  UID0030   PX190    PNE011    7T    PNE011  a1 2025-01-10                                                                                    TLE_U
# 118  UID0030   PX190    PNE011    3T     PX190  01 2024-11-12                                                                                    TLE_U
# 119  UID0031   PX189    PNE012    7T    PNE012  a2 2025-06-05                                                                                    TLE_L
# 120  UID0031   PX189    PNE012    7T    PNE012  a1 2025-01-10                                                                                    TLE_L
# 121  UID0031   PX189    PNE012    3T     PX189  01 2024-11-12                                                                                    TLE_L
# 122  UID0032   PX148    PNE013    7T    PNE013  a1 2025-01-13                                                                                    TLE_R
# 123  UID0032   PX148    PNE013    3T     PX148  01 2024-05-06                                                                                    TLE_R
# 124  UID0033   PX152    PNE014    7T    PNE014  a1 2025-01-13                                                                                    UKN_R
# 125  UID0033   PX152    PNE014    7T    PNE014  a2 2025-05-22                                                                                    UKN_R
# 126  UID0033   PX152    PNE014    3T     PX152  01 2024-05-23                                                                                    UKN_R
# 127  UID0033   PX152    PNE014    3T     PX152  02 2025-06-17                                                                                    UKN_R
# 128  UID0034   PX200    PNE015    7T    PNE015  a1 2025-01-15                                                                                   TLE_BL
# 129  UID0034   PX200    PNE015    7T    PNE015  a2 2025-08-12                                                                                   TLE_BL
# 130  UID0034   PX200    PNE015    3T     PX200  01 2024-12-03                                                                                   TLE_BL
# 131  UID0035   PX119    PNE016    7T    PNE016  a1 2025-01-16                                                                                    FLE_L
# 132  UID0035   PX119    PNE016    3T     PX119  01 2023-08-30                                                                                    FLE_L
# 133  UID0036   PX174    PNE017    7T    PNE017  a1 2025-02-20                                                                                    TLE_L
# 134  UID0036   PX174    PNE017    3T     PX174  01 2024-09-04                                                                                    TLE_L
# 135  UID0037   PX198    PNE018    7T    PNE018  a1 2025-03-12                                                                                    TLE_L
# 136  UID0037   PX198    PNE018    3T     PX198  01 2024-12-03                                                                                    TLE_L
# 137  UID0038   PX204    PNE019    7T    PNE019  a1 2025-03-18                                                                                    TLE_L
# 138  UID0038   PX204    PNE019    3T     PX204  01 2025-01-09                                                                                    TLE_L
# 139  UID0039   PX215    PNE020    7T    PNE020  a1 2025-03-27                                                                                    UKN_U
# 140  UID0039   PX215    PNE020    3T     PX215  01 2025-03-20                                                                                    UKN_U
# 141  UID0040   PX216    PNE021    7T    PNE021  a1 2025-04-02                                                                                    TLE_R
# 142  UID0040   PX216    PNE021    3T     PX216  01 2025-03-26                                                                                    TLE_R
# 143  UID0041   PX100    PNE022    7T    PNE022  a1 2025-04-30                                                                                    FLE_L
# 144  UID0041   PX100    PNE022    3T     PX100  01 2023-05-30                                                                                    FLE_L
# 145  UID0041   PX100    PNE022    3T     PX100  02 2024-10-29                                                                                    FLE_L
# 146  UID0042   PX038    PNE023    7T    PNE023  a1 2025-05-28                                     PATTERN NOT RECOGNIZED: lobe=PQLE, lat=R, MFCL=Focal
# 147  UID0042   PX038    PNE023    3T     PX038  01 2020-02-11                                     PATTERN NOT RECOGNIZED: lobe=PQLE, lat=R, MFCL=Focal
# 148  UID0043   PX224    PNE024    7T    PNE024  a1 2025-06-11                                                                                    TLE_R
# 149  UID0043   PX224    PNE024    3T     PX224  01 2025-06-13                                                                                    TLE_R
# 150  UID0044   PX223    PNE025    7T    PNE025  a1 2025-06-11  PATTERN NOT RECOGNIZED: lobe=PLE, lat=Lateralization of epileptogenic focus, MFCL=Focal
# 151  UID0044   PX223    PNE025    3T     PX223  01 2025-06-13  PATTERN NOT RECOGNIZED: lobe=PLE, lat=Lateralization of epileptogenic focus, MFCL=Focal
# 152  UID0045   PX175    PNE026    7T    PNE026  a1 2025-06-17                                                                                    FLE_R
# 153  UID0045   PX175    PNE026    3T     PX175  01 2024-09-04                                                                                    FLE_R
# 154  UID0046   PX222    PNE027    7T    PNE027  a1 2025-06-17                                                                                    UKN_L
# 155  UID0046   PX222    PNE027    3T     PX222  01 2025-06-12                                                                                    UKN_L
# 156  UID0047   PX225    PNE028    7T    PNE028  a1 2025-07-02                                                                                    TLE_R
# 157  UID0047   PX225    PNE028    3T     PX225  01 2025-06-16                                                                                    TLE_R
# 158  UID0048   PX050    PNE029    7T    PNE029  a1 2025-07-02                                                                                    TLE_R
# 159  UID0048   PX050    PNE029    3T     PX050  01 2021-03-02                                                                                    TLE_R
# 160  UID0048   PX050    PNE029    3T     PX050  02 2021-12-20                                                                                    TLE_R
# 161  UID0048   PX050    PNE029    3T     PX050  03 2022-12-13                                                                                    TLE_R
# 162  UID0048   PX050    PNE029    3T     PX050  04 2024-01-25                                                                                    TLE_R
# 163  UID0049   HC164    PNC043    7T    PNC043  a1 2025-07-16                                                                                     CTRL
# 164  UID0049   HC164    PNC043    3T     HC164  01 2025-04-24                                                                                     CTRL
# 165  UID0050   PX229    PNE030    7T    PNE030  a1 2025-07-22                                                                                    TLE_L
# 166  UID0050   PX229    PNE030    3T     PX229  01 2025-07-15                                                                                    TLE_L
# 167  UID0051   PX043    PNE031    7T    PNE031  a1 2025-07-25                                                                                    TLE_R
# 168  UID0051   PX043    PNE031    3T     PX043  01 2020-10-13                                                                                    TLE_R
# 169  UID0051   PX043    PNE031    3T     PX043  02 2023-06-06                                                                                    TLE_R
# 170  UID0053   PX235    PNE033    7T    PNE033  a1 2025-07-29                                                                                    FLE_R
# 171  UID0053   PX235    PNE033    3T     PX235  01 2025-07-29                                                                                    FLE_R
# 172  UID0054   PX236    PNE034    7T    PNE034  a1 2025-07-31                                    PATTERN NOT RECOGNIZED: lobe=nan, lat=nan, MFCL=Focal
# 173  UID0054   PX236    PNE034    3T     PX236  01 2025-07-31                                    PATTERN NOT RECOGNIZED: lobe=nan, lat=nan, MFCL=Focal
# 174  UID0055   PX228    PNE035    7T    PNE035  a1 2025-07-31                                    PATTERN NOT RECOGNIZED: lobe=nan, lat=nan, MFCL=Focal
# 175  UID0055   PX228    PNE035    3T     PX228  01 2025-07-04                                    PATTERN NOT RECOGNIZED: lobe=nan, lat=nan, MFCL=Focal
# 176  UID0056   PX233    PNE036    7T    PNE036  a1 2025-08-07                                    PATTERN NOT RECOGNIZED: lobe=nan, lat=nan, MFCL=Focal
# 177  UID0056   PX233    PNE036    3T     PX233  01 2025-07-28                                    PATTERN NOT RECOGNIZED: lobe=nan, lat=nan, MFCL=Focal
# 178  UID0057   PX240    PNE037    7T    PNE037  a1 2025-08-08                                                                                    UKN_U
# 179  UID0057   PX240    PNE037    3T     PX240  01 2025-08-12                                                                                    UKN_U
# 180  UID0058   PX144    PNE038    7T    PNE038  a1 2025-08-13                                                                                    TLE_R
# 181  UID0058   PX144    PNE038    3T     PX144  01 2024-04-09                                                                                    TLE_R
# 182  UID0058   PX144    PNE038    3T     PX144  02 2025-04-02                                                                                    TLE_R
# 183  UID0060   PX131    PNE040    7T    PNE040  a1 2025-08-20                                                                                    FLE_L
# 184  UID0060   PX131    PNE040    3T     PX131  01 2023-12-13                                                                                    FLE_L
# 185  UID0061   PX064    PNE041    7T    PNE041  a1 2025-08-26                              PATTERN NOT RECOGNIZED: lobe=IGE, lat=IGE, MFCL=Generalized
# 186  UID0061   PX064    PNE041    3T     PX064  01 2021-12-14                              PATTERN NOT RECOGNIZED: lobe=IGE, lat=IGE, MFCL=Generalized
# 187  UID0061   PX064    PNE041    3T     PX064  02 2024-08-28                              PATTERN NOT RECOGNIZED: lobe=IGE, lat=IGE, MFCL=Generalized
# 188  UID0061   PX064    PNE041    3T     PX064  03 2025-01-21                              PATTERN NOT RECOGNIZED: lobe=IGE, lat=IGE, MFCL=Generalized
# 189  UID0062   PX192    PNE042    7T    PNE042  a1 2025-08-26                                                                                    TLE_L
# 190  UID0062   PX192    PNE042    3T     PX192  01 2024-11-20                                                                                    TLE_L
# 191  UID0063   PX231    PNE043    7T    PNE043  a1 2025-08-27                                                                                    TLE_R
# 192  UID0063   PX231    PNE043    3T     PX231  01 2025-07-24                                                                                    TLE_R
# Index(['UID', 'MICS_ID', 'PNI_ID', 'study', 'SES', 'Date', 'lastSeizure',
#        'handedness', 'education', 'sex', 'gender', 'ethnicity', 'employment',
#        'dob', 'language', 'Histopatholgy',
#        'Engel classification (seizure outcomes at the 6 month )',
#        '# of ASMs prior current EMU admission',
#        'Epilepsy classification:Focal,Generalized',
#        'Genetic test (year,results)', 'Duration of admission',
#        'Epilepsy diagnosis based on ILAE', '# of ASM on admission',
#        'ILAE outcome after surgical resection by 1 yr',
#        'Risk factors for epilepsy',
#        'Epileptogenic focus confirmed by the information of (sEEG/ site of surgical resection/ Ictal EEG abnormalities +/. MRI findings): FLE=forntal lobe epilepsy and cingulate epilepsy, CLE:central/midline epilepsy,ILE: insular epilepsy, mTLE=mesio.temporal lobe epilepsy, nTLE=neocortical lobe epilepsy, PQLE=posterior quadrant lobe epilepsy , multifocal epilepsy,IGE=ideopathic lobe epilepsy,unclear)',
#        'FDG.PET', 'Surgical resection date and site',
#        'Lateralization of epileptogenic focus', 'EMU admission date(dd-mm-yy)',
#        'Dx at EMU discharge ', 'Baseline MRI (year,results)',
#        'ASMs  on admission (name, doses (mg per day)',
#        'Engel classification (seizure outcomes after 1 year from surgical resection)',
#        'Drug resistant epilepsy at time of EMU admission',
#        'Previous ASMs (name and doses (mg/d)) if applicable prior the current EMU admission',
#        'Neuromodulation devices', 'Invasive explorations (Y/N)',
#        'Seizure onset (yr)', 'age', 'grp', 'grp_detailed',
#        'ctx_hemi-L_surf-fsLR-5k_label-thickness_unsmth',
#        'ctx_hemi-R_surf-fsLR-5k_label-thickness_unsmth',
#        'ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-5mm',
#        'ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-5mm',
#        'ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-10mm',
#        'ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-10mm',
#        'ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_unsmth',
#        'ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_unsmth',
#        'ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-5mm',
#        'ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-5mm',
#        'ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-10mm',
#        'ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-10mm',
#        'ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-5mm',
#        'ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-5mm',
#        'ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-10mm',
#        'ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-10mm',
#        'hipp_hemi-L_surf-0p5mm_label-thickness_unsmth',
#        'hipp_hemi-R_surf-0p5mm_label-thickness_unsmth',
#        'hipp_hemi-L_surf-0p5mm_label-thickness_smth-2mm',
#        'hipp_hemi-R_surf-0p5mm_label-thickness_smth-2mm',
#        'hipp_hemi-L_surf-0p5mm_label-thickness_smth-5mm',
#        'hipp_hemi-R_surf-0p5mm_label-thickness_smth-5mm',
#        'hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_unsmth',
#        'hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_unsmth',
#        'hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-2mm',
#        'hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-2mm',
#        'hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-5mm',
#        'hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-5mm',
#        'hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-2mm',
#        'hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-2mm',
#        'hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-5mm',
#        'hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-5mm',
#        'ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_unsmth',
#        'ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_unsmth',
#        'hipp_hemi-L_surf-0p5mm_label-midthickness_flair_unsmth',
#        'hipp_hemi-R_surf-0p5mm_label-midthickness_flair_unsmth',
#        'NA: NO RAWDATA', 'NA: MISSING MP PROCESSING (unsmoothed map)',
#        'NA: MISSING MP PROCESSING (volume ft map)',
#        'NA: MISSING HU PROCESSING (surf)', 'NA: MISSING MP PROCESSING (surf)',
#        'NAs', 'ID_study'],
#       dtype='object')

# %%
# SUMMARY OF PARTICIPANTS/<TABLE 1>
demo.grp_summary(df_demo, col_grp='grp_detailed', save_pth=None)
print("-"*100)
print("MEDIAN AGE by group")
df_demo.groupby(['grp_detailed', 'study'])['age'].median().sort_index(level='grp_detailed')
# Out:
# ----------------------------------------
#                                                                                          num_px  num_ses_3T  num_ses_7T max_ses_3T max_ses_7T median_ses_3T median_ses_7T
# TOTAL                                                                                        60          91         102
# CTRL                                                                                         19          38          56          4          6           2.0           4.0
# TLE_R                                                                                         9          14           9          4          1           1.0           1.0
# TLE_L                                                                                         7           7           8          1          2           1.0           1.0
# FLE_L                                                                                         4           5           5          2          2           1.0           1.0
# FLE_R                                                                                         3           3           3          1          1           1.0           1.0
# PATTERN NOT RECOGNIZED: lobe=nan, lat=nan, MFCL=Focal                                         3           3           3          1          1           1.0           1.0
# TLE_BL                                                                                        3           3           5          1          2           1.0           2.0
# UKN_U                                                                                         3           3           3          1          1           1.0           1.0
# TLE_U                                                                                         2           5           2          4          1           2.5           1.0
# UKN_L                                                                                         2           2           2          1          1           1.0           1.0
# MFCL                                                                                          1           1           1          1          1           1.0           1.0
# PATTERN NOT RECOGNIZED: lobe=IGE, lat=IGE, MFCL=Generalized                                   1           3           1          3          1           3.0           1.0
# PATTERN NOT RECOGNIZED: lobe=PLE, lat=Lateralization of epileptogenic focus, MFCL=Focal       1           1           1          1          1           1.0           1.0
# PATTERN NOT RECOGNIZED: lobe=PQLE, lat=R, MFCL=Focal                                          1           1           1          1          1           1.0           1.0
# UKN_R                                                                                         1           2           2          2          2           2.0           2.0
# ----------------------------------------------------------------------------------------------------
# MEDIAN AGE by group
# grp_detailed                                                                             study
# CTRL                                                                                     3T       28.544832
#                                                                                          7T       27.274470
# FLE_L                                                                                    3T       24.906229
#                                                                                          7T       25.407255
# FLE_R                                                                                    3T       33.519507
#                                                                                          7T       34.212183
# MFCL                                                                                     3T       34.135524
#                                                                                          7T       34.214921
# PATTERN NOT RECOGNIZED: lobe=IGE, lat=IGE, MFCL=Generalized                              3T       26.907598
#                                                                                          7T       27.901437
# PATTERN NOT RECOGNIZED: lobe=PLE, lat=Lateralization of epileptogenic focus, MFCL=Focal  3T       22.902122
#                                                                                          7T       22.896646
# PATTERN NOT RECOGNIZED: lobe=PQLE, lat=R, MFCL=Focal                                     3T       23.408624
#                                                                                          7T       28.700890
# PATTERN NOT RECOGNIZED: lobe=nan, lat=nan, MFCL=Focal                                    3T       22.250513
#                                                                                          7T       22.324435
# TLE_BL                                                                                   3T       35.945243
#                                                                                          7T       36.153320
# TLE_L                                                                                    3T       31.616701
#                                                                                          7T       31.978097
# TLE_R                                                                                    3T       32.806297
#                                                                                          7T       28.626968
# TLE_U                                                                                    3T       30.888433
#                                                                                          7T       31.114305
# UKN_L                                                                                    3T       38.750171
#                                                                                          7T       38.761123
# UKN_R                                                                                    3T       29.073238
#                                                                                          7T       29.359343
# UKN_U                                                                                    3T       29.333333
#                                                                                          7T       29.374401
# Name: age, dtype: float64

# %% [markdown]
# # ANALYSIS ses_specs

# %% [markdown]
# # 4. Analysis

# %%
# create a column in df_demo that provides a session number per participant. Should order by scan date
# each UID-study combination should have a session number starting at 1 and increasing by 1 for each additional session, ordered by date
df_demo = df_demo.sort_values(by=['UID', 'study', 'Date'])
df_demo['ses_number'] = df_demo.groupby(['UID', 'study']).cumcount() + 1
demographics['col_sesNum'] = 'ses_number' # add to demographics dict for later use
#pd.set_option('display.max_rows', None)
df_demo[['UID', 'study', 'Date', 'ses_number']].loc[0:25,:]

# create a table counting  the number of sessions per study. this should return a n_unique_studies by n_unique_sessions table
df_demo_sessions = df_demo.groupby(['study', 'ses_number']).size().unstack(fill_value=0)
df_demo_sessions
# Out:
# ses_number   1   2   3   4  5  6
# study
# 3T          60  20   8   3  0  0
# 7T          60  16  10  10  5  1

# %%
# Iterate through specifications and session number, read in maps and keep df_demo with rows only from the session. The index of the df_maps should be 'UID'_'STUDY'_'STUDYID'_'SES'ArithmeticError
importlib.reload(tsutil)

save = True
save_pth = f"{['prjDir_root']}{ses_specs['prjDir_outs']}"
save_name = "01a_maps"
test = False
verbose = True

print(f"Creating a dictionary items with session number as an iterated item rather than study (each combo of: ses_number-feature-label-surface-smoothing).\n\tNote. Not seperating participant groups yet.")

dl = tsutil.extractMap_SES(df_mapPaths = df_demo, col_sesNum = demographics['col_sesNum'], col_studyID = demographics['col_studyID'],
                            coi = ses_specs['moderators'], save_pth = f"{ses_specs['prjDir_root']}{ses_specs['prjDir_outs']}", 
                            save_name = save_name, verbose = verbose, test=test)
# Out:
# Creating a dictionary items with session number as an iterated item rather than study (each combo of: ses_number-feature-label-surface-smoothing).
# 	Note. Not seperating participant groups yet.
# 36 map columns found: 18 L | 18 R.
#
# 36 map columns found.
#
# 	Processing surf-fsLR-5k_label-thickness_unsmth... (cols: ctx_hemi-L_surf-fsLR-5k_label-thickness_unsmth ctx_hemi-R_surf-fsLR-5k_label-thickness_unsmth) | region: cortex
#
# 	Processing surf-fsLR-5k_label-thickness_unsmth... (cols: ctx_hemi-L_surf-fsLR-5k_label-thickness_unsmth ctx_hemi-R_surf-fsLR-5k_label-thickness_unsmth)
# 		6 rows removed due to missing values for these maps. [193 rows before, 187 rows remain]
# 		82 unique study-IDs removed given data for 0 or 1 sessions. [187 rows before, 105 rows remain]
# 		34 unique study-ID pairs remain after removing 86 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PNE042', 'PNE043', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX233', 'PX235', 'PX236', 'Pilot013']
# 			[Session: 1] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 2] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 3] 18 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (18, 9684)
# 			[Session: 4] 13 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (13, 9684)
# 			[Session: 5] 5 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (5, 9684)
# 			[Session: 6] 1 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (1, 9684)
#
# 	Processing surf-fsLR-5k_label-thickness_smth-5mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-5mm ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-5mm) | region: cortex
#
# 	Processing surf-fsLR-5k_label-thickness_smth-5mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-5mm ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-5mm)
# 		6 rows removed due to missing values for these maps. [193 rows before, 187 rows remain]
# 		82 unique study-IDs removed given data for 0 or 1 sessions. [187 rows before, 105 rows remain]
# 		34 unique study-ID pairs remain after removing 86 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PNE042', 'PNE043', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX233', 'PX235', 'PX236', 'Pilot013']
# 			[Session: 1] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 2] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 3] 18 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (18, 9684)
# 			[Session: 4] 13 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (13, 9684)
# 			[Session: 5] 5 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (5, 9684)
# 			[Session: 6] 1 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (1, 9684)
#
# 	Processing surf-fsLR-5k_label-thickness_smth-10mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-10mm ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-10mm) | region: cortex
#
# 	Processing surf-fsLR-5k_label-thickness_smth-10mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-10mm ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-10mm)
# 		6 rows removed due to missing values for these maps. [193 rows before, 187 rows remain]
# 		82 unique study-IDs removed given data for 0 or 1 sessions. [187 rows before, 105 rows remain]
# 		34 unique study-ID pairs remain after removing 86 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PNE042', 'PNE043', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX233', 'PX235', 'PX236', 'Pilot013']
# 			[Session: 1] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 2] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 3] 18 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (18, 9684)
# 			[Session: 4] 13 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (13, 9684)
# 			[Session: 5] 5 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (5, 9684)
# 			[Session: 6] 1 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-thickness_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-thickness_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (1, 9684)
#
# 	Processing surf-fsLR-5k_label-midthickness_T1map_unsmth... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_unsmth ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_unsmth) | region: cortex
#
# 	Processing surf-fsLR-5k_label-midthickness_T1map_unsmth... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_unsmth ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_unsmth)
# 		13 rows removed due to missing values for these maps. [193 rows before, 180 rows remain]
# 		79 unique study-IDs removed given data for 0 or 1 sessions. [180 rows before, 101 rows remain]
# 		34 unique study-ID pairs remain after removing 86 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PNE042', 'PNE043', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX233', 'PX236', 'Pilot013']
# 			[Session: 1] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 2] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 3] 16 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (16, 9684)
# 			[Session: 4] 11 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (11, 9684)
# 			[Session: 5] 5 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (5, 9684)
# 			[Session: 6] 1 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (1, 9684)
#
# 	Processing surf-fsLR-5k_label-midthickness_T1map_smth-5mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-5mm ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-5mm) | region: cortex
#
# 	Processing surf-fsLR-5k_label-midthickness_T1map_smth-5mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-5mm ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-5mm)
# 		13 rows removed due to missing values for these maps. [193 rows before, 180 rows remain]
# 		79 unique study-IDs removed given data for 0 or 1 sessions. [180 rows before, 101 rows remain]
# 		34 unique study-ID pairs remain after removing 86 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PNE042', 'PNE043', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX233', 'PX236', 'Pilot013']
# 			[Session: 1] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 2] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 3] 16 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (16, 9684)
# 			[Session: 4] 11 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (11, 9684)
# 			[Session: 5] 5 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (5, 9684)
# 			[Session: 6] 1 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (1, 9684)
#
# 	Processing surf-fsLR-5k_label-midthickness_T1map_smth-10mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-10mm ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-10mm) | region: cortex
#
# 	Processing surf-fsLR-5k_label-midthickness_T1map_smth-10mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-10mm ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-10mm)
# 		13 rows removed due to missing values for these maps. [193 rows before, 180 rows remain]
# 		79 unique study-IDs removed given data for 0 or 1 sessions. [180 rows before, 101 rows remain]
# 		34 unique study-ID pairs remain after removing 86 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PNE042', 'PNE043', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX233', 'PX236', 'Pilot013']
# 			[Session: 1] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 2] 34 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (34, 9684)
# 			[Session: 3] 16 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (16, 9684)
# 			[Session: 4] 11 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (11, 9684)
# 			[Session: 5] 5 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (5, 9684)
# 			[Session: 6] 1 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_T1map_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_T1map_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (1, 9684)
#
# 	Processing surf-fsLR-5k_label-midthickness_flair_smth-5mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-5mm ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-5mm) | region: cortex
#
# 	Processing surf-fsLR-5k_label-midthickness_flair_smth-5mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-5mm ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-5mm)
# 		63 rows removed due to missing values for these maps. [193 rows before, 130 rows remain]
# 		88 unique study-IDs removed given data for 0 or 1 sessions. [130 rows before, 42 rows remain]
# 		18 unique study-ID pairs remain after removing 102 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC062', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC009', 'PNC019', 'PNC022', 'PNC024', 'PNC030', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE007', 'PNE008', 'PNE009', 'PNE010', 'PNE011', 'PNE012', 'PNE013', 'PNE014', 'PNE015', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE042', 'PNE043', 'PX043', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX233', 'PX235', 'PX236']
# 			[Session: 1] 18 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (18, 9684)
# 			[Session: 2] 18 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (18, 9684)
# 			[Session: 3] 5 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (5, 9684)
# 			[Session: 4] 1 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-5mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (1, 9684)
#
# 	Processing surf-fsLR-5k_label-midthickness_flair_smth-10mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-10mm ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-10mm) | region: cortex
#
# 	Processing surf-fsLR-5k_label-midthickness_flair_smth-10mm... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-10mm ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-10mm)
# 		63 rows removed due to missing values for these maps. [193 rows before, 130 rows remain]
# 		88 unique study-IDs removed given data for 0 or 1 sessions. [130 rows before, 42 rows remain]
# 		18 unique study-ID pairs remain after removing 102 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC062', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC009', 'PNC019', 'PNC022', 'PNC024', 'PNC030', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE007', 'PNE008', 'PNE009', 'PNE010', 'PNE011', 'PNE012', 'PNE013', 'PNE014', 'PNE015', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE042', 'PNE043', 'PX043', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX233', 'PX235', 'PX236']
# 			[Session: 1] 18 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (18, 9684)
# 			[Session: 2] 18 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (18, 9684)
# 			[Session: 3] 5 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (5, 9684)
# 			[Session: 4] 1 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_smth-10mm'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_smth-10mm']
# 	[get_maps] Maps retrieved. Size: (1, 9684)
#
# 	Processing surf-0p5mm_label-thickness_unsmth... (cols: hipp_hemi-L_surf-0p5mm_label-thickness_unsmth hipp_hemi-R_surf-0p5mm_label-thickness_unsmth) | region: hippocampus
#
# 	Processing surf-0p5mm_label-thickness_unsmth... (cols: hipp_hemi-L_surf-0p5mm_label-thickness_unsmth hipp_hemi-R_surf-0p5mm_label-thickness_unsmth)
# 		2 rows removed due to missing values for these maps. [193 rows before, 191 rows remain]
# 		82 unique study-IDs removed given data for 0 or 1 sessions. [191 rows before, 109 rows remain]
# 		36 unique study-ID pairs remain after removing 84 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC128', 'HC129', 'HC132', 'HC140', 'HC164', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX229', 'PX231', 'PX233', 'PX235', 'PX236', 'PX240', 'Pilot013']
# 			[Session: 1] 36 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (36, 14524)
# 			[Session: 2] 36 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (36, 14524)
# 			[Session: 3] 18 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (18, 14524)
# 			[Session: 4] 13 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (13, 14524)
# 			[Session: 5] 5 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (5, 14524)
# 			[Session: 6] 1 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-thickness_unsmth']
# 	[get_maps] Maps retrieved. Size: (1, 14524)
#
# 	Processing surf-0p5mm_label-thickness_smth-2mm... (cols: hipp_hemi-L_surf-0p5mm_label-thickness_smth-2mm hipp_hemi-R_surf-0p5mm_label-thickness_smth-2mm) | region: hippocampus
#
# 	Processing surf-0p5mm_label-thickness_smth-2mm... (cols: hipp_hemi-L_surf-0p5mm_label-thickness_smth-2mm hipp_hemi-R_surf-0p5mm_label-thickness_smth-2mm)
# 		2 rows removed due to missing values for these maps. [193 rows before, 191 rows remain]
# 		82 unique study-IDs removed given data for 0 or 1 sessions. [191 rows before, 109 rows remain]
# 		36 unique study-ID pairs remain after removing 84 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC128', 'HC129', 'HC132', 'HC140', 'HC164', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX229', 'PX231', 'PX233', 'PX235', 'PX236', 'PX240', 'Pilot013']
# 			[Session: 1] 36 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (36, 14524)
# 			[Session: 2] 36 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (36, 14524)
# 			[Session: 3] 18 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (18, 14524)
# 			[Session: 4] 13 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (13, 14524)
# 			[Session: 5] 5 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (5, 14524)
# 			[Session: 6] 1 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (1, 14524)
#
# 	Processing surf-0p5mm_label-thickness_smth-5mm... (cols: hipp_hemi-L_surf-0p5mm_label-thickness_smth-5mm hipp_hemi-R_surf-0p5mm_label-thickness_smth-5mm) | region: hippocampus
#
# 	Processing surf-0p5mm_label-thickness_smth-5mm... (cols: hipp_hemi-L_surf-0p5mm_label-thickness_smth-5mm hipp_hemi-R_surf-0p5mm_label-thickness_smth-5mm)
# 		2 rows removed due to missing values for these maps. [193 rows before, 191 rows remain]
# 		82 unique study-IDs removed given data for 0 or 1 sessions. [191 rows before, 109 rows remain]
# 		36 unique study-ID pairs remain after removing 84 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC128', 'HC129', 'HC132', 'HC140', 'HC164', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX229', 'PX231', 'PX233', 'PX235', 'PX236', 'PX240', 'Pilot013']
# 			[Session: 1] 36 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (36, 14524)
# 			[Session: 2] 36 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (36, 14524)
# 			[Session: 3] 18 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (18, 14524)
# 			[Session: 4] 13 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (13, 14524)
# 			[Session: 5] 5 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (5, 14524)
# 			[Session: 6] 1 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-thickness_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-thickness_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (1, 14524)
#
# 	Processing surf-0p5mm_label-midthickness_T1map_unsmth... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_unsmth hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_unsmth) | region: hippocampus
#
# 	Processing surf-0p5mm_label-midthickness_T1map_unsmth... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_unsmth hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_unsmth)
# 		15 rows removed due to missing values for these maps. [193 rows before, 178 rows remain]
# 		77 unique study-IDs removed given data for 0 or 1 sessions. [178 rows before, 101 rows remain]
# 		34 unique study-ID pairs remain after removing 86 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX233', 'PX236', 'Pilot013']
# 			[Session: 1] 34 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (34, 14524)
# 			[Session: 2] 34 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (34, 14524)
# 			[Session: 3] 16 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (16, 14524)
# 			[Session: 4] 11 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (11, 14524)
# 			[Session: 5] 5 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (5, 14524)
# 			[Session: 6] 1 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_unsmth']
# 	[get_maps] Maps retrieved. Size: (1, 14524)
#
# 	Processing surf-0p5mm_label-midthickness_T1map_smth-2mm... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-2mm hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-2mm) | region: hippocampus
#
# 	Processing surf-0p5mm_label-midthickness_T1map_smth-2mm... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-2mm hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-2mm)
# 		15 rows removed due to missing values for these maps. [193 rows before, 178 rows remain]
# 		77 unique study-IDs removed given data for 0 or 1 sessions. [178 rows before, 101 rows remain]
# 		34 unique study-ID pairs remain after removing 86 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX233', 'PX236', 'Pilot013']
# 			[Session: 1] 34 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (34, 14524)
# 			[Session: 2] 34 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (34, 14524)
# 			[Session: 3] 16 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (16, 14524)
# 			[Session: 4] 11 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (11, 14524)
# 			[Session: 5] 5 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (5, 14524)
# 			[Session: 6] 1 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (1, 14524)
#
# 	Processing surf-0p5mm_label-midthickness_T1map_smth-5mm... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-5mm hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-5mm) | region: hippocampus
#
# 	Processing surf-0p5mm_label-midthickness_T1map_smth-5mm... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-5mm hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-5mm)
# 		15 rows removed due to missing values for these maps. [193 rows before, 178 rows remain]
# 		77 unique study-IDs removed given data for 0 or 1 sessions. [178 rows before, 101 rows remain]
# 		34 unique study-ID pairs remain after removing 86 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC013', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC029', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE001', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE008', 'PNE010', 'PNE011', 'PNE013', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE041', 'PX038', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX233', 'PX236', 'Pilot013']
# 			[Session: 1] 34 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (34, 14524)
# 			[Session: 2] 34 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (34, 14524)
# 			[Session: 3] 16 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (16, 14524)
# 			[Session: 4] 11 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (11, 14524)
# 			[Session: 5] 5 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (5, 14524)
# 			[Session: 6] 1 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_T1map_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_T1map_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (1, 14524)
#
# 	Processing surf-0p5mm_label-midthickness_flair_smth-2mm... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-2mm hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-2mm) | region: hippocampus
#
# 	Processing surf-0p5mm_label-midthickness_flair_smth-2mm... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-2mm hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-2mm)
# 		65 rows removed due to missing values for these maps. [193 rows before, 128 rows remain]
# 		86 unique study-IDs removed given data for 0 or 1 sessions. [128 rows before, 42 rows remain]
# 		18 unique study-ID pairs remain after removing 102 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC062', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC009', 'PNC019', 'PNC022', 'PNC024', 'PNC030', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE007', 'PNE008', 'PNE009', 'PNE010', 'PNE011', 'PNE012', 'PNE013', 'PNE014', 'PNE015', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PX043', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX233', 'PX235', 'PX236']
# 			[Session: 1] 18 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (18, 14524)
# 			[Session: 2] 18 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (18, 14524)
# 			[Session: 3] 5 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (5, 14524)
# 			[Session: 4] 1 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-2mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-2mm']
# 	[get_maps] Maps retrieved. Size: (1, 14524)
#
# 	Processing surf-0p5mm_label-midthickness_flair_smth-5mm... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-5mm hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-5mm) | region: hippocampus
#
# 	Processing surf-0p5mm_label-midthickness_flair_smth-5mm... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-5mm hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-5mm)
# 		65 rows removed due to missing values for these maps. [193 rows before, 128 rows remain]
# 		86 unique study-IDs removed given data for 0 or 1 sessions. [128 rows before, 42 rows remain]
# 		18 unique study-ID pairs remain after removing 102 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC062', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC009', 'PNC019', 'PNC022', 'PNC024', 'PNC030', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE007', 'PNE008', 'PNE009', 'PNE010', 'PNE011', 'PNE012', 'PNE013', 'PNE014', 'PNE015', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PX043', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX233', 'PX235', 'PX236']
# 			[Session: 1] 18 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (18, 14524)
# 			[Session: 2] 18 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (18, 14524)
# 			[Session: 3] 5 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (5, 14524)
# 			[Session: 4] 1 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_smth-5mm'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_smth-5mm']
# 	[get_maps] Maps retrieved. Size: (1, 14524)
#
# 	Processing surf-fsLR-5k_label-midthickness_flair_unsmth... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_unsmth ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_unsmth) | region: cortex
#
# 	Processing surf-fsLR-5k_label-midthickness_flair_unsmth... (cols: ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_unsmth ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_unsmth)
# 		63 rows removed due to missing values for these maps. [193 rows before, 130 rows remain]
# 		88 unique study-IDs removed given data for 0 or 1 sessions. [130 rows before, 42 rows remain]
# 		18 unique study-ID pairs remain after removing 102 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC062', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC009', 'PNC019', 'PNC022', 'PNC024', 'PNC030', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE007', 'PNE008', 'PNE009', 'PNE010', 'PNE011', 'PNE012', 'PNE013', 'PNE014', 'PNE015', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PNE042', 'PNE043', 'PX043', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX233', 'PX235', 'PX236']
# 			[Session: 1] 18 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_unsmth']
# 	[get_maps] Maps retrieved. Size: (18, 9684)
# 			[Session: 2] 18 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_unsmth']
# 	[get_maps] Maps retrieved. Size: (18, 9684)
# 			[Session: 3] 5 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_unsmth']
# 	[get_maps] Maps retrieved. Size: (5, 9684)
# 			[Session: 4] 1 rows
# [get_maps] ['ctx_hemi-L_surf-fsLR-5k_label-midthickness_flair_unsmth'], ['ctx_hemi-R_surf-fsLR-5k_label-midthickness_flair_unsmth']
# 	[get_maps] Maps retrieved. Size: (1, 9684)
#
# 	Processing surf-0p5mm_label-midthickness_flair_unsmth... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_flair_unsmth hipp_hemi-R_surf-0p5mm_label-midthickness_flair_unsmth) | region: hippocampus
#
# 	Processing surf-0p5mm_label-midthickness_flair_unsmth... (cols: hipp_hemi-L_surf-0p5mm_label-midthickness_flair_unsmth hipp_hemi-R_surf-0p5mm_label-midthickness_flair_unsmth)
# 		65 rows removed due to missing values for these maps. [193 rows before, 128 rows remain]
# 		86 unique study-IDs removed given data for 0 or 1 sessions. [128 rows before, 42 rows remain]
# 		18 unique study-ID pairs remain after removing 102 IDs due to having one or zero sessions with data for this column.
# 		sutdy-IDs removed: ['HC062', 'HC116', 'HC128', 'HC129', 'HC132', 'HC140', 'PNC009', 'PNC019', 'PNC022', 'PNC024', 'PNC030', 'PNC037', 'PNC038', 'PNC039', 'PNC040', 'PNC041', 'PNC043', 'PNE002', 'PNE003', 'PNE004', 'PNE005', 'PNE006', 'PNE007', 'PNE008', 'PNE009', 'PNE010', 'PNE011', 'PNE012', 'PNE013', 'PNE014', 'PNE015', 'PNE016', 'PNE017', 'PNE018', 'PNE019', 'PNE020', 'PNE021', 'PNE022', 'PNE023', 'PNE024', 'PNE025', 'PNE026', 'PNE027', 'PNE028', 'PNE029', 'PNE030', 'PNE031', 'PNE033', 'PNE034', 'PNE035', 'PNE036', 'PNE037', 'PNE038', 'PNE040', 'PX043', 'PX119', 'PX131', 'PX137', 'PX148', 'PX152', 'PX153', 'PX158', 'PX168', 'PX173', 'PX174', 'PX175', 'PX176', 'PX183', 'PX189', 'PX190', 'PX192', 'PX194', 'PX198', 'PX199', 'PX200', 'PX204', 'PX215', 'PX216', 'PX222', 'PX223', 'PX224', 'PX225', 'PX228', 'PX233', 'PX235', 'PX236']
# 			[Session: 1] 18 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_unsmth']
# 	[get_maps] Maps retrieved. Size: (18, 14524)
# 			[Session: 2] 18 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_unsmth']
# 	[get_maps] Maps retrieved. Size: (18, 14524)
# 			[Session: 3] 5 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_unsmth']
# 	[get_maps] Maps retrieved. Size: (5, 14524)
# 			[Session: 4] 1 rows
# [get_maps] ['hipp_hemi-L_surf-0p5mm_label-midthickness_flair_unsmth'], ['hipp_hemi-R_surf-0p5mm_label-midthickness_flair_unsmth']
# 	[get_maps] Maps retrieved. Size: (1, 14524)
# Saved map_dictlist with z-scores to /host/verges/tank/data/daniel/3T7T/z/outputs/btwSES/01a_maps_19Sep2025-102425.pkl
#
# [extractMap] Returning list with 96 dictionary items (region: hippocampus).

# %%
tsutil.print_dict(dl)
# Out:
#  Dict list length (96 items)
#
# [0]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [1]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [2]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 9684)>
#
# [3]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(13, 12)>
# 	df_maps: <DataFrame shape=(13, 9684)>
#
# [4]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 9684)>
#
# [5]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 9684)>
#
# [6]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [7]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [8]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 9684)>
#
# [9]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(13, 12)>
# 	df_maps: <DataFrame shape=(13, 9684)>
#
# [10]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 9684)>
#
# [11]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 9684)>
#
# [12]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [13]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [14]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 9684)>
#
# [15]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(13, 12)>
# 	df_maps: <DataFrame shape=(13, 9684)>
#
# [16]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 9684)>
#
# [17]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 9684)>
#
# [18]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [19]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [20]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(16, 12)>
# 	df_maps: <DataFrame shape=(16, 9684)>
#
# [21]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(11, 12)>
# 	df_maps: <DataFrame shape=(11, 9684)>
#
# [22]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 9684)>
#
# [23]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 9684)>
#
# [24]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [25]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [26]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(16, 12)>
# 	df_maps: <DataFrame shape=(16, 9684)>
#
# [27]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(11, 12)>
# 	df_maps: <DataFrame shape=(11, 9684)>
#
# [28]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 9684)>
#
# [29]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 9684)>
#
# [30]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [31]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 9684)>
#
# [32]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(16, 12)>
# 	df_maps: <DataFrame shape=(16, 9684)>
#
# [33]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(11, 12)>
# 	df_maps: <DataFrame shape=(11, 9684)>
#
# [34]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 9684)>
#
# [35]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 9684)>
#
# [36]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 9684)>
#
# [37]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 9684)>
#
# [38]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 9684)>
#
# [39]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 9684)>
#
# [40]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 9684)>
#
# [41]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 9684)>
#
# [42]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 9684)>
#
# [43]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 9684)>
#
# [44]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(36, 12)>
# 	df_maps: <DataFrame shape=(36, 14524)>
#
# [45]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(36, 12)>
# 	df_maps: <DataFrame shape=(36, 14524)>
#
# [46]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 14524)>
#
# [47]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(13, 12)>
# 	df_maps: <DataFrame shape=(13, 14524)>
#
# [48]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 14524)>
#
# [49]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: NA
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 14524)>
#
# [50]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 2
# 	df_demo: <DataFrame shape=(36, 12)>
# 	df_maps: <DataFrame shape=(36, 14524)>
#
# [51]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 2
# 	df_demo: <DataFrame shape=(36, 12)>
# 	df_maps: <DataFrame shape=(36, 14524)>
#
# [52]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 2
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 14524)>
#
# [53]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 2
# 	df_demo: <DataFrame shape=(13, 12)>
# 	df_maps: <DataFrame shape=(13, 14524)>
#
# [54]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 2
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 14524)>
#
# [55]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 2
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 14524)>
#
# [56]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 12)>
# 	df_maps: <DataFrame shape=(36, 14524)>
#
# [57]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 12)>
# 	df_maps: <DataFrame shape=(36, 14524)>
#
# [58]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 14524)>
#
# [59]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(13, 12)>
# 	df_maps: <DataFrame shape=(13, 14524)>
#
# [60]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 14524)>
#
# [61]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 14524)>
#
# [62]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 14524)>
#
# [63]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 14524)>
#
# [64]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(16, 12)>
# 	df_maps: <DataFrame shape=(16, 14524)>
#
# [65]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(11, 12)>
# 	df_maps: <DataFrame shape=(11, 14524)>
#
# [66]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 14524)>
#
# [67]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: NA
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 14524)>
#
# [68]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 14524)>
#
# [69]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 14524)>
#
# [70]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(16, 12)>
# 	df_maps: <DataFrame shape=(16, 14524)>
#
# [71]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(11, 12)>
# 	df_maps: <DataFrame shape=(11, 14524)>
#
# [72]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 14524)>
#
# [73]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 14524)>
#
# [74]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 14524)>
#
# [75]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(34, 12)>
# 	df_maps: <DataFrame shape=(34, 14524)>
#
# [76]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(16, 12)>
# 	df_maps: <DataFrame shape=(16, 14524)>
#
# [77]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(11, 12)>
# 	df_maps: <DataFrame shape=(11, 14524)>
#
# [78]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 5
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 14524)>
#
# [79]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 6
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 14524)>
#
# [80]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 14524)>
#
# [81]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 14524)>
#
# [82]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 14524)>
#
# [83]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 14524)>
#
# [84]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 14524)>
#
# [85]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 14524)>
#
# [86]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 14524)>
#
# [87]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 14524)>
#
# [88]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: NA
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 9684)>
#
# [89]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: NA
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 9684)>
#
# [90]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: NA
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 9684)>
#
# [91]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: NA
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 9684)>
#
# [92]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 1
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: NA
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 14524)>
#
# [93]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 2
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: NA
# 	df_demo: <DataFrame shape=(18, 12)>
# 	df_maps: <DataFrame shape=(18, 14524)>
#
# [94]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 3
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: NA
# 	df_demo: <DataFrame shape=(5, 12)>
# 	df_maps: <DataFrame shape=(5, 14524)>
#
# [95]
# 	Keys: ['sesNum', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	sesNum: 4
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: NA
# 	df_demo: <DataFrame shape=(1, 12)>
# 	df_maps: <DataFrame shape=(1, 14524)>

# %%
# SHOW MAP MATRICES # TODO. adatpt for sessions
importlib.reload(tsutil)

# create pngs
fig_dir = "/host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw"
tsutil.plotMatrices(dl = dl, key = 'df_maps', sessions = [1,2], show=False, save_pth=fig_dir, test=False) # Visualize unsmoothed maps
tsutil.pngs2pdf(fig_dir, output="/host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES") # group pngs of same comparisons with different smoothing to single pdf

print("Should visually inspect maps, identifying feature-ID-SES combinations that are outliers. Mark for removal [editing <path/to/file name.xlsx> and rerun from step 3.")
# Out:
# Plotting matrices for df_maps...
# [get_pair] WARNING: Multiple matches found for index 0 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [1, 2, 3, 4, 5]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/cortex_thickness_fsLR-5k_thickness_smth-NAmm_ses-12_19Sep2025-110558.png
# [get_pair] WARNING: Multiple matches found for index 6 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [7, 8, 9, 10, 11]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/cortex_thickness_fsLR-5k_thickness_smth-5mm_ses-12_19Sep2025-110604.png
# [get_pair] WARNING: Multiple matches found for index 12 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [13, 14, 15, 16, 17]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/cortex_thickness_fsLR-5k_thickness_smth-10mm_ses-12_19Sep2025-110609.png
# [get_pair] WARNING: Multiple matches found for index 18 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [19, 20, 21, 22, 23]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/cortex_T1map_fsLR-5k_midthickness_smth-NAmm_ses-12_19Sep2025-110614.png
# [get_pair] WARNING: Multiple matches found for index 24 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [25, 26, 27, 28, 29]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/cortex_T1map_fsLR-5k_midthickness_smth-5mm_ses-12_19Sep2025-110619.png
# [get_pair] WARNING: Multiple matches found for index 30 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [31, 32, 33, 34, 35]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/cortex_T1map_fsLR-5k_midthickness_smth-10mm_ses-12_19Sep2025-110624.png
# [get_pair] WARNING: Multiple matches found for index 36 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [37, 38, 39]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/cortex_flair_fsLR-5k_midthickness_smth-5mm_ses-12_19Sep2025-110630.png
# [get_pair] WARNING: Multiple matches found for index 40 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [41, 42, 43]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/cortex_flair_fsLR-5k_midthickness_smth-10mm_ses-12_19Sep2025-110635.png
# [get_pair] WARNING: Multiple matches found for index 44 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [45, 46, 47, 48, 49]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/hippocampus_thickness_0p5mm_thickness_smth-NAmm_ses-12_19Sep2025-110639.png
# [get_pair] WARNING: Multiple matches found for index 50 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [51, 52, 53, 54, 55]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/hippocampus_thickness_0p5mm_thickness_smth-2mm_ses-12_19Sep2025-110645.png
# [get_pair] WARNING: Multiple matches found for index 56 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [57, 58, 59, 60, 61]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/hippocampus_thickness_0p5mm_thickness_smth-5mm_ses-12_19Sep2025-110650.png
# [get_pair] WARNING: Multiple matches found for index 62 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [63, 64, 65, 66, 67]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/hippocampus_T1map_0p5mm_midthickness_smth-NAmm_ses-12_19Sep2025-110656.png
# [get_pair] WARNING: Multiple matches found for index 68 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [69, 70, 71, 72, 73]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/hippocampus_T1map_0p5mm_midthickness_smth-2mm_ses-12_19Sep2025-110701.png
# [get_pair] WARNING: Multiple matches found for index 74 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [75, 76, 77, 78, 79]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/hippocampus_T1map_0p5mm_midthickness_smth-5mm_ses-12_19Sep2025-110706.png
# [get_pair] WARNING: Multiple matches found for index 80 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [81, 82, 83]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/hippocampus_flair_0p5mm_midthickness_smth-2mm_ses-12_19Sep2025-110712.png
# [get_pair] WARNING: Multiple matches found for index 84 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [85, 86, 87]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/hippocampus_flair_0p5mm_midthickness_smth-5mm_ses-12_19Sep2025-110717.png
# [get_pair] WARNING: Multiple matches found for index 88 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [89, 90, 91]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/cortex_flair_fsLR-5k_midthickness_smth-NAmm_ses-12_19Sep2025-110721.png
# [get_pair] WARNING: Multiple matches found for index 92 with keys ['region', 'surf', 'label', 'feature', 'smth']. Returning all matches: [93, 94, 95]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/maps_SES/raw/hippocampus_flair_0p5mm_midthickness_smth-NAmm_ses-12_19Sep2025-110726.png
# Should visually inspect maps, identifying feature-ID-SES combinations that are outliers. Mark for removal [editing <path/to/file name.xlsx> and rerun from step 3.

# %% [markdown]
# # Within study, vertex-wise statistics (z-, w- scores)
# - compares _all_ participants to controls

# %%
# import smmothed maps
reimport = False
test = False
toPrint = True
save_name = "05a_stats_winStudy"

if 'dl' not in globals() or dl is None or reimport == True:
    pth = "/host/verges/tank/data/daniel/3T7T/z/outputs/btwSES/01a_maps_19Sep2025-102425.pkl"
    dl = tsutil.loadPickle(pth, dlPrint=toPrint)
    
tsutil.print_dict(dl, df_print=False)

# calculate statistics
dl_winComp = tsutil.winComp(dl = dl, demographics = demographics, ctrl_grp = ctrl_grp, z = ses_specs['z'], w = ses_specs['w'], 
                            covars = ses_specs['covars'], col_grp = ses_specs['col_grp'],
                            save = True, save_pth = ses_specs['prjDir_root'] + ses_specs['prjDir_outs'], save_name = save_name,
                            verbose = True, dlPrint = True, test=test)
# Out:
# Loaded smoothed maps from /host/verges/tank/data/daniel/3T7T/z/outputs/04b_dl_maps_smth_17Sep2025-091726.pkl
#
#  Dict list length (120 items)
#
# [0]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(56, 221)>
# 	df_maps: <DataFrame shape=(56, 9684)>
#
# [1]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(56, 221)>
# 	df_maps: <DataFrame shape=(56, 9684)>
#
# [2]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(56, 221)>
# 	df_maps: <DataFrame shape=(56, 9684)>
#
# [3]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(56, 221)>
# 	df_maps: <DataFrame shape=(56, 9684)>
#
# [4]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
#
# [5]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
#
# [6]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [7]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [8]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
#
# [9]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
#
# [10]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [11]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [12]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
#
# [13]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
#
# [14]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [15]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [16]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
#
# [17]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
#
# [18]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [19]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [20]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
#
# [21]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
#
# [22]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [23]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [24]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
#
# [25]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
#
# [26]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [27]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [28]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
#
# [29]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
#
# [30]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [31]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [32]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
#
# [33]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
#
# [34]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [35]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [36]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [37]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [38]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [39]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [40]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [41]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [42]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [43]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [44]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [45]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [46]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [47]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [48]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [49]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [50]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [51]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [52]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [53]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [54]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [55]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [56]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [57]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [58]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [59]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [60]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: FA
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [61]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: FA
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [62]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: FA
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [63]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: FA
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [64]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: FA
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [65]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: FA
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
#
# [66]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: FA
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [67]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: FA
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [68]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 2
# 	df_demo: <DataFrame shape=(58, 221)>
# 	df_maps: <DataFrame shape=(58, 14524)>
#
# [69]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 2
# 	df_demo: <DataFrame shape=(58, 221)>
# 	df_maps: <DataFrame shape=(58, 14524)>
#
# [70]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(58, 221)>
# 	df_maps: <DataFrame shape=(58, 14524)>
#
# [71]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(58, 221)>
# 	df_maps: <DataFrame shape=(58, 14524)>
#
# [72]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [73]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [74]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [75]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [76]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [77]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: T1map
# 	smth: 2
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [78]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [79]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [80]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [81]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [82]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [83]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(52, 221)>
# 	df_maps: <DataFrame shape=(52, 14524)>
#
# [84]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [85]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [86]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [87]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [88]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [89]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: flair
# 	smth: 2
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [90]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [91]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [92]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [93]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [94]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [95]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(35, 221)>
# 	df_maps: <DataFrame shape=(35, 14524)>
#
# [96]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: ADC
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [97]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: ADC
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [98]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: ADC
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [99]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: ADC
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [100]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: ADC
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [101]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: ADC
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [102]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [103]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [104]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [105]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [106]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [107]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [108]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [109]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [110]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [111]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [112]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [113]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [114]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [115]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [116]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [117]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [118]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
#
# [119]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# [winComp] Saving log to: /host/verges/tank/data/daniel/3T7T/z/outputs/05a_stats_winStudy_log_17Sep2025-162236.txt
# [winComp] Saving log to: /host/verges/tank/data/daniel/3T7T/z/outputs/05a_stats_winStudy_log_17Sep2025-162236.txt
# Computing within study comparisons. Start time: 2025-09-17 16:22:36
# 	Parameters: z=True, w=True, covars=['age', 'sex'], col_grp=grp_detailed, ctrl_grp={'ctrl': ['CTRL']}
# 	Demographics columns: {'pth': '/host/verges/tank/data/daniel/3T7T/z/outputs/01c_grpSummary_16Sep2025.csv', 'nStudies': True, 'ID_7T': 'PNI_ID', 'ID_3T': 'MICS_ID', 'SES': 'SES', 'date': 'Date', 'age': 'age', 'sex': 'sex', 'grp': 'grp_detailed'}
# 	Number of dictionary items to process: 120
# 	[MICs] - cortex: thickness, fsLR-5k, thickness, 5mm
# 	Input shapes:		[demo] (56, 221) | [maps] (56, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (55, 2) | [maps] (55, 9684)
# 	Output shape:		[map stats] (55, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (56, 221) | [maps] (56, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (55, 2) | [maps] (55, 9684)
# 	Output shape:		[map stats] (55, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (56, 221) | [maps] (56, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (55, 2) | [maps] (55, 9684)
# 	Output shape:		[map stats] (55, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (56, 221) | [maps] (56, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (55, 2) | [maps] (55, 9684)
# 	Output shape:		[map stats] (55, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (53, 221) | [maps] (53, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (52, 2) | [maps] (52, 9684)
# 	Output shape:		[map stats] (52, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (53, 221) | [maps] (53, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (52, 2) | [maps] (52, 9684)
# 	Output shape:		[map stats] (52, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (53, 221) | [maps] (53, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (52, 2) | [maps] (52, 9684)
# 	Output shape:		[map stats] (52, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (53, 221) | [maps] (53, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (52, 2) | [maps] (52, 9684)
# 	Output shape:		[map stats] (52, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (53, 221) | [maps] (53, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (52, 2) | [maps] (52, 9684)
# 	Output shape:		[map stats] (52, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (53, 221) | [maps] (53, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (52, 2) | [maps] (52, 9684)
# 	Output shape:		[map stats] (52, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (53, 221) | [maps] (53, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (52, 2) | [maps] (52, 9684)
# 	Output shape:		[map stats] (52, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (53, 221) | [maps] (53, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (17, 2) | [maps] (17, 9684)
# 	Test group shapes:	[demo] (52, 2) | [maps] (52, 9684)
# 	Output shape:		[map stats] (52, 9684)
# 	Computing z scores [17 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [17 controls, 2 covars]...
# 		W-scores computed in 00:07 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (36, 221) | [maps] (36, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'M': 0, 'F': 1}, 'original_values': ['M', 'F']}}
# 	Control group shapes:	[demo] (3, 2) | [maps] (3, 9684)
# 	Test group shapes:	[demo] (36, 2) | [maps] (36, 9684)
# 	Output shape:		[map stats] (36, 9684)
# 	Input shapes:		[demo] (36, 221) | [maps] (36, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'M': 0, 'F': 1}, 'original_values': ['M', 'F']}}
# 	Control group shapes:	[demo] (3, 2) | [maps] (3, 9684)
# 	Test group shapes:	[demo] (36, 2) | [maps] (36, 9684)
# 	Output shape:		[map stats] (36, 9684)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (36, 221) | [maps] (36, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'M': 0, 'F': 1}, 'original_values': ['M', 'F']}}
# 	Control group shapes:	[demo] (3, 2) | [maps] (3, 9684)
# 	Test group shapes:	[demo] (36, 2) | [maps] (36, 9684)
# 	Output shape:		[map stats] (36, 9684)
# 	Input shapes:		[demo] (36, 221) | [maps] (36, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'M': 0, 'F': 1}, 'original_values': ['M', 'F']}}
# 	Control group shapes:	[demo] (3, 2) | [maps] (3, 9684)
# 	Test group shapes:	[demo] (36, 2) | [maps] (36, 9684)
# 	Output shape:		[map stats] (36, 9684)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (36, 221) | [maps] (36, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'M': 0, 'F': 1}, 'original_values': ['M', 'F']}}
# 	Control group shapes:	[demo] (3, 2) | [maps] (3, 9684)
# 	Test group shapes:	[demo] (36, 2) | [maps] (36, 9684)
# 	Output shape:		[map stats] (36, 9684)
# 	Input shapes:		[demo] (36, 221) | [maps] (36, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'M': 0, 'F': 1}, 'original_values': ['M', 'F']}}
# 	Control group shapes:	[demo] (3, 2) | [maps] (3, 9684)
# 	Test group shapes:	[demo] (36, 2) | [maps] (36, 9684)
# 	Output shape:		[map stats] (36, 9684)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (36, 221) | [maps] (36, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'M': 0, 'F': 1}, 'original_values': ['M', 'F']}}
# 	Control group shapes:	[demo] (3, 2) | [maps] (3, 9684)
# 	Test group shapes:	[demo] (36, 2) | [maps] (36, 9684)
# 	Output shape:		[map stats] (36, 9684)
# 	Input shapes:		[demo] (36, 221) | [maps] (36, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'M': 0, 'F': 1}, 'original_values': ['M', 'F']}}
# 	Control group shapes:	[demo] (3, 2) | [maps] (3, 9684)
# 	Test group shapes:	[demo] (36, 2) | [maps] (36, 9684)
# 	Output shape:		[map stats] (36, 9684)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:07 (mm:ss).
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:07 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:07 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:07 (mm:ss).
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:07 (mm:ss).
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:07 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# 	Computing w scores [15 controls, 2 covars]...
# 		W-scores computed in 00:08 (mm:ss).
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (0, 221) | [maps] (0, 0)
# 	Input shapes:		[demo] (50, 221) | [maps] (50, 9684)
# 	Converted categorical covariates to dummy variables:
# 	{'sex': {'type': 'binary', 'mapping': {'F': 0, 'M': 1}, 'original_values': ['F', 'M']}}
# 	Control group shapes:	[demo] (15, 2) | [maps] (15, 9684)
# 	Test group shapes:	[demo] (50, 2) | [maps] (50, 9684)
# 	Output shape:		[map stats] (50, 9684)
# 	Computing z scores [15 controls]...
# 		Z-scores computed in 00:00 (mm:ss).
# ...
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [101]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: ADC
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [102]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [103]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [104]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [105]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [106]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [107]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [108]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [109]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [110]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [111]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [112]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [113]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [114]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [115]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [116]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [117]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [118]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>
#
# [119]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_z: <DataFrame shape=(49, 14524)>
# 	df_w: <DataFrame shape=(49, 14524)>
# 	df_w_models: <DataFrame shape=(4, 14524)>

# %%
importlib.reload(tsutil)
fig_dir = "/host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw"
tsutil.plotMatrices(dl = dl_winComp, key = 'df_z', name_append="stat-z", show=False, save_pth=fig_dir, test=False) # visualize z score maps
tsutil.plotMatrices(dl = dl_winComp, key = 'df_w', name_append="stat-w", show=False, save_pth=fig_dir, test=False) # visualize w score maps
tsutil.pngs2pdf(fig_dir, output="/host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp", verbose = True) # group pngs of same comparisons with different smoothing to single pdf
# Out:
# Plotting matrices for df_z...
# 	NaN values present [df_z MICs [idx: 0]: thickness]
# 	NaN values present [df_z PNI [idx: 1]: thickness]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_thickness_fsLR-5k_thickness_smth-5mm_stat-z_17Sep2025-163632.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_thickness_fsLR-5k_thickness_smth-10mm_stat-z_17Sep2025-163639.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_T1map_fsLR-5k_midthickness_smth-5mm_stat-z_17Sep2025-163646.png
# [MICs] - cortex: T1map, fsLR-5k, pial, 5mm
# [PNI] - cortex: T1map, fsLR-5k, pial, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_T1map_fsLR-5k_white_smth-5mm_stat-z_17Sep2025-163653.png
# [MICs] - cortex: T1map, fsLR-5k, swm1.0mm, 5mm
# [PNI] - cortex: T1map, fsLR-5k, swm1.0mm, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_T1map_fsLR-5k_midthickness_smth-10mm_stat-z_17Sep2025-163659.png
# [MICs] - cortex: T1map, fsLR-5k, pial, 10mm
# [PNI] - cortex: T1map, fsLR-5k, pial, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_T1map_fsLR-5k_white_smth-10mm_stat-z_17Sep2025-163706.png
# [MICs] - cortex: T1map, fsLR-5k, swm1.0mm, 10mm
# [PNI] - cortex: T1map, fsLR-5k, swm1.0mm, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, midthickness, 5mm
# [PNI] - cortex: flair, fsLR-5k, midthickness, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, pial, 5mm
# [PNI] - cortex: flair, fsLR-5k, pial, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, white, 5mm
# [PNI] - cortex: flair, fsLR-5k, white, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, swm1.0mm, 5mm
# [PNI] - cortex: flair, fsLR-5k, swm1.0mm, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, midthickness, 10mm
# [PNI] - cortex: flair, fsLR-5k, midthickness, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, pial, 10mm
# [PNI] - cortex: flair, fsLR-5k, pial, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, white, 10mm
# [PNI] - cortex: flair, fsLR-5k, white, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, swm1.0mm, 10mm
# [PNI] - cortex: flair, fsLR-5k, swm1.0mm, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_ADC_fsLR-5k_midthickness_smth-5mm_stat-z_17Sep2025-163712.png
# [MICs] - cortex: ADC, fsLR-5k, pial, 5mm
# [PNI] - cortex: ADC, fsLR-5k, pial, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_ADC_fsLR-5k_white_smth-5mm_stat-z_17Sep2025-163719.png
# [MICs] - cortex: ADC, fsLR-5k, swm1.0mm, 5mm
# [PNI] - cortex: ADC, fsLR-5k, swm1.0mm, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_ADC_fsLR-5k_midthickness_smth-10mm_stat-z_17Sep2025-163725.png
# [MICs] - cortex: ADC, fsLR-5k, pial, 10mm
# [PNI] - cortex: ADC, fsLR-5k, pial, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_ADC_fsLR-5k_white_smth-10mm_stat-z_17Sep2025-163732.png
# [MICs] - cortex: ADC, fsLR-5k, swm1.0mm, 10mm
# [PNI] - cortex: ADC, fsLR-5k, swm1.0mm, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_FA_fsLR-5k_midthickness_smth-5mm_stat-z_17Sep2025-163738.png
# [MICs] - cortex: FA, fsLR-5k, pial, 5mm
# [PNI] - cortex: FA, fsLR-5k, pial, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_FA_fsLR-5k_white_smth-5mm_stat-z_17Sep2025-163745.png
# [MICs] - cortex: FA, fsLR-5k, swm1.0mm, 5mm
# [PNI] - cortex: FA, fsLR-5k, swm1.0mm, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_FA_fsLR-5k_midthickness_smth-10mm_stat-z_17Sep2025-163751.png
# [MICs] - cortex: FA, fsLR-5k, pial, 10mm
# [PNI] - cortex: FA, fsLR-5k, pial, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_FA_fsLR-5k_white_smth-10mm_stat-z_17Sep2025-163758.png
# [MICs] - cortex: FA, fsLR-5k, swm1.0mm, 10mm
# [PNI] - cortex: FA, fsLR-5k, swm1.0mm, 10mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_thickness_0p5mm_thickness_smth-2mm_stat-z_17Sep2025-163804.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_thickness_0p5mm_thickness_smth-5mm_stat-z_17Sep2025-163811.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_midthickness_smth-2mm_stat-z_17Sep2025-163818.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_inner_smth-2mm_stat-z_17Sep2025-163824.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_outer_smth-2mm_stat-z_17Sep2025-163831.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_midthickness_smth-5mm_stat-z_17Sep2025-163838.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_inner_smth-5mm_stat-z_17Sep2025-163844.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_outer_smth-5mm_stat-z_17Sep2025-163851.png
# [MICs] - hippocampus: flair, 0p5mm, midthickness, 2mm
# [PNI] - hippocampus: flair, 0p5mm, midthickness, 2mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, inner, 2mm
# [PNI] - hippocampus: flair, 0p5mm, inner, 2mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, outer, 2mm
# [PNI] - hippocampus: flair, 0p5mm, outer, 2mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, midthickness, 5mm
# [PNI] - hippocampus: flair, 0p5mm, midthickness, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, inner, 5mm
# [PNI] - hippocampus: flair, 0p5mm, inner, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, outer, 5mm
# [PNI] - hippocampus: flair, 0p5mm, outer, 5mm
# 	WARNING. Missing key 'df_z'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_midthickness_smth-2mm_stat-z_17Sep2025-163857.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_inner_smth-2mm_stat-z_17Sep2025-163904.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_outer_smth-2mm_stat-z_17Sep2025-163911.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_midthickness_smth-5mm_stat-z_17Sep2025-163917.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_inner_smth-5mm_stat-z_17Sep2025-163924.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_outer_smth-5mm_stat-z_17Sep2025-163931.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_midthickness_smth-2mm_stat-z_17Sep2025-163937.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_inner_smth-2mm_stat-z_17Sep2025-163944.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_outer_smth-2mm_stat-z_17Sep2025-163951.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_midthickness_smth-5mm_stat-z_17Sep2025-163957.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_inner_smth-5mm_stat-z_17Sep2025-164004.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_outer_smth-5mm_stat-z_17Sep2025-164010.png
# Plotting matrices for df_w...
# 	NaN values present [df_w MICs [idx: 0]: thickness]
# 	NaN values present [df_w PNI [idx: 1]: thickness]
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_thickness_fsLR-5k_thickness_smth-5mm_stat-w_17Sep2025-164017.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_thickness_fsLR-5k_thickness_smth-10mm_stat-w_17Sep2025-164025.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_T1map_fsLR-5k_midthickness_smth-5mm_stat-w_17Sep2025-164032.png
# [MICs] - cortex: T1map, fsLR-5k, pial, 5mm
# [PNI] - cortex: T1map, fsLR-5k, pial, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_T1map_fsLR-5k_white_smth-5mm_stat-w_17Sep2025-164040.png
# [MICs] - cortex: T1map, fsLR-5k, swm1.0mm, 5mm
# [PNI] - cortex: T1map, fsLR-5k, swm1.0mm, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_T1map_fsLR-5k_midthickness_smth-10mm_stat-w_17Sep2025-164047.png
# [MICs] - cortex: T1map, fsLR-5k, pial, 10mm
# [PNI] - cortex: T1map, fsLR-5k, pial, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_T1map_fsLR-5k_white_smth-10mm_stat-w_17Sep2025-164054.png
# [MICs] - cortex: T1map, fsLR-5k, swm1.0mm, 10mm
# [PNI] - cortex: T1map, fsLR-5k, swm1.0mm, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, midthickness, 5mm
# [PNI] - cortex: flair, fsLR-5k, midthickness, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, pial, 5mm
# [PNI] - cortex: flair, fsLR-5k, pial, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, white, 5mm
# [PNI] - cortex: flair, fsLR-5k, white, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, swm1.0mm, 5mm
# [PNI] - cortex: flair, fsLR-5k, swm1.0mm, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, midthickness, 10mm
# [PNI] - cortex: flair, fsLR-5k, midthickness, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, pial, 10mm
# [PNI] - cortex: flair, fsLR-5k, pial, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, white, 10mm
# [PNI] - cortex: flair, fsLR-5k, white, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - cortex: flair, fsLR-5k, swm1.0mm, 10mm
# [PNI] - cortex: flair, fsLR-5k, swm1.0mm, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_ADC_fsLR-5k_midthickness_smth-5mm_stat-w_17Sep2025-164101.png
# [MICs] - cortex: ADC, fsLR-5k, pial, 5mm
# [PNI] - cortex: ADC, fsLR-5k, pial, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_ADC_fsLR-5k_white_smth-5mm_stat-w_17Sep2025-164108.png
# [MICs] - cortex: ADC, fsLR-5k, swm1.0mm, 5mm
# [PNI] - cortex: ADC, fsLR-5k, swm1.0mm, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_ADC_fsLR-5k_midthickness_smth-10mm_stat-w_17Sep2025-164116.png
# [MICs] - cortex: ADC, fsLR-5k, pial, 10mm
# [PNI] - cortex: ADC, fsLR-5k, pial, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_ADC_fsLR-5k_white_smth-10mm_stat-w_17Sep2025-164123.png
# [MICs] - cortex: ADC, fsLR-5k, swm1.0mm, 10mm
# [PNI] - cortex: ADC, fsLR-5k, swm1.0mm, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_FA_fsLR-5k_midthickness_smth-5mm_stat-w_17Sep2025-164130.png
# [MICs] - cortex: FA, fsLR-5k, pial, 5mm
# [PNI] - cortex: FA, fsLR-5k, pial, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_FA_fsLR-5k_white_smth-5mm_stat-w_17Sep2025-164137.png
# [MICs] - cortex: FA, fsLR-5k, swm1.0mm, 5mm
# [PNI] - cortex: FA, fsLR-5k, swm1.0mm, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_FA_fsLR-5k_midthickness_smth-10mm_stat-w_17Sep2025-164144.png
# [MICs] - cortex: FA, fsLR-5k, pial, 10mm
# [PNI] - cortex: FA, fsLR-5k, pial, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/cortex_FA_fsLR-5k_white_smth-10mm_stat-w_17Sep2025-164151.png
# [MICs] - cortex: FA, fsLR-5k, swm1.0mm, 10mm
# [PNI] - cortex: FA, fsLR-5k, swm1.0mm, 10mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_thickness_0p5mm_thickness_smth-2mm_stat-w_17Sep2025-164158.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_thickness_0p5mm_thickness_smth-5mm_stat-w_17Sep2025-164205.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_midthickness_smth-2mm_stat-w_17Sep2025-164213.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_inner_smth-2mm_stat-w_17Sep2025-164220.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_outer_smth-2mm_stat-w_17Sep2025-164227.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_midthickness_smth-5mm_stat-w_17Sep2025-164235.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_inner_smth-5mm_stat-w_17Sep2025-164244.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_T1map_0p5mm_outer_smth-5mm_stat-w_17Sep2025-164251.png
# [MICs] - hippocampus: flair, 0p5mm, midthickness, 2mm
# [PNI] - hippocampus: flair, 0p5mm, midthickness, 2mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, inner, 2mm
# [PNI] - hippocampus: flair, 0p5mm, inner, 2mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, outer, 2mm
# [PNI] - hippocampus: flair, 0p5mm, outer, 2mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, midthickness, 5mm
# [PNI] - hippocampus: flair, 0p5mm, midthickness, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, inner, 5mm
# [PNI] - hippocampus: flair, 0p5mm, inner, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# [MICs] - hippocampus: flair, 0p5mm, outer, 5mm
# [PNI] - hippocampus: flair, 0p5mm, outer, 5mm
# 	WARNING. Missing key 'df_w'. Skipping None and None
#
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_midthickness_smth-2mm_stat-w_17Sep2025-164258.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_inner_smth-2mm_stat-w_17Sep2025-164306.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_outer_smth-2mm_stat-w_17Sep2025-164313.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_midthickness_smth-5mm_stat-w_17Sep2025-164320.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_inner_smth-5mm_stat-w_17Sep2025-164327.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_ADC_0p5mm_outer_smth-5mm_stat-w_17Sep2025-164334.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_midthickness_smth-2mm_stat-w_17Sep2025-164342.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_inner_smth-2mm_stat-w_17Sep2025-164349.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_outer_smth-2mm_stat-w_17Sep2025-164356.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_midthickness_smth-5mm_stat-w_17Sep2025-164403.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_inner_smth-5mm_stat-w_17Sep2025-164411.png
# 	Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/raw/hippocampus_FA_0p5mm_outer_smth-5mm_stat-w_17Sep2025-164418.png
# Creating 17 PDFs...
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/cortex_thickness_fsLR-5k_thickness_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_T1map_0p5mm_inner_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/cortex_T1map_fsLR-5k_white_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/cortex_FA_fsLR-5k_white_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_ADC_0p5mm_inner_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/cortex_FA_fsLR-5k_midthickness_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_thickness_0p5mm_thickness_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_ADC_0p5mm_outer_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/cortex_ADC_fsLR-5k_midthickness_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_FA_0p5mm_inner_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/cortex_T1map_fsLR-5k_midthickness_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_FA_0p5mm_midthickness_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/cortex_ADC_fsLR-5k_white_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_T1map_0p5mm_outer_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_T1map_0p5mm_midthickness_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_FA_0p5mm_outer_17Sep2025.pdf
# 	PDF created: /host/verges/tank/data/daniel/3T7T/z/outputs/figs/05a_winComp/hippocampus_ADC_0p5mm_midthickness_17Sep2025.pdf

# %% [markdown]
# # Select group of interest and ipsi/contra flip

# %%
# Create new dictionary list based on previous dl.
# New dl will have the same number of dictionary items (one for each study, ft, label, surf, smth, region combination).
#   Keys of each dictionary items may change. One df for each combination of [group[len(goi)] x lateralization[_R, _L, _ic] + 1 (ctrl)] x stat[<_z>, <_w>]] 
#   If df_{stat} is none, nothing regarding this statistic will be added to dict item.

importlib.reload(tsutil)

reimport = False
test = False
toPrint = False
goi = ["TLE"] # group(s) of interest. Store main diagnosis abrev in list to allow for multiple groups

# import
pth = "/host/verges/tank/data/daniel/3T7T/z/outputs/05a_stats_winStudy_17Sep2025-163602.pkl"
if 'dl_winComp' not in globals(): reimport = True
elif dl_winComp is None: reimport = True
if reimport: dl_winComp = tsutil.loadPickle(pth, dlPrint=toPrint)

dl_grp_ic = tsutil.grp_flip(dl = dl_winComp, demographics = demographics, 
                    goi = goi, col_grp = ses_specs['col_grp'],
                    save_pth = ses_specs['prjDir_root'] + ses_specs['prjDir_outs'], save_name = "05b_stats_winStudy_grp", test=test, verbose=verbose, dlPrint=True)
# Out:
# [grp_flip] Saving log to: /host/verges/tank/data/daniel/3T7T/z/outputs/05b_stats_winStudy_grp_log_18Sep2025-125307.txt
# ----------------------------------------------------------------------------------------------------
#
#  Dict list length (120 items)
#
# [0]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(56, 221)>
# 	df_maps: <DataFrame shape=(56, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0012_HC131_01', 'UID0013_HC013_01',
#        'UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01',
#        'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [1]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 5
# 	df_demo: <DataFrame shape=(56, 221)>
# 	df_maps: <DataFrame shape=(56, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0012_PNC029_a1', 'UID0013_PNC030_a1',
#        'UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1',
#        'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [2]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(56, 221)>
# 	df_maps: <DataFrame shape=(56, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0012_HC131_01', 'UID0013_HC013_01',
#        'UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01',
#        'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [3]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: thickness
# 	feature: thickness
# 	smth: 10
# 	df_demo: <DataFrame shape=(56, 221)>
# 	df_maps: <DataFrame shape=(56, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0012_PNC029_a1', 'UID0013_PNC030_a1',
#        'UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1',
#        'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [4]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0012_HC131_01', 'UID0013_HC013_01',
#        'UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01',
#        'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [5]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0012_PNC029_a1', 'UID0013_PNC030_a1',
#        'UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1',
#        'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [6]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [7]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [8]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0012_HC131_01', 'UID0013_HC013_01',
#        'UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01',
#        'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [9]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0012_PNC029_a1', 'UID0013_PNC030_a1',
#        'UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1',
#        'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [10]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [11]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: T1map
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [12]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0012_HC131_01', 'UID0013_HC013_01',
#        'UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01',
#        'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [13]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0012_PNC029_a1', 'UID0013_PNC030_a1',
#        'UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1',
#        'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [14]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [15]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [16]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0012_HC131_01', 'UID0013_HC013_01',
#        'UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01',
#        'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [17]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(53, 221)>
# 	df_maps: <DataFrame shape=(53, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0012_PNC029_a1', 'UID0013_PNC030_a1',
#        'UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1',
#        'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(17, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(17, 9684)>
#
# [18]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [19]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: T1map
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [20]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
# 	ctrl_IDs: Index(['UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01'], dtype='object', name='UID_ID_SES')
# 	df_z: None
# 	df_w: None
# 	df_w_models: None
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
#
# [21]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
# 	ctrl_IDs: Index(['UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1'], dtype='object', name='UID_ID_SES')
# 	df_z: None
# 	df_w: None
# 	df_w_models: None
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
#
# [22]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [23]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [24]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
# 	ctrl_IDs: Index(['UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01'], dtype='object', name='UID_ID_SES')
# 	df_z: None
# 	df_w: None
# 	df_w_models: None
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
#
# [25]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
# 	ctrl_IDs: Index(['UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1'], dtype='object', name='UID_ID_SES')
# 	df_z: None
# 	df_w: None
# 	df_w_models: None
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
#
# [26]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [27]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: flair
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [28]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
# 	ctrl_IDs: Index(['UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01'], dtype='object', name='UID_ID_SES')
# 	df_z: None
# 	df_w: None
# 	df_w_models: None
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
#
# [29]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
# 	ctrl_IDs: Index(['UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1'], dtype='object', name='UID_ID_SES')
# 	df_z: None
# 	df_w: None
# 	df_w_models: None
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
#
# [30]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [31]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [32]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
# 	ctrl_IDs: Index(['UID0015_HC116_01', 'UID0016_HC140_01', 'UID0017_HC152_01'], dtype='object', name='UID_ID_SES')
# 	df_z: None
# 	df_w: None
# 	df_w_models: None
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
#
# [33]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_z', 'df_w', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(36, 221)>
# 	df_maps: <DataFrame shape=(36, 9684)>
# 	ctrl_IDs: Index(['UID0015_PNC037_a1', 'UID0016_PNC038_a1', 'UID0017_PNC039_a1'], dtype='object', name='UID_ID_SES')
# 	df_z: None
# 	df_w: None
# 	df_w_models: None
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
#
# [34]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [35]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: flair
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [36]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [37]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [38]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [39]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [40]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [41]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [42]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [43]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: ADC
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [44]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [45]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [46]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [47]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [48]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [49]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: white
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [50]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [51]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: swm1.0mm
# 	feature: ADC
# 	smth: 10
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [52]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01', 'UID0062_PX192_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [53]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: cortex
# 	surf: fsLR-5k
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(50, 221)>
# 	df_maps: <DataFrame shape=(50, 9684)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 9684)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1', 'UID0062_PNE042_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_z_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_z_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_z_ctrl: <DataFrame shape=(15, 9684)>
# 	df_w_TLE_R: <DataFrame shape=(8, 9684)>
# 	df_w_TLE_L: <DataFrame shape=(9, 9684)>
# 	df_w_TLE_ic: <DataFrame shape=(17, 9684)>
# 	df_w_ctrl: <DataFrame shape=(15, 9684)>
#
# [54]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: MICs
# 	region: cortex
# 	surf: fsLR-5k
# 	label: pial
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(0, 221)>
# 	df_maps: <DataFrame shape=(0, 0)>
#
# [55]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps']
# 	study: PNI
# ...
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [110]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [111]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [112]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [113]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 2
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [114]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [115]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: midthickness
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [116]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [117]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: inner
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [118]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: MICs
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_HC082_01', 'UID0003_HC081_01', 'UID0004_HC135_01',
#        'UID0005_HC083_01', 'UID0006_HC076_01', 'UID0007_HC062_01',
#        'UID0008_HC132_01', 'UID0009_HC088_01', 'UID0010_HC128_01',
#        'UID0011_HC130_01', 'UID0015_HC116_01', 'UID0016_HC140_01',
#        'UID0017_HC152_01', 'UID0018_HC069_01', 'UID0019_HC052_01'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PX173_01', 'UID0032_PX148_01', 'UID0040_PX216_01', 'UID0043_PX224_01', 'UID0047_PX225_01', 'UID0048_PX050_01', 'UID0051_PX043_01', 'UID0058_PX144_01']
# 	TLE_IDs_L: ['UID0023_PX176_01', 'UID0028_PX153_01', 'UID0029_PX168_01', 'UID0031_PX189_01', 'UID0034_PX200_01', 'UID0036_PX174_01', 'UID0037_PX198_01', 'UID0038_PX204_01']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>
#
# [119]
# 	Keys: ['study', 'region', 'surf', 'label', 'feature', 'smth', 'df_demo', 'df_maps', 'ctrl_IDs', 'df_w_models', 'TLE_IDs_R', 'TLE_IDs_L', 'df_z_TLE_R', 'df_z_TLE_L', 'df_z_TLE_ic', 'df_z_ctrl', 'df_w_TLE_R', 'df_w_TLE_L', 'df_w_TLE_ic', 'df_w_ctrl']
# 	study: PNI
# 	region: hippocampus
# 	surf: 0p5mm
# 	label: outer
# 	feature: FA
# 	smth: 5
# 	df_demo: <DataFrame shape=(49, 221)>
# 	df_maps: <DataFrame shape=(49, 14524)>
# 	ctrl_IDs: Index(['UID0002_PNC003_01', 'UID0003_PNC006_01', 'UID0004_PNC009_01',
#        'UID0005_PNC011_01', 'UID0006_PNC018_01', 'UID0007_PNC019_01',
#        'UID0008_PNC022_01', 'UID0009_PNC024_01', 'UID0010_PNC025_01',
#        'UID0011_PNC026_01', 'UID0015_PNC037_a1', 'UID0016_PNC038_a1',
#        'UID0017_PNC039_a1', 'UID0018_PNC040_a1', 'UID0019_PNC041_a1'],
#       dtype='object', name='UID_ID_SES')
# 	df_w_models: <DataFrame shape=(4, 14524)>
# 	TLE_IDs_R: ['UID0025_PNE006_a1', 'UID0032_PNE013_a1', 'UID0040_PNE021_a1', 'UID0043_PNE024_a1', 'UID0047_PNE028_a1', 'UID0048_PNE029_a1', 'UID0051_PNE031_a1', 'UID0058_PNE038_a1']
# 	TLE_IDs_L: ['UID0023_PNE004_a1', 'UID0028_PNE009_a1', 'UID0029_PNE010_a1', 'UID0031_PNE012_a1', 'UID0034_PNE015_a1', 'UID0036_PNE017_a1', 'UID0037_PNE018_a1', 'UID0038_PNE019_a1']
# 	df_z_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_z_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_z_ctrl: <DataFrame shape=(15, 14524)>
# 	df_w_TLE_R: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_L: <DataFrame shape=(8, 14524)>
# 	df_w_TLE_ic: <DataFrame shape=(16, 14524)>
# 	df_w_ctrl: <DataFrame shape=(15, 14524)>

# %% [markdown]
# # Within study Cohen's D

# %%
importlib.reload(tsutil)

reimport = False
test = False
toPrint = False
save = True

stats = []
if ses_specs['z']: # statistics to compute d-scores for
    stats.append('z')
if ses_specs['w']:
    stats.append('w')

# import
pth = "/host/verges/tank/data/daniel/3T7T/z/outputs/05b_stats_winStudy_grp_18Sep2025-125541.pkl"
if 'dl_grp_ic' not in globals(): reimport = True
elif dl_grp_ic is None: reimport = True
if reimport: dl_grp_ic = tsutil.loadPickle(pth, dlPrint=toPrint)

winD = tsutil.winD(dl = dl_grp_ic, stats = stats, ipsiTo = ses_specs.get('ipsiTo', 'L'), 
                   save = save, save_pth = ses_specs['prjDir_root'] + ses_specs['prjDir_outs'], save_name = "05c_stats_winD",
                   verbose = verbose, test = test, dlPrint = toPrint)
# Out:
# [winD] Saving log to: /host/verges/tank/data/daniel/3T7T/z/outputs/05c_stats_winD_log_18Sep2025-154003.txt
# Start time: 2025-09-18 15:40:03
# Saved dictlist with groups and ipsi/contra statistics dfs to /host/verges/tank/data/daniel/3T7T/z/outputs/05c_stats_winD_2025Sep18-154003.pkl
#
# Completed. End time: 2025-09-18 16:01:08
# Duration: 21:4 (mm:ss)

# %%
# visualize matrices
importlib.reload(tsutil)
save_pth = "/host/verges/tank/data/daniel/3T7T/z/outputs/figs/05c_winD/raw"
tsutil.plotMatrices(dl = winD[83], key = 'df_d', show=False, save_pth=save_pth) # Visualize unsmoothed maps
tsutil.plotMatrices(dl = winD[83], key = 'df_d_ic', show=False, save_pth=save_pth) # Visualize unsmoothed maps
tsutil.pngs2pdf(fig_dir = save_pth, output = "/host/verges/tank/data/daniel/3T7T/z/outputs/figs/05c_winD", verbose = True)
# Out:
# Plotting matrices for df_d...
# 	WARNING. No matching index found for: [PNI] - hippocampus: T1map, 0p5mm, outer, 5mm (idx 0).
# Skipping.
# Plotting matrices for df_d_ic...
# 	WARNING. No matching index found for: [PNI] - hippocampus: T1map, 0p5mm, outer, 5mm (idx 0).
# Skipping.

# %% [markdown]
# # Between study: D-score differences
# - Identify pairs of dictionary items
# - Extract d scoring statitics and compute:
# - raw d dif
# - d dif / ctrl d

# %%
importlib.reload(tsutil)

reimport = False
test = False
toPrint = False
verbose = True

# import 
pth = "/host/verges/tank/data/daniel/3T7T/z/outputs/05c_stats_winD_2025Sep18-154003.pkl"
if 'winD' not in globals(): reimport = True
elif winD is None: reimport = True
if reimport: dl = tsutil.loadPickle(pth, dlPrint=toPrint)

comps = tsutil.btwD(dl = winD,
                    save = save, save_pth = ses_specs['prjDir_root'] + ses_specs['prjDir_outs'], save_name = "05d_stats_btwStudy",
                    verbose = verbose, test = test, dlPrint = toPrint)
# Out:
# [winD] Saving log to: /host/verges/tank/data/daniel/3T7T/z/outputs/05d_stats_btwStudy_log_18Sep2025-161131.txt
# Start time: 2025-09-18 16:11:31
# Saved dictlist with groups and ipsi/contra statistics dfs to /host/verges/tank/data/daniel/3T7T/z/outputs/05d_stats_btwStudy_18Sep2025-161131.pkl
#
# Completed btwD. End time: 2025-09-18 16:11:52
# Duration: 00:20 (mm:ss)

# %% [markdown]
# # Visualize
