# %%
import pandas as pd
import pickle
# Out:
#   Cell In[5], line 3
#     from 04_group_anal import print_dict
#            ^
# SyntaxError: invalid decimal literal

# %%
# support print functions
def print_dict(dict, df_print=False):
    """
    Print the contents of a dictionary with DataFrames in a readable format.
    Input:
        List of dict items.
        df_print: if True, prints DataFrame contents; if False, only print the shape of the DF keys

    Output:
        Prints the keys and values of each dictionary item.
    """
    import pandas as pd
    print(f"\n dict: ({len(dict)} items):")
    for i, d in enumerate(dict):
        print(f"\nItem {i}:")
        print(f"  Keys: {list(d.keys())}")

        for k, v in d.items():
            if isinstance(v, pd.DataFrame):
                print(f"  {k}: <DataFrame shape={v.shape}>")
                if df_print == True: print(f"  {k}: {v}")
            else:
                print(f" {k}: {v}")

# %%
# paths
rt = "/host/verges/tank/data/daniel/3T7T/z/outputs/results"
winStdy_pth = "comparisons_withinStudy_09Jun2025-1127.pkl"
btwStdy_pth = "comp_btwScanners_09Jun2025-1139.pkl"

# %%
# import within study comparisons (winStudy)
# import between study comparisons (btwStudy)
with open(f"{rt}/{winStdy_pth}", "rb") as f:
    winStdy = pickle.load(f)

with open(f"{rt}/{btwStdy_pth}", "rb") as f:
    btwStdy = pickle.load(f)

len(winStdy), len(btwStdy)
# Out:
# (198, 198)

# %%
# visualization functions

def showBrains(lh, rh, surface='fsLR-5k', ipsiTo=None, title=None, min=-2.5, max=2.5, inflated=False, save_name=None, save_pth=None, cmap="seismic"):
    """
    Returns brain figures

    inputs:
        lh: column with values for left hemisphere surface (each row represents a vertex and is properly indexed) 
        rh: column right hemisphere surface (each row represents a vertex and is properly indexed) 
        surface: surface type (default is 'fsLR-5k')
        inflated: whether to use inflated surfaces (default is False)
        title: title for the plot (default is None)
        save_name: name to save the figure (default is None)
        save_pth: path to save the figure (default is None)

    """    
    
    import os
    import glob
    import numpy as np
    import nibabel as nib
    import seaborn as sns
    from brainspace.plotting import plot_hemispheres
    from brainspace.mesh.mesh_io import read_surface
    from brainspace.datasets import load_conte69
    import datetime

    micapipe=os.popen("echo $MICAPIPE").read()[:-1]
    
    # set wd to save_pth
    if save_pth is not None:
        if not os.path.exists(save_pth):
            os.makedirs(save_pth)
        os.chdir(save_pth)

    if surface == 'fsLR-5k':
        if inflated == True:
            # Load fsLR 5k inflated
            surf_lh = read_surface(micapipe + '/surfaces/fsLR-5k.L.inflated.surf.gii', itype='gii')
            surf_rh = read_surface(micapipe + '/surfaces/fsLR-5k.R.inflated.surf.gii', itype='gii')
        else:
            # Load Load fsLR 5k
            surf_lh = read_surface(micapipe + '/surfaces/fsLR-5k.L.surf.gii', itype='gii')
            surf_rh = read_surface(micapipe + '/surfaces/fsLR-5k.R.surf.gii', itype='gii')
    elif surface == 'fsLR-32k':
        if inflated == True:
            # Load fsLR 32k inflated
            surf_lh = read_surface(micapipe + '/surfaces/fsLR-32k.L.inflated.surf.gii', itype='gii')
            surf_rh = read_surface(micapipe + '/surfaces/fsLR-32k.R.inflated.surf.gii', itype='gii')
        else:
            # Load fsLR 32k
            surf_lh = read_surface(micapipe + '/surfaces/fsLR-32k.L.surf.gii', itype='gii')
            surf_rh = read_surface(micapipe + '/surfaces/fsLR-32k.R.surf.gii', itype='gii')
    else:
        raise ValueError(f"Surface {surface} not recognized. Use 'fsLR-5k' or 'fsLR-32k'.")

    
    data = np.hstack(np.concatenate([lh, rh], axis=0))


    lbl_text = {'top': title}
    
    if ipsiTo is not None and ipsiTo == "L":
        lbl_text = {
            'left': 'ipsi',
            'right': 'contra'
        }    
    elif ipsiTo is not None and ipsiTo == "R":
        lbl_text = {
            'left': 'contra',
            'right': 'ipsi'
        }
    else:
        lbl_text = {
            'left': 'L',
            'right': 'R'
        }

    # Ensure all values are strings (robust against accidental lists/arrays)
    lbl_text = {k: str(v) for k, v in lbl_text.items()}

    date = datetime.datetime.now().strftime("%d%b%Y-%H%M")
    filename = f"{save_name}_{surface}_{date}.png" if save_name and save_pth else None
    
    # Plot the surface with a title
    if filename : 
        print(f"[showBrains] Plot saved to {filename}")
        return plot_hemispheres(
                surf_lh, surf_rh, array_name=data, 
                size=(900, 250), color_bar='bottom', zoom=1.25, embed_nb=True, interactive=False, share='both',
                nan_color=(0, 0, 0, 1), color_range=(min,max), cmap=cmap, transparent_bg=False, 
                screenshot=True, filename=filename,
                #, label_text = lbl_text
            )
    else:
        return plot_hemispheres(
                surf_lh, surf_rh, array_name=data, 
                size=(900, 250), color_bar='bottom', zoom=1.25, embed_nb=True, interactive=False, share='both',
                nan_color=(0, 0, 0, 1), color_range=(min,max), cmap=cmap, transparent_bg=False, 
                #, label_text = lbl_text
            )

# %%
# for each group, create a column of figures
# top: 7T brains, bottom 3T brains, last comparison
def fig_2():
    """
    input:
        dict1: dictionary item for first plot
        dict2: dictionary item for second plot
        dict3: dictionary item for third plot
        Each dict item must contain 
    output:
        Figure with 3 subplots, each showing a brain surface with values from the respective dictionary item.
    """
    
    showbrains()

# %%
print_dict(winStdy, df_print=False)
# Out:
#  dict: (198 items):
#
# Item 0:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-5k_white_L', 'map_map_FA_fsLR-5k_white_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_fsLR-5k_white_L', 'stats_stats_FA_fsLR-5k_white_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: white
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_FA_fsLR-5k_white_L: <DataFrame shape=(4842, 19)>
#   map_map_FA_fsLR-5k_white_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 19
#   stats_stats_FA_fsLR-5k_white_L: <DataFrame shape=(4842, 4)>
#   stats_stats_FA_fsLR-5k_white_R: <DataFrame shape=(4842, 4)>
#
# Item 1:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-5k_white_L', 'map_map_ADC_fsLR-5k_white_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_fsLR-5k_white_L', 'stats_stats_ADC_fsLR-5k_white_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: white
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_ADC_fsLR-5k_white_L: <DataFrame shape=(4842, 19)>
#   map_map_ADC_fsLR-5k_white_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 19
#   stats_stats_ADC_fsLR-5k_white_L: <DataFrame shape=(4842, 4)>
#   stats_stats_ADC_fsLR-5k_white_R: <DataFrame shape=(4842, 4)>
#
# Item 2:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-5k_white_L', 'map_map_T1map_fsLR-5k_white_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_fsLR-5k_white_L', 'stats_stats_T1stats_fsLR-5k_white_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: white
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-5k_white_L: <DataFrame shape=(4842, 19)>
#   map_map_T1map_fsLR-5k_white_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 19
#   stats_stats_T1stats_fsLR-5k_white_L: <DataFrame shape=(4842, 4)>
#   stats_stats_T1stats_fsLR-5k_white_R: <DataFrame shape=(4842, 4)>
#
# Item 3:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-5k_midthickness_L', 'map_map_FA_fsLR-5k_midthickness_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_fsLR-5k_midthickness_L', 'stats_stats_FA_fsLR-5k_midthickness_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: midthickness
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_FA_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 19)>
#   map_map_FA_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 19
#   stats_stats_FA_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 4)>
#   stats_stats_FA_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 4)>
#
# Item 4:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-5k_midthickness_L', 'map_map_ADC_fsLR-5k_midthickness_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_fsLR-5k_midthickness_L', 'stats_stats_ADC_fsLR-5k_midthickness_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: midthickness
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_ADC_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 19)>
#   map_map_ADC_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 19
#   stats_stats_ADC_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 4)>
#   stats_stats_ADC_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 4)>
#
# Item 5:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-5k_midthickness_L', 'map_map_T1map_fsLR-5k_midthickness_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_fsLR-5k_midthickness_L', 'stats_stats_T1stats_fsLR-5k_midthickness_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: midthickness
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 19)>
#   map_map_T1map_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 19
#   stats_stats_T1stats_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 4)>
#   stats_stats_T1stats_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 4)>
#
# Item 6:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-5k_pial_L', 'map_map_FA_fsLR-5k_pial_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_fsLR-5k_pial_L', 'stats_stats_FA_fsLR-5k_pial_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: pial
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_FA_fsLR-5k_pial_L: <DataFrame shape=(4842, 19)>
#   map_map_FA_fsLR-5k_pial_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 19
#   stats_stats_FA_fsLR-5k_pial_L: <DataFrame shape=(4842, 4)>
#   stats_stats_FA_fsLR-5k_pial_R: <DataFrame shape=(4842, 4)>
#
# Item 7:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-5k_pial_L', 'map_map_ADC_fsLR-5k_pial_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_fsLR-5k_pial_L', 'stats_stats_ADC_fsLR-5k_pial_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: pial
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_ADC_fsLR-5k_pial_L: <DataFrame shape=(4842, 19)>
#   map_map_ADC_fsLR-5k_pial_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 19
#   stats_stats_ADC_fsLR-5k_pial_L: <DataFrame shape=(4842, 4)>
#   stats_stats_ADC_fsLR-5k_pial_R: <DataFrame shape=(4842, 4)>
#
# Item 8:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-5k_pial_L', 'map_map_T1map_fsLR-5k_pial_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_fsLR-5k_pial_L', 'stats_stats_T1stats_fsLR-5k_pial_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: pial
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-5k_pial_L: <DataFrame shape=(4842, 19)>
#   map_map_T1map_fsLR-5k_pial_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 19
#   stats_stats_T1stats_fsLR-5k_pial_L: <DataFrame shape=(4842, 4)>
#   stats_stats_T1stats_fsLR-5k_pial_R: <DataFrame shape=(4842, 4)>
#
# Item 9:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-32k_white_L', 'map_map_FA_fsLR-32k_white_R', 'ipsiTo']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: white
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_FA_fsLR-32k_white_L: <DataFrame shape=(32492, 19)>
#   map_map_FA_fsLR-32k_white_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 10:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-32k_white_L', 'map_map_ADC_fsLR-32k_white_R', 'ipsiTo']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: white
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_ADC_fsLR-32k_white_L: <DataFrame shape=(32492, 19)>
#   map_map_ADC_fsLR-32k_white_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 11:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-32k_white_L', 'map_map_T1map_fsLR-32k_white_R', 'ipsiTo']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: white
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-32k_white_L: <DataFrame shape=(32492, 19)>
#   map_map_T1map_fsLR-32k_white_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 12:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-32k_midthickness_L', 'map_map_FA_fsLR-32k_midthickness_R', 'ipsiTo']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: midthickness
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_FA_fsLR-32k_midthickness_L: <DataFrame shape=(32492, 19)>
#   map_map_FA_fsLR-32k_midthickness_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 13:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-32k_midthickness_L', 'map_map_ADC_fsLR-32k_midthickness_R', 'ipsiTo']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: midthickness
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_ADC_fsLR-32k_midthickness_L: <DataFrame shape=(32492, 19)>
#   map_map_ADC_fsLR-32k_midthickness_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 14:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-32k_midthickness_L', 'map_map_T1map_fsLR-32k_midthickness_R', 'ipsiTo']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: midthickness
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-32k_midthickness_L: <DataFrame shape=(32492, 19)>
#   map_map_T1map_fsLR-32k_midthickness_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 15:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-32k_pial_L', 'map_map_FA_fsLR-32k_pial_R', 'ipsiTo']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: pial
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_FA_fsLR-32k_pial_L: <DataFrame shape=(32492, 19)>
#   map_map_FA_fsLR-32k_pial_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 16:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-32k_pial_L', 'map_map_ADC_fsLR-32k_pial_R', 'ipsiTo']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: pial
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_ADC_fsLR-32k_pial_L: <DataFrame shape=(32492, 19)>
#   map_map_ADC_fsLR-32k_pial_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 17:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-32k_pial_L', 'map_map_T1map_fsLR-32k_pial_R', 'ipsiTo']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: pial
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-32k_pial_L: <DataFrame shape=(32492, 19)>
#   map_map_T1map_fsLR-32k_pial_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 18:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_0p5mm_outer_hipp_L', 'map_map_FA_0p5mm_outer_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_0p5mm_outer_hipp_L', 'stats_stats_FA_0p5mm_outer_hipp_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_FA_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 18)>
#   map_map_FA_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 18)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 18
#   stats_stats_FA_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_FA_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 19:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_0p5mm_outer_hipp_L', 'map_map_ADC_0p5mm_outer_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_0p5mm_outer_hipp_L', 'stats_stats_ADC_0p5mm_outer_hipp_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_ADC_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 18)>
#   map_map_ADC_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 18)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 18
#   stats_stats_ADC_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_ADC_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 20:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_0p5mm_outer_hipp_L', 'map_map_T1map_0p5mm_outer_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_0p5mm_outer_hipp_L', 'stats_stats_T1stats_0p5mm_outer_hipp_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 18)>
#   map_map_T1map_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 18)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 18
#   stats_stats_T1stats_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_T1stats_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 21:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_0p5mm_inner_hipp_L', 'map_map_FA_0p5mm_inner_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_0p5mm_inner_hipp_L', 'stats_stats_FA_0p5mm_inner_hipp_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_FA_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 18)>
#   map_map_FA_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 18)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 18
#   stats_stats_FA_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_FA_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 22:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_0p5mm_inner_hipp_L', 'map_map_ADC_0p5mm_inner_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_0p5mm_inner_hipp_L', 'stats_stats_ADC_0p5mm_inner_hipp_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_ADC_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 18)>
#   map_map_ADC_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 18)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 18
#   stats_stats_ADC_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_ADC_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 23:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_0p5mm_inner_hipp_L', 'map_map_T1map_0p5mm_inner_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_0p5mm_inner_hipp_L', 'stats_stats_T1stats_0p5mm_inner_hipp_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 18)>
#   map_map_T1map_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 18)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 18
#   stats_stats_T1stats_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_T1stats_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 24:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_0p5mm_midthickness_hipp_L', 'map_map_FA_0p5mm_midthickness_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_0p5mm_midthickness_hipp_L', 'stats_stats_FA_0p5mm_midthickness_hipp_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_FA_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 18)>
#   map_map_FA_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 18)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 18
#   stats_stats_FA_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_FA_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 25:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_0p5mm_midthickness_hipp_L', 'map_map_ADC_0p5mm_midthickness_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_0p5mm_midthickness_hipp_L', 'stats_stats_ADC_0p5mm_midthickness_hipp_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_ADC_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 18)>
#   map_map_ADC_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 18)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 18
#   stats_stats_ADC_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_ADC_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 26:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_0p5mm_midthickness_hipp_L', 'map_map_T1map_0p5mm_midthickness_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_0p5mm_midthickness_hipp_L', 'stats_stats_T1stats_0p5mm_midthickness_hipp_R']
#  study: MICs
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 18)>
#   map_map_T1map_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 18)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 18
#   stats_stats_T1stats_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_T1stats_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 27:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-5k_white_L', 'map_map_FA_fsLR-5k_white_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_fsLR-5k_white_L', 'stats_stats_FA_fsLR-5k_white_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: white
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_FA_fsLR-5k_white_L: <DataFrame shape=(4842, 11)>
#   map_map_FA_fsLR-5k_white_R: <DataFrame shape=(4842, 11)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 11
#   stats_stats_FA_fsLR-5k_white_L: <DataFrame shape=(4842, 4)>
#   stats_stats_FA_fsLR-5k_white_R: <DataFrame shape=(4842, 4)>
#
# Item 28:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-5k_white_L', 'map_map_ADC_fsLR-5k_white_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_fsLR-5k_white_L', 'stats_stats_ADC_fsLR-5k_white_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: white
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_ADC_fsLR-5k_white_L: <DataFrame shape=(4842, 11)>
#   map_map_ADC_fsLR-5k_white_R: <DataFrame shape=(4842, 11)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 11
#   stats_stats_ADC_fsLR-5k_white_L: <DataFrame shape=(4842, 4)>
#   stats_stats_ADC_fsLR-5k_white_R: <DataFrame shape=(4842, 4)>
#
# Item 29:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-5k_white_L', 'map_map_T1map_fsLR-5k_white_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_fsLR-5k_white_L', 'stats_stats_T1stats_fsLR-5k_white_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: white
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-5k_white_L: <DataFrame shape=(4842, 19)>
#   map_map_T1map_fsLR-5k_white_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 12
#  n_comp: 19
#   stats_stats_T1stats_fsLR-5k_white_L: <DataFrame shape=(4842, 4)>
#   stats_stats_T1stats_fsLR-5k_white_R: <DataFrame shape=(4842, 4)>
#
# Item 30:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-5k_midthickness_L', 'map_map_FA_fsLR-5k_midthickness_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_fsLR-5k_midthickness_L', 'stats_stats_FA_fsLR-5k_midthickness_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: midthickness
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_FA_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 11)>
#   map_map_FA_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 11)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 11
#   stats_stats_FA_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 4)>
#   stats_stats_FA_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 4)>
#
# Item 31:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-5k_midthickness_L', 'map_map_ADC_fsLR-5k_midthickness_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_fsLR-5k_midthickness_L', 'stats_stats_ADC_fsLR-5k_midthickness_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: midthickness
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_ADC_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 11)>
#   map_map_ADC_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 11)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 11
#   stats_stats_ADC_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 4)>
#   stats_stats_ADC_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 4)>
#
# Item 32:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-5k_midthickness_L', 'map_map_T1map_fsLR-5k_midthickness_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_fsLR-5k_midthickness_L', 'stats_stats_T1stats_fsLR-5k_midthickness_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: midthickness
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 19)>
#   map_map_T1map_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 12
#  n_comp: 19
#   stats_stats_T1stats_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 4)>
#   stats_stats_T1stats_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 4)>
#
# Item 33:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-5k_pial_L', 'map_map_FA_fsLR-5k_pial_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_fsLR-5k_pial_L', 'stats_stats_FA_fsLR-5k_pial_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: pial
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_FA_fsLR-5k_pial_L: <DataFrame shape=(4842, 11)>
#   map_map_FA_fsLR-5k_pial_R: <DataFrame shape=(4842, 11)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 11
#   stats_stats_FA_fsLR-5k_pial_L: <DataFrame shape=(4842, 4)>
#   stats_stats_FA_fsLR-5k_pial_R: <DataFrame shape=(4842, 4)>
#
# Item 34:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-5k_pial_L', 'map_map_ADC_fsLR-5k_pial_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_fsLR-5k_pial_L', 'stats_stats_ADC_fsLR-5k_pial_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: pial
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_ADC_fsLR-5k_pial_L: <DataFrame shape=(4842, 11)>
#   map_map_ADC_fsLR-5k_pial_R: <DataFrame shape=(4842, 11)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 11
#   stats_stats_ADC_fsLR-5k_pial_L: <DataFrame shape=(4842, 4)>
#   stats_stats_ADC_fsLR-5k_pial_R: <DataFrame shape=(4842, 4)>
#
# Item 35:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-5k_pial_L', 'map_map_T1map_fsLR-5k_pial_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_fsLR-5k_pial_L', 'stats_stats_T1stats_fsLR-5k_pial_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: pial
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-5k_pial_L: <DataFrame shape=(4842, 19)>
#   map_map_T1map_fsLR-5k_pial_R: <DataFrame shape=(4842, 19)>
#  ipsiTo: L
#  n_ctrl: 12
#  n_comp: 19
#   stats_stats_T1stats_fsLR-5k_pial_L: <DataFrame shape=(4842, 4)>
#   stats_stats_T1stats_fsLR-5k_pial_R: <DataFrame shape=(4842, 4)>
#
# Item 36:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-32k_white_L', 'map_map_FA_fsLR-32k_white_R', 'ipsiTo']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: white
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_FA_fsLR-32k_white_L: <DataFrame shape=(32492, 11)>
#   map_map_FA_fsLR-32k_white_R: <DataFrame shape=(32492, 11)>
#  ipsiTo: L
#
# Item 37:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-32k_white_L', 'map_map_ADC_fsLR-32k_white_R', 'ipsiTo']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: white
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_ADC_fsLR-32k_white_L: <DataFrame shape=(32492, 11)>
#   map_map_ADC_fsLR-32k_white_R: <DataFrame shape=(32492, 11)>
#  ipsiTo: L
#
# Item 38:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-32k_white_L', 'map_map_T1map_fsLR-32k_white_R', 'ipsiTo']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: white
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-32k_white_L: <DataFrame shape=(32492, 19)>
#   map_map_T1map_fsLR-32k_white_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 39:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-32k_midthickness_L', 'map_map_FA_fsLR-32k_midthickness_R', 'ipsiTo']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: midthickness
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_FA_fsLR-32k_midthickness_L: <DataFrame shape=(32492, 11)>
#   map_map_FA_fsLR-32k_midthickness_R: <DataFrame shape=(32492, 11)>
#  ipsiTo: L
#
# Item 40:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-32k_midthickness_L', 'map_map_ADC_fsLR-32k_midthickness_R', 'ipsiTo']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: midthickness
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_ADC_fsLR-32k_midthickness_L: <DataFrame shape=(32492, 11)>
#   map_map_ADC_fsLR-32k_midthickness_R: <DataFrame shape=(32492, 11)>
#  ipsiTo: L
#
# Item 41:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-32k_midthickness_L', 'map_map_T1map_fsLR-32k_midthickness_R', 'ipsiTo']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: midthickness
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-32k_midthickness_L: <DataFrame shape=(32492, 19)>
#   map_map_T1map_fsLR-32k_midthickness_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 42:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-32k_pial_L', 'map_map_FA_fsLR-32k_pial_R', 'ipsiTo']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: pial
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_FA_fsLR-32k_pial_L: <DataFrame shape=(32492, 11)>
#   map_map_FA_fsLR-32k_pial_R: <DataFrame shape=(32492, 11)>
#  ipsiTo: L
#
# Item 43:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-32k_pial_L', 'map_map_ADC_fsLR-32k_pial_R', 'ipsiTo']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: pial
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(11, 6)>
#   map_map_ADC_fsLR-32k_pial_L: <DataFrame shape=(32492, 11)>
#   map_map_ADC_fsLR-32k_pial_R: <DataFrame shape=(32492, 11)>
#  ipsiTo: L
#
# Item 44:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-32k_pial_L', 'map_map_T1map_fsLR-32k_pial_R', 'ipsiTo']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: pial
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(19, 6)>
#   map_map_T1map_fsLR-32k_pial_L: <DataFrame shape=(32492, 19)>
#   map_map_T1map_fsLR-32k_pial_R: <DataFrame shape=(32492, 19)>
#  ipsiTo: L
#
# Item 45:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_0p5mm_outer_hipp_L', 'map_map_FA_0p5mm_outer_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_0p5mm_outer_hipp_L', 'stats_stats_FA_0p5mm_outer_hipp_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(9, 6)>
#   map_map_FA_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 9)>
#   map_map_FA_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 9)>
#  ipsiTo: L
#  n_ctrl: 8
#  n_comp: 9
#   stats_stats_FA_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_FA_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 46:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_0p5mm_outer_hipp_L', 'map_map_ADC_0p5mm_outer_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_0p5mm_outer_hipp_L', 'stats_stats_ADC_0p5mm_outer_hipp_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(9, 6)>
#   map_map_ADC_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 9)>
#   map_map_ADC_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 9)>
#  ipsiTo: L
#  n_ctrl: 8
#  n_comp: 9
#   stats_stats_ADC_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_ADC_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 47:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_0p5mm_outer_hipp_L', 'map_map_T1map_0p5mm_outer_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_0p5mm_outer_hipp_L', 'stats_stats_T1stats_0p5mm_outer_hipp_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(15, 6)>
#   map_map_T1map_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 15)>
#   map_map_T1map_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 15)>
#  ipsiTo: L
#  n_ctrl: 9
#  n_comp: 15
#   stats_stats_T1stats_0p5mm_outer_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_T1stats_0p5mm_outer_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 48:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_0p5mm_inner_hipp_L', 'map_map_FA_0p5mm_inner_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_0p5mm_inner_hipp_L', 'stats_stats_FA_0p5mm_inner_hipp_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(9, 6)>
#   map_map_FA_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 9)>
#   map_map_FA_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 9)>
#  ipsiTo: L
#  n_ctrl: 8
#  n_comp: 9
#   stats_stats_FA_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_FA_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 49:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_0p5mm_inner_hipp_L', 'map_map_ADC_0p5mm_inner_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_0p5mm_inner_hipp_L', 'stats_stats_ADC_0p5mm_inner_hipp_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(9, 6)>
#   map_map_ADC_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 9)>
#   map_map_ADC_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 9)>
#  ipsiTo: L
#  n_ctrl: 8
#  n_comp: 9
#   stats_stats_ADC_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_ADC_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 50:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_0p5mm_inner_hipp_L', 'map_map_T1map_0p5mm_inner_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_0p5mm_inner_hipp_L', 'stats_stats_T1stats_0p5mm_inner_hipp_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(15, 6)>
#   map_map_T1map_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 15)>
#   map_map_T1map_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 15)>
#  ipsiTo: L
#  n_ctrl: 9
#  n_comp: 15
#   stats_stats_T1stats_0p5mm_inner_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_T1stats_0p5mm_inner_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 51:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_0p5mm_midthickness_hipp_L', 'map_map_FA_0p5mm_midthickness_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_0p5mm_midthickness_hipp_L', 'stats_stats_FA_0p5mm_midthickness_hipp_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(9, 6)>
#   map_map_FA_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 9)>
#   map_map_FA_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 9)>
#  ipsiTo: L
#  n_ctrl: 8
#  n_comp: 9
#   stats_stats_FA_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_FA_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 52:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_0p5mm_midthickness_hipp_L', 'map_map_ADC_0p5mm_midthickness_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_0p5mm_midthickness_hipp_L', 'stats_stats_ADC_0p5mm_midthickness_hipp_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(9, 6)>
#   map_map_ADC_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 9)>
#   map_map_ADC_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 9)>
#  ipsiTo: L
#  n_ctrl: 8
#  n_comp: 9
#   stats_stats_ADC_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_ADC_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 53:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_0p5mm_midthickness_hipp_L', 'map_map_T1map_0p5mm_midthickness_hipp_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_0p5mm_midthickness_hipp_L', 'stats_stats_T1stats_0p5mm_midthickness_hipp_R']
#  study: PNI
#  grp: allPX
#  grp_labels: ['TLE_U', 'MFCL', 'FLE_R', 'MFCL_bTLE', 'UKN_L', 'mTLE_R', 'mTLE_L', 'FLE_L', 'UKN_U', 'TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(15, 6)>
#   map_map_T1map_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 15)>
#   map_map_T1map_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 15)>
#  ipsiTo: L
#  n_ctrl: 9
#  n_comp: 15
#   stats_stats_T1stats_0p5mm_midthickness_hipp_L: <DataFrame shape=(7262, 4)>
#   stats_stats_T1stats_0p5mm_midthickness_hipp_R: <DataFrame shape=(7262, 4)>
#
# Item 54:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-5k_white_L', 'map_map_FA_fsLR-5k_white_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_fsLR-5k_white_L', 'stats_stats_FA_fsLR-5k_white_R']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-5k
#  label: white
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_FA_fsLR-5k_white_L: <DataFrame shape=(4842, 5)>
#   map_map_FA_fsLR-5k_white_R: <DataFrame shape=(4842, 5)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 5
#   stats_stats_FA_fsLR-5k_white_L: <DataFrame shape=(4842, 4)>
#   stats_stats_FA_fsLR-5k_white_R: <DataFrame shape=(4842, 4)>
#
# Item 55:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-5k_white_L', 'map_map_ADC_fsLR-5k_white_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_fsLR-5k_white_L', 'stats_stats_ADC_fsLR-5k_white_R']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-5k
#  label: white
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_ADC_fsLR-5k_white_L: <DataFrame shape=(4842, 5)>
#   map_map_ADC_fsLR-5k_white_R: <DataFrame shape=(4842, 5)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 5
#   stats_stats_ADC_fsLR-5k_white_L: <DataFrame shape=(4842, 4)>
#   stats_stats_ADC_fsLR-5k_white_R: <DataFrame shape=(4842, 4)>
#
# Item 56:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-5k_white_L', 'map_map_T1map_fsLR-5k_white_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_fsLR-5k_white_L', 'stats_stats_T1stats_fsLR-5k_white_R']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-5k
#  label: white
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_T1map_fsLR-5k_white_L: <DataFrame shape=(4842, 5)>
#   map_map_T1map_fsLR-5k_white_R: <DataFrame shape=(4842, 5)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 5
#   stats_stats_T1stats_fsLR-5k_white_L: <DataFrame shape=(4842, 4)>
#   stats_stats_T1stats_fsLR-5k_white_R: <DataFrame shape=(4842, 4)>
#
# Item 57:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-5k_midthickness_L', 'map_map_FA_fsLR-5k_midthickness_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_fsLR-5k_midthickness_L', 'stats_stats_FA_fsLR-5k_midthickness_R']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-5k
#  label: midthickness
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_FA_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 5)>
#   map_map_FA_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 5)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 5
#   stats_stats_FA_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 4)>
#   stats_stats_FA_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 4)>
#
# Item 58:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-5k_midthickness_L', 'map_map_ADC_fsLR-5k_midthickness_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_fsLR-5k_midthickness_L', 'stats_stats_ADC_fsLR-5k_midthickness_R']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-5k
#  label: midthickness
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_ADC_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 5)>
#   map_map_ADC_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 5)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 5
#   stats_stats_ADC_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 4)>
#   stats_stats_ADC_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 4)>
#
# Item 59:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-5k_midthickness_L', 'map_map_T1map_fsLR-5k_midthickness_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_fsLR-5k_midthickness_L', 'stats_stats_T1stats_fsLR-5k_midthickness_R']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-5k
#  label: midthickness
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_T1map_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 5)>
#   map_map_T1map_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 5)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 5
#   stats_stats_T1stats_fsLR-5k_midthickness_L: <DataFrame shape=(4842, 4)>
#   stats_stats_T1stats_fsLR-5k_midthickness_R: <DataFrame shape=(4842, 4)>
#
# Item 60:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-5k_pial_L', 'map_map_FA_fsLR-5k_pial_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_FA_fsLR-5k_pial_L', 'stats_stats_FA_fsLR-5k_pial_R']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-5k
#  label: pial
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_FA_fsLR-5k_pial_L: <DataFrame shape=(4842, 5)>
#   map_map_FA_fsLR-5k_pial_R: <DataFrame shape=(4842, 5)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 5
#   stats_stats_FA_fsLR-5k_pial_L: <DataFrame shape=(4842, 4)>
#   stats_stats_FA_fsLR-5k_pial_R: <DataFrame shape=(4842, 4)>
#
# Item 61:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-5k_pial_L', 'map_map_ADC_fsLR-5k_pial_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_ADC_fsLR-5k_pial_L', 'stats_stats_ADC_fsLR-5k_pial_R']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-5k
#  label: pial
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_ADC_fsLR-5k_pial_L: <DataFrame shape=(4842, 5)>
#   map_map_ADC_fsLR-5k_pial_R: <DataFrame shape=(4842, 5)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 5
#   stats_stats_ADC_fsLR-5k_pial_L: <DataFrame shape=(4842, 4)>
#   stats_stats_ADC_fsLR-5k_pial_R: <DataFrame shape=(4842, 4)>
#
# Item 62:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_T1map_fsLR-5k_pial_L', 'map_map_T1map_fsLR-5k_pial_R', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_stats_T1stats_fsLR-5k_pial_L', 'stats_stats_T1stats_fsLR-5k_pial_R']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-5k
#  label: pial
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_T1map_fsLR-5k_pial_L: <DataFrame shape=(4842, 5)>
#   map_map_T1map_fsLR-5k_pial_R: <DataFrame shape=(4842, 5)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 5
#   stats_stats_T1stats_fsLR-5k_pial_L: <DataFrame shape=(4842, 4)>
#   stats_stats_T1stats_fsLR-5k_pial_R: <DataFrame shape=(4842, 4)>
#
# Item 63:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_FA_fsLR-32k_white_L', 'map_map_FA_fsLR-32k_white_R', 'ipsiTo']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-32k
#  label: white
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_FA_fsLR-32k_white_L: <DataFrame shape=(32492, 5)>
#   map_map_FA_fsLR-32k_white_R: <DataFrame shape=(32492, 5)>
#  ipsiTo: L
#
# Item 64:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_map_ADC_fsLR-32k_white_L', 'map_map_ADC_fsLR-32k_white_R', 'ipsiTo']
#  study: MICs
#  grp: TLE_L
#  grp_labels: ['TLE_L', 'mTLE_L']
#  surface: fsLR-32k
#  label: white
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(5, 6)>
#   map_map_ADC_fsLR-32k_white_L: <DataFrame shape=(32492, 5)>
#   map_map_ADC_fsLR-32k_white_R: <DataFrame shape=(32492, 5)>
#  ipsiTo: L
#
# Item 65:
# ...
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: pial
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(32492, 7)>
#   map_contra: <DataFrame shape=(32492, 7)>
#  ipsiTo: L
#
# Item 162:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(7262, 7)>
#   map_contra: <DataFrame shape=(7262, 7)>
#  ipsiTo: L
#
# Item 163:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(7262, 7)>
#   map_contra: <DataFrame shape=(7262, 7)>
#  ipsiTo: L
#
# Item 164:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(7262, 7)>
#   map_contra: <DataFrame shape=(7262, 7)>
#  ipsiTo: L
#
# Item 165:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(7262, 7)>
#   map_contra: <DataFrame shape=(7262, 7)>
#  ipsiTo: L
#
# Item 166:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(7262, 7)>
#   map_contra: <DataFrame shape=(7262, 7)>
#  ipsiTo: L
#
# Item 167:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(7262, 7)>
#   map_contra: <DataFrame shape=(7262, 7)>
#  ipsiTo: L
#
# Item 168:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(7262, 7)>
#   map_contra: <DataFrame shape=(7262, 7)>
#  ipsiTo: L
#
# Item 169:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(7262, 7)>
#   map_contra: <DataFrame shape=(7262, 7)>
#  ipsiTo: L
#
# Item 170:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(7262, 7)>
#   map_contra: <DataFrame shape=(7262, 7)>
#  ipsiTo: L
#
# Item 171:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-5k
#  label: white
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(4842, 4)>
#   map_contra: <DataFrame shape=(4842, 4)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 4
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 172:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-5k
#  label: white
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(4842, 4)>
#   map_contra: <DataFrame shape=(4842, 4)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 4
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 173:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: white
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(8, 7)>
#   map_ipsi: <DataFrame shape=(4842, 8)>
#   map_contra: <DataFrame shape=(4842, 8)>
#  ipsiTo: L
#  n_ctrl: 12
#  n_comp: 8
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 174:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-5k
#  label: midthickness
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(4842, 4)>
#   map_contra: <DataFrame shape=(4842, 4)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 4
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 175:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-5k
#  label: midthickness
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(4842, 4)>
#   map_contra: <DataFrame shape=(4842, 4)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 4
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 176:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: midthickness
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(8, 7)>
#   map_ipsi: <DataFrame shape=(4842, 8)>
#   map_contra: <DataFrame shape=(4842, 8)>
#  ipsiTo: L
#  n_ctrl: 12
#  n_comp: 8
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 177:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-5k
#  label: pial
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(4842, 4)>
#   map_contra: <DataFrame shape=(4842, 4)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 4
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 178:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-5k
#  label: pial
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(4842, 4)>
#   map_contra: <DataFrame shape=(4842, 4)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 4
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 179:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: pial
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(8, 7)>
#   map_ipsi: <DataFrame shape=(4842, 8)>
#   map_contra: <DataFrame shape=(4842, 8)>
#  ipsiTo: L
#  n_ctrl: 12
#  n_comp: 8
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 180:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-32k
#  label: white
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(32492, 4)>
#   map_contra: <DataFrame shape=(32492, 4)>
#  ipsiTo: L
#
# Item 181:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-32k
#  label: white
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(32492, 4)>
#   map_contra: <DataFrame shape=(32492, 4)>
#  ipsiTo: L
#
# Item 182:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: white
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(8, 7)>
#   map_ipsi: <DataFrame shape=(32492, 8)>
#   map_contra: <DataFrame shape=(32492, 8)>
#  ipsiTo: L
#
# Item 183:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-32k
#  label: midthickness
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(32492, 4)>
#   map_contra: <DataFrame shape=(32492, 4)>
#  ipsiTo: L
#
# Item 184:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-32k
#  label: midthickness
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(32492, 4)>
#   map_contra: <DataFrame shape=(32492, 4)>
#  ipsiTo: L
#
# Item 185:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: midthickness
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(8, 7)>
#   map_ipsi: <DataFrame shape=(32492, 8)>
#   map_contra: <DataFrame shape=(32492, 8)>
#  ipsiTo: L
#
# Item 186:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-32k
#  label: pial
#  feature: FA
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(32492, 4)>
#   map_contra: <DataFrame shape=(32492, 4)>
#  ipsiTo: L
#
# Item 187:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-32k
#  label: pial
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(32492, 4)>
#   map_contra: <DataFrame shape=(32492, 4)>
#  ipsiTo: L
#
# Item 188:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: fsLR-32k
#  label: pial
#  feature: T1map
#  hippocampal: False
#   map_pths: <DataFrame shape=(8, 7)>
#   map_ipsi: <DataFrame shape=(32492, 8)>
#   map_contra: <DataFrame shape=(32492, 8)>
#  ipsiTo: L
#
# Item 189:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: 0p5mm
#  label: outer
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(3, 7)>
#   map_ipsi: <DataFrame shape=(7262, 3)>
#   map_contra: <DataFrame shape=(7262, 3)>
#  ipsiTo: L
#
# Item 190:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: 0p5mm
#  label: outer
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(3, 7)>
#   map_ipsi: <DataFrame shape=(7262, 3)>
#   map_contra: <DataFrame shape=(7262, 3)>
#  ipsiTo: L
#
# Item 191:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: outer
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(5, 7)>
#   map_ipsi: <DataFrame shape=(7262, 5)>
#   map_contra: <DataFrame shape=(7262, 5)>
#  ipsiTo: L
#
# Item 192:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: 0p5mm
#  label: inner
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(3, 7)>
#   map_ipsi: <DataFrame shape=(7262, 3)>
#   map_contra: <DataFrame shape=(7262, 3)>
#  ipsiTo: L
#
# Item 193:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: 0p5mm
#  label: inner
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(3, 7)>
#   map_ipsi: <DataFrame shape=(7262, 3)>
#   map_contra: <DataFrame shape=(7262, 3)>
#  ipsiTo: L
#
# Item 194:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: inner
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(5, 7)>
#   map_ipsi: <DataFrame shape=(7262, 5)>
#   map_contra: <DataFrame shape=(7262, 5)>
#  ipsiTo: L
#
# Item 195:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: 0p5mm
#  label: midthickness
#  feature: FA
#  hippocampal: True
#   map_pths: <DataFrame shape=(3, 7)>
#   map_ipsi: <DataFrame shape=(7262, 3)>
#   map_contra: <DataFrame shape=(7262, 3)>
#  ipsiTo: L
#
# Item 196:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: 0p5mm
#  label: midthickness
#  feature: ADC
#  hippocampal: True
#   map_pths: <DataFrame shape=(3, 7)>
#   map_ipsi: <DataFrame shape=(7262, 3)>
#   map_contra: <DataFrame shape=(7262, 3)>
#  ipsiTo: L
#
# Item 197:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: 0p5mm
#  label: midthickness
#  feature: T1map
#  hippocampal: True
#   map_pths: <DataFrame shape=(5, 7)>
#   map_ipsi: <DataFrame shape=(7262, 5)>
#   map_contra: <DataFrame shape=(7262, 5)>
#  ipsiTo: L

# %%
grps = ['allPX', 'TLE_L', 'TLE_R', 'TLE_ic']
fts = ['ADC', 'FA', 'T1map']
surfs = ['fsLR-5k']
lbls = ['midthickness']

for grp in grps:
    for ft in fts:
        for surf in surfs:
            for lbl in lbls:
                print(f"{grp}, {ft}, {surf}, {lbl}")
                # search winStdy and btwStdy for appropriate index
                tT_idx = [i for i, d in enumerate(winStdy) if d['study'] == 'MICs' and d['grp'] == grp and d['feature'] == ft and d['surface'] == surf and d['label'] == lbl]
                sT_idx = [i for i, d in enumerate(btwStdy) if d['study'] == 'PNI' and d['grp'] == grp and d['feature'] == ft and d['surface'] == surf and d['label'] == lbl]
                
                comp_idx = [i for i, d in enumerate(btwStdy) if d['grp'] == grp and d['feature'] == ft and d['surface'] == surf and d['label'] == lbl]
                print(f"\tindices. winStudy [3T: {tT_idx}, 7T: {sT_idx}], comparison: {comp_idx}")
                if not tT_idx or not sT_idx or not comp_idx:
                    print(f"\t\tAt least one comparison incomplete. Skipping.")
                    continue
                
                # Show the brains
# Out:
# allPX, ADC, fsLR-5k, midthickness
# 	indices. winStudy [3T: [4], 7T: [31]], comparison: [4, 31]
# allPX, FA, fsLR-5k, midthickness
# 	indices. winStudy [3T: [3], 7T: [30]], comparison: [3, 30]
# allPX, T1map, fsLR-5k, midthickness
# 	indices. winStudy [3T: [5], 7T: [32]], comparison: [5, 32]
# TLE_L, ADC, fsLR-5k, midthickness
# 	indices. winStudy [3T: [58], 7T: [85]], comparison: [58, 85]
# TLE_L, FA, fsLR-5k, midthickness
# 	indices. winStudy [3T: [57], 7T: [84]], comparison: [57, 84]
# TLE_L, T1map, fsLR-5k, midthickness
# 	indices. winStudy [3T: [59], 7T: [86]], comparison: [59, 86]
# TLE_R, ADC, fsLR-5k, midthickness
# 	indices. winStudy [3T: [112], 7T: []], comparison: [112]
# 		At least one comparison incomplete. Skipping.
# TLE_R, FA, fsLR-5k, midthickness
# 	indices. winStudy [3T: [111], 7T: []], comparison: [111]
# 		At least one comparison incomplete. Skipping.
# TLE_R, T1map, fsLR-5k, midthickness
# 	indices. winStudy [3T: [113], 7T: [136]], comparison: [113, 136]
# TLE_ic, ADC, fsLR-5k, midthickness
# 	indices. winStudy [3T: [148], 7T: [175]], comparison: [148, 175]
# TLE_ic, FA, fsLR-5k, midthickness
# 	indices. winStudy [3T: [147], 7T: [174]], comparison: [147, 174]
# TLE_ic, T1map, fsLR-5k, midthickness
# 	indices. winStudy [3T: [149], 7T: [176]], comparison: [149, 176]

# %%
print_dict([btwStdy[148], btwStdy[175]], df_print=False)
# Out:
#  dict: (2 items):
#
# Item 0:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: MICs
#  grp: TLE_ic
#  grp_labels: ['TLE_L', 'TLE_R']
#  surface: fsLR-5k
#  label: midthickness
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(7, 7)>
#   map_ipsi: <DataFrame shape=(4842, 7)>
#   map_contra: <DataFrame shape=(4842, 7)>
#  ipsiTo: L
#  n_ctrl: 11
#  n_comp: 7
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
#
# Item 1:
#   Keys: ['study', 'grp', 'grp_labels', 'surface', 'label', 'feature', 'hippocampal', 'map_pths', 'map_ipsi', 'map_contra', 'ipsiTo', 'n_ctrl', 'n_comp', 'stats_ipsi', 'stats_contra']
#  study: PNI
#  grp: TLE_ic
#  grp_labels: ['TLE_L']
#  surface: fsLR-5k
#  label: midthickness
#  feature: ADC
#  hippocampal: False
#   map_pths: <DataFrame shape=(4, 7)>
#   map_ipsi: <DataFrame shape=(4842, 4)>
#   map_contra: <DataFrame shape=(4842, 4)>
#  ipsiTo: L
#  n_ctrl: 10
#  n_comp: 4
#   stats_ipsi: <DataFrame shape=(4842, 4)>
#   stats_contra: <DataFrame shape=(4842, 4)>
