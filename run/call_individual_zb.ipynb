# %% [markdown]
# # Run z-brains analyses for individual cases

# %%
import pandas as pd
import os, sys, subprocess
import importlib

# import utilities
utilities_path = os.path.abspath(os.path.join(os.getcwd(), "/host/verges/tank/data/daniel", "Utils"))
sys.path.append(utilities_path) # path to Utilities
import id, gen, zbUtils

# %%
importlib.reload(id)
# Out:
# <module 'id' from '/host/verges/tank/data/daniel/Utils/id.py'>

# %%
# Input IDs

# IDs: should be in long format (all IDs to be used should be in same column (regardless of if it is 3T or 7T ID))
# model: "/host/verges/tank/data/daniel/3T7T/z/data/models/participants_mics_hc.csv"

# list col names
IDs = {
    "dir": "/host/verges/tank/data/daniel/3T7T/z/data/pt/master_demo_19Mar2025_age_y.csv",
    "ID_col": "ID",
    "SES_col": "SES",
    "age_col": "age_y",
    "sex": "sex"
}

# Dir tmp
dir_tmp = "/host/verges/tank/data/daniel/3T7T/z/outputs/tmp"

# %%
# zBrain parameters

# size of kernels for smoothing (cortex: ctx; hippocampus: hip). 
# NOTE: Both lists must be of same length.
smooth_ctx=[2,5,10] # try with 2,5,10
smooth_hip=[1,2,5] # try with 1,2,5

# surface
res="high" # low (cotrex: 5K, hippocampus: 2mm), high (ctx: 32k, hipp: 0.5mm), all (both high and low)

# Output: path and file name
out_name="DM_zb_37comp" # will create folders with this name in BIDs directory

# path to z-brains software
score_type = "z" # z or w, will call appropriate shell script accordingly

# Dictionary item for each study
# Note: zBrains only currently supports one 'ctrl_ptrn', not a list

# directories need to be relative except for root
MICs = {
    "name" : "MICs",
    "ctrl_ptrn" : "HC",
    "pt_ptrn" : "PX",
    "dir_root" : "/data/mica3/BIDS_MICs",
    "dir_raw" : "rawdata",
    "dir_deriv" : "derivatives",
    "dir_mp" : "micapipe_v0.2.0",
    "dir_hu" : "hippunfold_v1.3.0"
}

PNI = {
    "name" : "PNI",
    "ctrl_ptrn" : "PNC",
    "pt_ptrn" : "PNE",
    "dir_root" : "/data/mica3/BIDS_PNI",
    "dir_raw" : "rawdata",
    "dir_deriv" : "derivatives",
    "dir_mp" : "micapipe_v0.2.0",
    "dir_hu" : "hippunfold_v1.3.0"
}

studies = [MICs, PNI]

# %%
# testing values
test = False
if test:
    dir_software = "/host/verges/tank/data/daniel/3T7T/z/code/run/tests/printArgs.sh"
elif score_type == "z":
    dir_software = "/host/verges/tank/data/daniel/3T7T/z/code/run/runZB.sh"
elif score_type == "w":
    dir_software = "/host/verges/tank/data/daniel/3T7T/z/code/run/runZB_w.sh"
else:  
    print("Invalid score type. Must be either 'z', 'w' or 'test'")

# studies = [MICs]
# smooth_ctx=[10]
# smooth_hip=[5]

# %%
# Convert IDs to format accepted by zBrains (add sub-, ses-)

# ensure that ID and ses are properly formatted
#df = gen.fmt(IDs["dir"], [dir_IDs_cols["7T_ID"], dir_IDs_cols["3T_ID"], dir_IDs_cols["7T_SES"], dir_IDs_cols["3T_SES"]])
df = gen.fmt(IDs["dir"], ["ID", "SES"])
# rename df columns
df = df.rename(columns={IDs["ID_col"]:"ID", IDs["SES_col"]:"SES", IDs["age_col"]:"AGE", IDs["sex"]:"SEX"})
#df.head()

# save df to tmp, use path as new IDs["dir"]
dir_IDs = dir_tmp+"/"+os.path.splitext(os.path.basename(IDs["dir"]))[0]+"_fmt.csv"
df.to_csv(dir_IDs, index=False)

print("[INFO] Formatted IDs saved to: ", dir_IDs)

# seperate IDs by study - pass seperate IDs csv to zBrains
# extract ID patterns
ptrns = []
for study in studies:
    ptrns.append([f"sub-{study['ctrl_ptrn']}", f"sub-{study['pt_ptrn']}"])

#print(ptrns)

split_paths = id.split(dir_IDs, col="ID", patterns=ptrns, pth_out=dir_tmp) # split_paths holds paths to split files
# split_paths[0]: MICs, [1]: PNI

# print(split_paths)
# length of split_paths should be equal to the number of studies

if len(split_paths) != len(studies):
    print("[main] Error: Number of split files does not match number of studies.")
    print("\t Check  that the attributes 'ctrl_ptrn' and 'pt_ptrn' are properly defined in all study dictionaries.")
    sys.exit(1)
# Out:
# [INFO] Formatted IDs saved to:  /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/master_demo_19Mar2025_age_y_fmt.csv
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/split_ID_1.csv (24 rows)sub-PX: 16, sub-HC: 8
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/split_ID_2.csv (24 rows)sub-PNE: 16, sub-PNC: 8

# %%
# Manually call zBrains for specific ID
ID = "PNE017" # ID of interest    

df_path = split_paths[1] # demo file, MICs = [0], PNI = [1]
study = PNI
ctrl_ptrn = "sub-%s" %study["ctrl_ptrn"]
pt_ptrn = "sub-%s" %ID
ptrns = [ctrl_ptrn,pt_ptrn]
print(ptrns)

demo_pth = id.split(df_path, col="ID", patterns=ptrns, pth_out=dir_tmp, output_prefix="demo")# filter for only control IDs  

print("\n=====================================")
print(study["name"])
#--control_prefix and define according to study

# run z-brains with each smoothing kernel - can run cortex and hippocampus seperately and in parallel
for ctx, hip in zip(smooth_ctx, smooth_hip):
    print(f"Smoothing: ctx={ctx}, hip={hip}")
    
    # call via bash, pass appropriate arguments
    print("Calling zBrains with:")
    print(study, out_name, ctx, hip, res, demo_pth[0], demo_pth[1], score_type, dir_software)
    
    result = zbUtils.runZBrain(
        study, out_name, ctx, hip, res, demo_ref=demo_pth[0], demo=demo_pth[1], 
        score=score_type, dir_software=dir_software
    )
    # Print zBrains run output
    if result.returncode != 0:
        print(f"Command failed with return code {result.returncode}")

    print("STDOUT:")
    for line in result.stdout.splitlines():
        print(f"\t{line}")

    if result.stderr:
        print("STDERR:")
        for line in result.stderr.splitlines():
            print(f"\t{line}")
# Out:
# ['sub-PNC', 'sub-PNE017']
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_1.csv (8 rows)sub-PNC: 8
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_2.csv (1 rows)sub-PNE: 1
#
# =====================================
# PNI
# Smoothing: ctx=2, hip=1
# Calling zBrains with:
# {'name': 'PNI', 'ctrl_ptrn': 'PNC', 'pt_ptrn': 'PNE', 'dir_root': '/data/mica3/BIDS_PNI', 'dir_raw': 'rawdata', 'dir_deriv': 'derivatives', 'dir_mp': 'micapipe_v0.2.0', 'dir_hu': 'hippunfold_v1.3.0'} DM_zb_37comp 2 1 high /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_1.csv /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_2.csv z /host/verges/tank/data/daniel/3T7T/z/code/run/runZB.sh
# STDOUT:
# 	Activating Python environment at /data/mica1/03_projects/ian/anaconda3
# 	Activated zbrains environment
# 	Running analysis on all subjects specified in the demo files
# 	{'participant_id': 'ID', 'session_id': 'SES'}
# 	Running analysis on all subjects specified in the demo_ref files
# 	Using sessions from demo file
# 	Running analysis on all sessions specified in the demo_ref files
# 	['sub-PNE017', 'sub-PNC003', 'sub-PNC006', 'sub-PNC011', 'sub-PNC018', 'sub-PNC019', 'sub-PNC024', 'sub-PNC025', 'sub-PNC026']
# 	['ses-a1', 'ses-03', 'ses-03', 'ses-03', 'ses-01', 'ses-01', 'ses-a1', 'ses-a1', 'ses-a3']
# 	INFO: zbrains is running with:
# 	proc analysis
# 	NOTE: WorkBench... Workbench
# 	NOTE:              /usr/bin/wb_command
# 	NOTE: python...... 3.8.19
# 	NOTE:              /data/mica1/03_projects/ian/anaconda3/envs/zbrains/bin/python
# 	NOTE:
# 	NOTE: Arguments...
# 	NOTE: sub ['sub-PNE017', 'sub-PNC003', 'sub-PNC006', 'sub-PNC011', 'sub-PNC018', 'sub-PNC019', 'sub-PNC024', 'sub-PNC025', 'sub-PNC026']
# 	NOTE: dataset /data/mica3/BIDS_PNI
# 	NOTE: zbrains DM_zb_37comp
# 	NOTE: ses ['ses-a1', 'ses-03', 'ses-03', 'ses-03', 'ses-01', 'ses-01', 'ses-a1', 'ses-a1', 'ses-a3']
# 	NOTE: micapipe micapipe_v0.2.0
# 	NOTE: hippunfold hippunfold_v1.3.0
# 	NOTE: plugin None
# 	NOTE: dataset_ref ['/data/mica3/BIDS_PNI']
# 	NOTE: zbrains_ref ['DM_zb_37comp']
# 	NOTE: run proc analysis
# 	NOTE: struct all
# 	NOTE: feat ['all']
# 	NOTE: demo_ref ['/host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_1.csv']
# 	NOTE: demo /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_2.csv
# 	NOTE: normative None
# 	NOTE: deconfound None
# 	NOTE: resolution ['high']
# 	NOTE: label_ctx None
# 	NOTE: label_hip None
# 	NOTE: smooth_ctx 2
# 	NOTE: smooth_hip 1
# 	NOTE: threshold None
# 	NOTE: column_map {'participant_id': 'ID', 'session_id': 'SES'}
# 	NOTE: init None
# 	NOTE: delete_temps None
# 	NOTE: n_jobs 4
# 	NOTE: n_jobs_wb 4
# 	NOTE: wb_path /usr/bin/
# 	NOTE: control_prefix PNC
# 	NOTE: verbose 2
# 	NOTE: dicoms 0
# 	NOTE: volumetric 0
# 	NOTE: test None
# 	Processing sub-PNE017 ses-a1 with tasks proc
# 	Processing sub-PNC006 ses-03 with tasks proc
# 	Processing sub-PNC011 ses-03 with tasks proc
# 	Processing sub-PNC003 ses-03 with tasks proc
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	 Cortical feature mapping: sub-PNC011_ses-03
# 	 Cortical feature mapping: sub-PNC003_ses-03
# 	 Cortical feature mapping: sub-PNE017_ses-a1
# 	 Cortical feature mapping: sub-PNC006_ses-03
# 	[Errno 2] No such file or directory: '/data/mica3/BIDS_PNI/derivatives/hippunfold_v1.3.0/hippunfold/sub-PNC006/ses-03/surf/sub-PNC006_ses-03_hemi-L_space-T1w_den-0p5mm_label-hipp_inner.surf.gii'
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC006/ses-03/z_brains_temp.exd9mn8k
# 	Processing sub-PNC018 ses-01 with tasks proc
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	 Cortical feature mapping: sub-PNC018_ses-01
# 	[Errno 2] No such file or directory: '/data/mica3/BIDS_PNI/derivatives/hippunfold_v1.3.0/hippunfold/sub-PNE017/ses-a1/surf/sub-PNE017_ses-a1_hemi-R_space-T1w_den-0p5mm_label-hipp_outer.surf.gii'
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNE017/ses-a1/z_brains_temp.8ju7d3ln
# 	Processing sub-PNC019 ses-01 with tasks proc
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	 Cortical feature mapping: sub-PNC019_ses-01
# 	INFO: sub-PNC003_ses-03: Mapping 'ADC' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'ADC' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsLR-32k_label-white_ADC.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'ADC' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'ADC' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsLR-32k_label-midthickness_ADC.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'FA' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'FA' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsLR-32k_label-white_FA.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'FA' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'FA' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsLR-32k_label-midthickness_FA.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'flair' to cortex [label=white, resolution=32k]
# 	INFO: sub-PNC011_ses-03: Mapping 'ADC' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'flair' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsLR-32k_label-white_flair.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'flair' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'flair' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsLR-32k_label-midthickness_flair.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'flair_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'flair_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'flair_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'flair_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'qT1' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'ADC' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsLR-32k_label-white_ADC.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'ADC' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'ADC' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsLR-32k_label-midthickness_ADC.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'FA' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'FA' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsLR-32k_label-white_FA.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'FA' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'FA' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsLR-32k_label-midthickness_FA.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'flair' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'flair' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsLR-32k_label-white_flair.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'flair' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'flair' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsLR-32k_label-midthickness_flair.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'flair_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'flair_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'flair_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'flair_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'qT1' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC003_ses-03: 'qT1' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC003_ses-03: Mapping 'qT1' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC011_ses-03: 'qT1' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC011_ses-03: Mapping 'qT1' to cortex [label=midthickness, resolution=32k]
# 	INFO: sub-PNC018_ses-01: Mapping 'ADC' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC003_ses-03: 'qT1' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC003_ses-03: Mapping 'qT1_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'qT1_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'qT1_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC003_ses-03: cannot map 'qT1_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC003_ses-03: Mapping 'thickness' to cortex [label=white, resolution=32k]
# 	INFO: sub-PNC019_ses-01: Mapping 'ADC' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC011_ses-03: 'qT1' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC011_ses-03: Mapping 'qT1_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'qT1_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'qT1_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'qT1_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC011_ses-03: Mapping 'thickness' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC018_ses-01: 'ADC' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'ADC' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC003_ses-03: 'thickness' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC003_ses-03: Mapping 'thickness' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC019_ses-01: 'ADC' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'ADC' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC011_ses-03: 'thickness' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC011_ses-03: Mapping 'thickness' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC018_ses-01: 'ADC' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'FA' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC003_ses-03: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC003_ses-03 ended in 0.74 minutes
# 	 Hippocampal feature mapping: sub-PNC003_ses-03
# 	NOTE: sub-PNC019_ses-01: 'ADC' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'FA' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC011_ses-03: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC011_ses-03 ended in 0.75 minutes
# 	 Hippocampal feature mapping: sub-PNC011_ses-03
# 	NOTE: sub-PNC018_ses-01: 'FA' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'FA' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC019_ses-01: 'FA' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'FA' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC018_ses-01: 'FA' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'flair' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC018_ses-01: cannot map 'flair' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC018/ses-01/maps/sub-PNC018_ses-01_hemi-L_surf-fsLR-32k_label-white_flair.func.gii
# 	INFO: sub-PNC018_ses-01: Mapping 'flair' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC018_ses-01: cannot map 'flair' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC018/ses-01/maps/sub-PNC018_ses-01_hemi-L_surf-fsLR-32k_label-midthickness_flair.func.gii
# 	INFO: sub-PNC018_ses-01: Mapping 'flair_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC018_ses-01: cannot map 'flair_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC018/ses-01/maps/sub-PNC018_ses-01_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC018_ses-01: Mapping 'flair_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC018_ses-01: cannot map 'flair_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC018/ses-01/maps/sub-PNC018_ses-01_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC018_ses-01: Mapping 'qT1' to cortex [label=white, resolution=32k]
# 	INFO: sub-PNC003_ses-03: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC003_ses-03: cannot map 'ADC' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_space-nativepro_model-DTI_map-ADC.nii.gz
# 	INFO: sub-PNC003_ses-03: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC003_ses-03: cannot map 'FA' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_space-nativepro_model-DTI_map-FA.nii.gz
# 	INFO: sub-PNC003_ses-03: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC003_ses-03: cannot map 'flair' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC003_ses-03: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	INFO: sub-PNC011_ses-03: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC019_ses-01: 'FA' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'flair' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC019_ses-01: cannot map 'flair' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC019/ses-01/maps/sub-PNC019_ses-01_hemi-L_surf-fsLR-32k_label-white_flair.func.gii
# 	INFO: sub-PNC019_ses-01: Mapping 'flair' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC019_ses-01: cannot map 'flair' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC019/ses-01/maps/sub-PNC019_ses-01_hemi-L_surf-fsLR-32k_label-midthickness_flair.func.gii
# 	INFO: sub-PNC019_ses-01: Mapping 'flair_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC019_ses-01: cannot map 'flair_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC019/ses-01/maps/sub-PNC019_ses-01_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC019_ses-01: Mapping 'flair_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC019_ses-01: cannot map 'flair_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC019/ses-01/maps/sub-PNC019_ses-01_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC019_ses-01: Mapping 'qT1' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC011_ses-03: cannot map 'ADC' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_space-nativepro_model-DTI_map-ADC.nii.gz
# 	INFO: sub-PNC011_ses-03: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC011_ses-03: cannot map 'FA' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_space-nativepro_model-DTI_map-FA.nii.gz
# 	INFO: sub-PNC011_ses-03: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC011_ses-03: cannot map 'flair' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC011_ses-03: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC018_ses-01: 'qT1' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'qT1' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC019_ses-01: 'qT1' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'qT1' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC018_ses-01: 'qT1' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'qT1_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC018_ses-01: cannot map 'qT1_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC018/ses-01/maps/sub-PNC018_ses-01_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC018_ses-01: Mapping 'qT1_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC018_ses-01: cannot map 'qT1_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC018/ses-01/maps/sub-PNC018_ses-01_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC018_ses-01: Mapping 'thickness' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC019_ses-01: 'qT1' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'qT1_blur' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC018_ses-01: 'thickness' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'thickness' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC018_ses-01: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC018_ses-01 ended in 0.86 minutes
# 	 Hippocampal feature mapping: sub-PNC018_ses-01
# 	NOTE: sub-PNC003_ses-03: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC003_ses-03: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC011_ses-03: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC011_ses-03: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC003_ses-03: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC003_ses-03 ended in 0.44 minutes
# 	 Subcortical feature mapping: sub-PNC003_ses-03
# 	NOTE: sub-PNC011_ses-03: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC011_ses-03 ended in 0.43 minutes
# 	 Subcortical feature mapping: sub-PNC011_ses-03
# 	INFO: sub-PNC018_ses-01: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC019_ses-01: 'qT1_blur' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'qT1_blur' to cortex [label=midthickness, resolution=32k]
# 	INFO: sub-PNC003_ses-03: Mapping 'ADC' to subcortical structures
# 	WARNING: sub-PNC003_ses-03: cannot map 'ADC' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_space-nativepro_model-DTI_map-ADC.nii.gz
# 	INFO: sub-PNC003_ses-03: Mapping 'FA' to subcortical structures
# 	WARNING: sub-PNC003_ses-03: cannot map 'FA' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_space-nativepro_model-DTI_map-FA.nii.gz
# 	INFO: sub-PNC003_ses-03: Mapping 'flair' to subcortical structures
# 	WARNING: sub-PNC003_ses-03: cannot map 'flair' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC003/ses-03/maps/sub-PNC003_ses-03_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC003_ses-03: Mapping 'qT1' to subcortical structures
# 	INFO: sub-PNC011_ses-03: Mapping 'ADC' to subcortical structures
# 	WARNING: sub-PNC011_ses-03: cannot map 'ADC' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_space-nativepro_model-DTI_map-ADC.nii.gz
# 	INFO: sub-PNC011_ses-03: Mapping 'FA' to subcortical structures
# 	WARNING: sub-PNC011_ses-03: cannot map 'FA' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_space-nativepro_model-DTI_map-FA.nii.gz
# 	INFO: sub-PNC011_ses-03: Mapping 'flair' to subcortical structures
# 	WARNING: sub-PNC011_ses-03: cannot map 'flair' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC011/ses-03/maps/sub-PNC011_ses-03_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC011_ses-03: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC018_ses-01: 'ADC' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC018_ses-01: 'FA' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC018_ses-01: cannot map 'flair' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC018/ses-01/maps/sub-PNC018_ses-01_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC018_ses-01: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC018_ses-01: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC018_ses-01: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC018_ses-01 ended in 0.55 minutes
# 	 Subcortical feature mapping: sub-PNC018_ses-01
# 	NOTE: sub-PNC019_ses-01: 'qT1_blur' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'thickness' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC019_ses-01: 'thickness' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'thickness' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC011_ses-03: 'qT1' successfully mapped.
# 	INFO: sub-PNC011_ses-03: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC011_ses-03: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC011_ses-03 ended in 0.55 minutes
# 	 Total elapsed time for sub-PNC011_ses-03: 1.73 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC011/ses-03/z_brains_temp.wdufy5ad
# 	NOTE: sub-PNC003_ses-03: 'qT1' successfully mapped.
# 	INFO: sub-PNC003_ses-03: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC003_ses-03: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC003_ses-03 ended in 0.55 minutes
# 	 Total elapsed time for sub-PNC003_ses-03: 1.73 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC003/ses-03/z_brains_temp.iy_jejai
# 	Processing sub-PNC024 ses-a1 with tasks proc
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	Processing sub-PNC025 ses-a1 with tasks proc
# 	 Cortical feature mapping: sub-PNC024_ses-a1
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	 Cortical feature mapping: sub-PNC025_ses-a1
# 	NOTE: sub-PNC019_ses-01: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC019_ses-01 ended in 1.36 minutes
# 	 Hippocampal feature mapping: sub-PNC019_ses-01
# 	INFO: sub-PNC018_ses-01: Mapping 'ADC' to subcortical structures
# 	NOTE: sub-PNC018_ses-01: 'ADC' successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'FA' to subcortical structures
# 	INFO: sub-PNC019_ses-01: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	INFO: sub-PNC024_ses-a1: Mapping 'ADC' to cortex [label=white, resolution=32k]
# 	INFO: sub-PNC025_ses-a1: Mapping 'ADC' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'ADC' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'ADC' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'ADC' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'ADC' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'ADC' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'FA' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'ADC' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'FA' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'FA' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'FA' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'FA' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'FA' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC019_ses-01: 'ADC' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC024_ses-a1: 'FA' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'flair' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'FA' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'flair' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'flair' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'flair' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'flair' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'flair' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'flair' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'flair_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC024_ses-a1: cannot map 'flair_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC024/ses-a1/maps/sub-PNC024_ses-a1_hemi-L_surf-fsnative_label-swm1.0mm_flair.func.gii
# 	INFO: sub-PNC024_ses-a1: Mapping 'flair_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC024_ses-a1: cannot map 'flair_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC024/ses-a1/maps/sub-PNC024_ses-a1_hemi-L_surf-fsnative_label-swm1.0mm_flair.func.gii
# 	INFO: sub-PNC024_ses-a1: Mapping 'qT1' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'flair' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'flair_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC025_ses-a1: cannot map 'flair_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC025/ses-a1/maps/sub-PNC025_ses-a1_hemi-L_surf-fsnative_label-swm1.0mm_flair.func.gii
# 	INFO: sub-PNC025_ses-a1: Mapping 'flair_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC025_ses-a1: cannot map 'flair_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC025/ses-a1/maps/sub-PNC025_ses-a1_hemi-L_surf-fsnative_label-swm1.0mm_flair.func.gii
# 	INFO: sub-PNC025_ses-a1: Mapping 'qT1' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'qT1' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'qT1' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'qT1' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'qT1' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC018_ses-01: 'FA' successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'flair' to subcortical structures
# 	WARNING: sub-PNC018_ses-01: cannot map 'flair' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC018/ses-01/maps/sub-PNC018_ses-01_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC018_ses-01: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'qT1' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'qT1_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC024_ses-a1: cannot map 'qT1_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC024/ses-a1/maps/sub-PNC024_ses-a1_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC024_ses-a1: Mapping 'qT1_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC024_ses-a1: cannot map 'qT1_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC024/ses-a1/maps/sub-PNC024_ses-a1_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC024_ses-a1: Mapping 'thickness' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'qT1' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'qT1_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC025_ses-a1: cannot map 'qT1_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC025/ses-a1/maps/sub-PNC025_ses-a1_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC025_ses-a1: Mapping 'qT1_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC025_ses-a1: cannot map 'qT1_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC025/ses-a1/maps/sub-PNC025_ses-a1_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC025_ses-a1: Mapping 'thickness' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'thickness' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'thickness' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'thickness' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'thickness' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC019_ses-01: 'FA' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC019_ses-01: cannot map 'flair' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC019/ses-01/maps/sub-PNC019_ses-01_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC019_ses-01: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC025_ses-a1: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC025_ses-a1 ended in 0.61 minutes
# 	 Hippocampal feature mapping: sub-PNC025_ses-a1
# 	NOTE: sub-PNC024_ses-a1: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC024_ses-a1 ended in 0.62 minutes
# 	 Hippocampal feature mapping: sub-PNC024_ses-a1
# 	NOTE: sub-PNC019_ses-01: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC019_ses-01: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC019_ses-01 ended in 0.69 minutes
# 	 Subcortical feature mapping: sub-PNC019_ses-01
# 	NOTE: sub-PNC018_ses-01: 'qT1' successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC018_ses-01: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC018_ses-01 ended in 0.88 minutes
# 	 Total elapsed time for sub-PNC018_ses-01: 2.29 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC018/ses-01/z_brains_temp.c79fif5w
# 	Processing sub-PNC026 ses-a3 with tasks proc
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	 Cortical feature mapping: sub-PNC026_ses-a3
# 	INFO: sub-PNC025_ses-a1: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	INFO: sub-PNC024_ses-a1: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	INFO: sub-PNC019_ses-01: Mapping 'ADC' to subcortical structures
# 	INFO: sub-PNC026_ses-a3: Mapping 'ADC' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'ADC' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-white_ADC.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'ADC' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'ADC' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-midthickness_ADC.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'FA' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'FA' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-white_FA.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'FA' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'FA' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-midthickness_FA.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-white_flair.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-midthickness_flair.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC026_ses-a3: 'qT1' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC026_ses-a3: 'qT1' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'qT1_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'qT1_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'thickness' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'ADC' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC026_ses-a3: 'thickness' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'thickness' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'ADC' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC026_ses-a3: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC026_ses-a3 ended in 0.41 minutes
# 	 Hippocampal feature mapping: sub-PNC026_ses-a3
# 	NOTE: sub-PNC019_ses-01: 'ADC' successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'FA' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'FA' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC025_ses-a1: 'FA' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	INFO: sub-PNC026_ses-a3: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'ADC' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_model-DTI_map-ADC.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'FA' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_model-DTI_map-FA.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC024_ses-a1: 'flair' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC025_ses-a1: 'flair' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC026_ses-a3: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC026_ses-a3: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC026_ses-a3 ended in 0.27 minutes
# 	 Subcortical feature mapping: sub-PNC026_ses-a3
# 	NOTE: sub-PNC019_ses-01: 'FA' successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'flair' to subcortical structures
# 	WARNING: sub-PNC019_ses-01: cannot map 'flair' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC019/ses-01/maps/sub-PNC019_ses-01_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC019_ses-01: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC025_ses-a1: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC024_ses-a1: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC024_ses-a1 ended in 0.98 minutes
# 	 Subcortical feature mapping: sub-PNC024_ses-a1
# 	INFO: sub-PNC026_ses-a3: Mapping 'ADC' to subcortical structures
# 	WARNING: sub-PNC026_ses-a3: cannot map 'ADC' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_model-DTI_map-ADC.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'FA' to subcortical structures
# 	WARNING: sub-PNC026_ses-a3: cannot map 'FA' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_model-DTI_map-FA.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair' to subcortical structures
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC025_ses-a1 ended in 1.07 minutes
# 	 Subcortical feature mapping: sub-PNC025_ses-a1
# 	NOTE: sub-PNC019_ses-01: 'qT1' successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC019_ses-01: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC019_ses-01 ended in 1.01 minutes
# 	 Total elapsed time for sub-PNC019_ses-01: 3.06 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC019/ses-01/z_brains_temp.iyyvnetb
# 	NOTE: sub-PNC026_ses-a3: 'qT1' successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC026_ses-a3: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC026_ses-a3 ended in 0.38 minutes
# 	 Total elapsed time for sub-PNC026_ses-a3: 1.07 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC026/ses-a3/z_brains_temp.8uigxpcw
# 	INFO: sub-PNC024_ses-a1: Mapping 'ADC' to subcortical structures
# 	INFO: sub-PNC025_ses-a1: Mapping 'ADC' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'ADC' successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'FA' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'ADC' successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'FA' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'FA' successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'flair' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'FA' successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'flair' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'flair' successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'flair' successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'qT1' successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC024_ses-a1 ended in 1.06 minutes
# 	 Total elapsed time for sub-PNC024_ses-a1: 2.66 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC024/ses-a1/z_brains_temp.jns4z6u6
# 	NOTE: sub-PNC025_ses-a1: 'qT1' successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC025_ses-a1 ended in 1.02 minutes
# 	 Total elapsed time for sub-PNC025_ses-a1: 2.70 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC025/ses-a1/z_brains_temp.lgqy3m8_
# 	Processing sub-PNE017 ses-a1 with tasks analysis
# ...
# 	WARNING: sub-PNC018_ses-01: cannot map 'flair' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC018/ses-01/maps/sub-PNC018_ses-01_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC018_ses-01: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC025_ses-a1 ended in 1.26 minutes
# 	 Hippocampal feature mapping: sub-PNC025_ses-a1
# 	NOTE: sub-PNC024_ses-a1: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC024_ses-a1 ended in 1.56 minutes
# 	 Hippocampal feature mapping: sub-PNC024_ses-a1
# 	NOTE: sub-PNC018_ses-01: 'qT1' successfully mapped.
# 	INFO: sub-PNC018_ses-01: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC018_ses-01: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC018_ses-01 ended in 0.82 minutes
# 	 Total elapsed time for sub-PNC018_ses-01: 3.31 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC018/ses-01/z_brains_temp.d9z7cccs
# 	Processing sub-PNC026 ses-a3 with tasks proc
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] proc
# 	 Cortical feature mapping: sub-PNC026_ses-a3
# 	INFO: sub-PNC019_ses-01: Mapping 'ADC' to subcortical structures
# 	INFO: sub-PNC025_ses-a1: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC019_ses-01: 'ADC' successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'FA' to subcortical structures
# 	INFO: sub-PNC024_ses-a1: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	INFO: sub-PNC026_ses-a3: Mapping 'ADC' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'ADC' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-white_ADC.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'ADC' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'ADC' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-midthickness_ADC.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'FA' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'FA' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-white_FA.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'FA' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'FA' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-midthickness_FA.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-white_flair.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsLR-32k_label-midthickness_flair.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsnative_label-white_flair.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'ADC' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC026_ses-a3: 'qT1' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'ADC' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC019_ses-01: 'FA' successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'flair' to subcortical structures
# 	WARNING: sub-PNC019_ses-01: cannot map 'flair' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC019/ses-01/maps/sub-PNC019_ses-01_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC019_ses-01: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'FA' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC026_ses-a3: 'qT1' [label=midthickness, resolution=32k] successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1_blur' to cortex [label=white, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'qT1_blur' [label=white, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1_blur' to cortex [label=midthickness, resolution=32k]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'qT1_blur' [label=midthickness, resolution=32k] to cortex. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_hemi-L_surf-fsnative_label-swm1.0mm_T1map.func.gii
# 	INFO: sub-PNC026_ses-a3: Mapping 'thickness' to cortex [label=white, resolution=32k]
# 	NOTE: sub-PNC024_ses-a1: 'FA' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC026_ses-a3: 'thickness' [label=white, resolution=32k] successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'thickness' to cortex [label=midthickness, resolution=32k]
# 	NOTE: sub-PNC025_ses-a1: 'flair' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC019_ses-01: 'qT1' successfully mapped.
# 	INFO: sub-PNC019_ses-01: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC019_ses-01: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC019_ses-01 ended in 0.93 minutes
# 	 Total elapsed time for sub-PNC019_ses-01: 3.85 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC019/ses-01/z_brains_temp.m40c23_b
# 	NOTE: sub-PNC026_ses-a3: 'thickness' [label=midthickness, resolution=32k] successfully mapped.
# 	Cortical feature mapping for sub-PNC026_ses-a3 ended in 0.76 minutes
# 	 Hippocampal feature mapping: sub-PNC026_ses-a3
# 	NOTE: sub-PNC024_ses-a1: 'flair' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC025_ses-a1: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	INFO: sub-PNC026_ses-a3: Mapping 'ADC' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'ADC' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_model-DTI_map-ADC.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'FA' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'FA' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_model-DTI_map-FA.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair' to hippocampus [label=midthickness, resolution=0p5mm]
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair' [label=midthickness, resolution=0p5mm] to hippocampus. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC024_ses-a1: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	NOTE: sub-PNC025_ses-a1: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC025_ses-a1 ended in 1.22 minutes
# 	 Subcortical feature mapping: sub-PNC025_ses-a1
# 	NOTE: sub-PNC024_ses-a1: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC024_ses-a1 ended in 1.15 minutes
# 	 Subcortical feature mapping: sub-PNC024_ses-a1
# 	NOTE: sub-PNC026_ses-a3: 'qT1' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'thickness' to hippocampus [label=midthickness, resolution=0p5mm]
# 	INFO: sub-PNC025_ses-a1: Mapping 'ADC' to subcortical structures
# 	NOTE: sub-PNC026_ses-a3: 'thickness' [label=midthickness, resolution=0p5mm] successfully mapped.
# 	Hippocampal feature mapping for sub-PNC026_ses-a3 ended in 0.53 minutes
# 	 Subcortical feature mapping: sub-PNC026_ses-a3
# 	INFO: sub-PNC024_ses-a1: Mapping 'ADC' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'ADC' successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'FA' to subcortical structures
# 	INFO: sub-PNC026_ses-a3: Mapping 'ADC' to subcortical structures
# 	WARNING: sub-PNC026_ses-a3: cannot map 'ADC' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_model-DTI_map-ADC.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'FA' to subcortical structures
# 	WARNING: sub-PNC026_ses-a3: cannot map 'FA' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_model-DTI_map-FA.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'flair' to subcortical structures
# 	WARNING: sub-PNC026_ses-a3: cannot map 'flair' to subcortical structures. Missing file: /data/mica3/BIDS_PNI/derivatives/micapipe_v0.2.0/sub-PNC026/ses-a3/maps/sub-PNC026_ses-a3_space-nativepro_map-flair.nii.gz
# 	INFO: sub-PNC026_ses-a3: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'ADC' successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'FA' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'FA' successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'flair' to subcortical structures
# 	NOTE: sub-PNC026_ses-a3: 'qT1' successfully mapped.
# 	INFO: sub-PNC026_ses-a3: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC026_ses-a3: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC026_ses-a3 ended in 0.4 minutes
# 	 Total elapsed time for sub-PNC026_ses-a3: 1.70 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC026/ses-a3/z_brains_temp.ybm_q9i7
# 	NOTE: sub-PNC024_ses-a1: 'FA' successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'flair' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'flair' successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'flair' successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'qT1' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'qT1' successfully mapped.
# 	INFO: sub-PNC025_ses-a1: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC025_ses-a1: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC025_ses-a1 ended in 1.04 minutes
# 	 Total elapsed time for sub-PNC025_ses-a1: 3.53 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC025/ses-a1/z_brains_temp.peneu4z4
# 	NOTE: sub-PNC024_ses-a1: 'qT1' successfully mapped.
# 	INFO: sub-PNC024_ses-a1: Mapping 'volume' to subcortical structures
# 	NOTE: sub-PNC024_ses-a1: 'volume' successfully mapped.
# 	Subcortical feature mapping for sub-PNC024_ses-a1 ended in 1.06 minutes
# 	 Total elapsed time for sub-PNC024_ses-a1: 3.77 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNC024/ses-a1/z_brains_temp.a1av54wd
# 	Processing sub-PNE017 ses-a1 with tasks analysis
# 	Temporary directory: ['cortex', 'hippocampus', 'subcortex'] ['ADC', 'FA', 'flair', 'flair_blur', 'qT1', 'qT1_blur', 'thickness'] ['high'] analysis
# 	0
# 	['white', 'midthickness']
#
#
# 	Starting analysis
# 	cortex high white
#
# 	Structure: cortex [resolution = high	label = white          ]
# 		ADC            : 	No data available for target subject.
# 		FA             : 	No data available for target subject.
# 		flair          : 	No data available for target subject.
# 		flair_blur     : 	No data available for reference subjects.
# 		qT1            : 	No data available for target subject.
# 		qT1_blur       : 	No data available for target subject.
# 		thickness      : 	No data available for target subject.
# 	cortex high midthickness
#
# 	Structure: cortex [resolution = high	label = midthickness   ]
# 		ADC            : 	No data available for target subject.
# 		FA             : 	No data available for target subject.
# 		flair          : 	No data available for target subject.
# 		flair_blur     : 	No data available for reference subjects.
# 		qT1            : 	No data available for target subject.
# 		qT1_blur       : 	No data available for target subject.
# 		thickness      : 	No data available for target subject.
# 	hippocampus high midthickness
#
# 	Structure: hippocampus [resolution = high	label = midthickness   ]
# 		ADC            : 	No data available for target subject.
# 		FA             : 	No data available for target subject.
# 		flair          : 	No data available for target subject.
# 		flair_blur     : 	No data available for reference subjects.
# 		qT1            : 	No data available for target subject.
# 		qT1_blur       : 	No data available for reference subjects.
# 		thickness      : 	No data available for target subject.
# 	subcortex None None
#
# 	Structure: subcortex
# 		ADC            : 	No data available for target subject.
# 		FA             : 	No data available for target subject.
# 		flair          : 	No data available for target subject.
# 		flair_blur     : 	No data available for reference subjects.
# 		qT1            : 	No data available for target subject.
# 		qT1_blur       : 	No data available for reference subjects.
# 		thickness      : 	No data available for target subject.
# 	Done!
#
#
#
#
# 	Starting report generation
# 	white midthickness
# 	  participant_id session_id SEX     ethn         edu hand        AGE
# 	0     sub-PNE017     ses-a1   M  Mexican  law degree    R  31.208761
# 	multi:  []
# 	multi:  []
# 	multi:  []
# 	feat_report=[]
# 	Clinical report successfully created: /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNE017/ses-a1/sub-PNE017_ses-a1_approach-zscore_summary-report.pdf
# 	 Total elapsed time for sub-PNE017_ses-a1: 0.56 minutes
# 	Cleaning up temp dir /data/mica3/BIDS_PNI/derivatives/DM_zb_37comp/sub-PNE017/ses-a1/z_brains_temp.52kbecu2
