# %% [markdown]
# # Run z-brains analyses for individual cases

# %%
import pandas as pd
import os, sys, subprocess
import importlib

# import utilities
utilities_path = os.path.abspath(os.path.join(os.getcwd(), "/host/verges/tank/data/daniel", "Utils"))
sys.path.append(utilities_path) # path to Utilities
import id, gen, zbUtils

# %%
importlib.reload(id)
# Out:
# <module 'id' from '/host/verges/tank/data/daniel/Utils/id.py'>

# %%
# Input IDs

# IDs: should be in long format (all IDs to be used should be in same column (regardless of if it is 3T or 7T ID))
# model: "/host/verges/tank/data/daniel/3T7T/z/data/models/participants_mics_hc.csv"

# list col names
IDs = {
    "dir": "/host/verges/tank/data/daniel/3T7T/z/data/pt/demo_23May2025_singleID.csv",
    "ID_col": "ID",
    "SES_col": "SES",
    "age_col": "age",
    "sex": "sex"
}

# Dir tmp
dir_tmp = "/host/verges/tank/data/daniel/3T7T/z/outputs/tmp"

# %%
# zBrain parameters

# size of kernels for smoothing (cortex: ctx; hippocampus: hip). 
# NOTE: Both lists must be of same length.
smooth_ctx=[10] # try with 10
smooth_hip=[5] # try with 5

# surface
res="high" # low (cotrex: 5K, hippocampus: 2mm), high (ctx: 32k, hipp: 0.5mm), all (both high and low)

# Output: path and file name
out_name="DM_zb_37comp" # will create folders with this name in BIDs directory

# path to z-brains software
score_type = "z" # z or w, will call appropriate shell script accordingly

# Dictionary item for each study
# Note: zBrains only currently supports one 'ctrl_ptrn', not a list

# directories need to be relative except for root
MICs = {
    "name" : "MICs",
    "ctrl_ptrn" : "HC",
    "pt_ptrn" : "PX",
    "dir_root" : "/data/mica3/BIDS_MICs",
    "dir_raw" : "rawdata",
    "dir_deriv" : "derivatives",
    "dir_mp" : "micapipe_v0.2.0",
    "dir_hu" : "hippunfold_v1.3.0"
}

PNI = {
    "name" : "PNI",
    "ctrl_ptrn" : "PNC",
    "pt_ptrn" : "PNE",
    "dir_root" : "/data/mica3/BIDS_PNI",
    "dir_raw" : "rawdata",
    "dir_deriv" : "derivatives",
    "dir_mp" : "micapipe_v0.2.0",
    "dir_hu" : "hippunfold_v1.3.0"
}

studies = [MICs, PNI]

# %%
# testing values
test = False
if test:
    dir_software = "/host/verges/tank/data/daniel/3T7T/z/code/run/tests/printArgs.sh"
elif score_type == "z":
    dir_software = "/host/verges/tank/data/daniel/3T7T/z/code/run/runZB.sh"
elif score_type == "w":
    dir_software = "/host/verges/tank/data/daniel/3T7T/z/code/run/runZB_w.sh"
else:  
    print("Invalid score type. Must be either 'z', 'w' or 'test'")

# studies = [MICs]
# smooth_ctx=[10]
# smooth_hip=[5]

# %%
# Convert IDs to format accepted by zBrains (add sub-, ses-)

# ensure that ID and ses are properly formatted
#df = gen.fmt(IDs["dir"], [dir_IDs_cols["7T_ID"], dir_IDs_cols["3T_ID"], dir_IDs_cols["7T_SES"], dir_IDs_cols["3T_SES"]])
df = gen.fmt(IDs["dir"], ["ID", "SES"])
# rename df columns
df = df.rename(columns={IDs["ID_col"]:"ID", IDs["SES_col"]:"SES", IDs["age_col"]:"AGE", IDs["sex"]:"SEX"})
#df.head()

# save df to tmp, use path as new IDs["dir"]
dir_IDs = dir_tmp+"/"+os.path.splitext(os.path.basename(IDs["dir"]))[0]+"_fmt.csv"
df.to_csv(dir_IDs, index=False)

print("[INFO] Formatted IDs saved to: ", dir_IDs)

# seperate IDs by study - pass seperate IDs csv to zBrains
# extract ID patterns
ptrns = []
for study in studies:
    ptrns.append([f"sub-{study['ctrl_ptrn']}", f"sub-{study['pt_ptrn']}"])

#print(ptrns)

split_paths = id.split(dir_IDs, col="ID", patterns=ptrns, pth_out=dir_tmp) # split_paths holds paths to split files
# split_paths[0]: MICs, [1]: PNI

# print(split_paths)
# length of split_paths should be equal to the number of studies

if len(split_paths) != len(studies):
    print("[main] Error: Number of split files does not match number of studies.")
    print("\t Check  that the attributes 'ctrl_ptrn' and 'pt_ptrn' are properly defined in all study dictionaries.")
    sys.exit(1)
# Out:
# [INFO] Formatted IDs saved to:  /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_23May2025_singleID_fmt.csv
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/split_ID_1.csv (47 rows)sub-PX: 25, sub-HC: 22
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/split_ID_2.csv (73 rows)sub-PNC: 47, sub-PNE: 26

# %%
# Iterate over studies and run zBrains for each smoothing kernel
#    
for idx, study in enumerate(studies):
    
    df_path = split_paths[idx] # demo file, MICs = [0], PNI = [1]
    ctrl_ptrn = "sub-%s" %study["ctrl_ptrn"]
    pt_ptrn = "sub-%s" %study["pt_ptrn"]
    ptrns = [ctrl_ptrn,pt_ptrn]
    print(ptrns)

    print("\n=====================================")
    print(study["name"])
    demo_pth = id.split(df_path, col="ID", patterns=ptrns, pth_out=dir_tmp, output_prefix="demo") # filter for only control IDs  
    print("Demo path: ", demo_pth)

    #--control_prefix and define according to study
    for row in df.iterrows():
        # run z-brains with each smoothing kernel - can run cortex and hippocampus seperately and in parallel
        for ctx, hip in zip(smooth_ctx, smooth_hip):
            # check if path already exists
            chk_pth()

            print(f"Smoothing: ctx={ctx}, hip={hip}")
            
            # call via bash, pass appropriate arguments
            print("Calling zBrains with:")
            print(study, out_name, ctx, hip, res, demo_pth[0], demo_pth[1], score_type, dir_software)
            continue

            result = zbUtils.runZBrain(
                study, out_name, ctx, hip, res, demo_ref=demo_pth[idx], demo=demo_pth[1], 
                score=score_type, dir_software=dir_software
            )
            # Print zBrains run output
            if result.returncode != 0:
                print(f"Command failed with return code {result.returncode}")

            print("STDOUT:")
            for line in result.stdout.splitlines():
                print(f"\t{line}")

            if result.stderr:
                print("STDERR:")
                for line in result.stderr.splitlines():
                    print(f"\t{line}")
# Out:
# ['sub-HC', 'sub-PX']
#
# =====================================
# MICs
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_1.csv (22 rows)sub-HC: 22
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_2.csv (25 rows)sub-PX: 25
# Demo path:  ['/host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_1.csv', '/host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_2.csv']
#    MICS_ID    PNI_ID         ID study     SES        Date  ethnicity  SEX  \
# 0    HC062    PNC019  sub-HC062    3T  ses-01  25.08.2020    Mexican    M
# 1    HC062    PNC019  sub-HC062    3T  ses-02  08.09.2020    Mexican    M
# 2    HC062    PNC019  sub-HC062    3T  ses-03  16.08.2022    Mexican    M
# 3    HC076    PNC018  sub-HC076    3T  ses-01  08.02.2022   Filipino    F
# 4    HC076    PNC018  sub-HC076    3T  ses-02  27.09.2022   Filipino    F
# 5    HC076    PNC018  sub-HC076    3T  ses-03  06.02.2024   Filipino    F
# 6    HC076    PNC018  sub-HC076    3T  ses-04  17.04.2025   Filipino    F
# 7    HC081    PNC006  sub-HC081    3T  ses-01  26.04.2022   Lebanese    M
# 8    HC081    PNC006  sub-HC081    3T  ses-02  22.11.2022   Lebanese    M
# 9    HC081    PNC006  sub-HC081    3T  ses-03  24.10.2023   Lebanese    M
# 10   HC082    PNC003  sub-HC082    3T  ses-01  26.04.2022  Japanese     F
# 11   HC082    PNC003  sub-HC082    3T  ses-02  25.05.2023  Japanese     F
# 12   HC083    PNC011  sub-HC083    3T  ses-01  12.07.2022     Latino    M
# 13   HC083    PNC011  sub-HC083    3T  ses-02  28.01.2025     Latino    M
# 14   HC088    PNC024  sub-HC088    3T  ses-01  19.07.2022     French    M
# 15   HC088    PNC024  sub-HC088    3T  ses-02  31.10.2023     French    M
# 16   HC116    PNC037  sub-HC116    3T  ses-01  04.07.2023        NaN  NaN
# 17   HC128    PNC025  sub-HC128    3T  ses-01  02.06.2024    Chinese    M
# 18   HC129  Pilot013  sub-HC129    3T  ses-01  09.07.2024        NaN  NaN
# 19   HC130    PNC026  sub-HC130    3T  ses-01  09.07.2024    Chinese    F
# 20   HC130    PNC026  sub-HC130    3T  ses-02  15.01.2025    Chinese    F
# 21   HC140    PNC038  sub-HC140    3T  ses-01  23.10.2024        NaN  NaN
#
#     gender          employment  ...  Duration of admission  \
# 0      NaN            Post Doc  ...                    NaN
# 1      NaN            Post Doc  ...                    NaN
# 2      NaN            Post Doc  ...                    NaN
# 3      NaN  Full time student   ...                    NaN
# 4      NaN  Full time student   ...                    NaN
# 5      NaN  Full time student   ...                    NaN
# 6      NaN  Full time student   ...                    NaN
# 7      NaN   Full time student  ...                    NaN
# 8      NaN   Graduate Studies   ...                    NaN
# 9      NaN   Full time student  ...                    NaN
# 10     NaN   Full time student  ...                    NaN
# 11     NaN   Full time student  ...                    NaN
# 12     NaN             Student  ...                    NaN
# 13     NaN                 NaN  ...                    NaN
# 14     NaN   Full time student  ...                    NaN
# 15     NaN   Full time student  ...                    NaN
# 16     NaN                 NaN  ...                    NaN
# 17     NaN   Full time student  ...                    NaN
# 18     NaN                 NaN  ...                    NaN
# 19     NaN   Full time student  ...                    NaN
# 20     NaN   Full time student  ...                    NaN
# 21     NaN                 NaN  ...                    NaN
#
#                     Education Epilepsy diagnosis based on ILAE  \
# 0                         PhD                              NaN
# 1                         PhD                              NaN
# 2                         PhD                              NaN
# 3                        Grad                              NaN
# 4                        Grad                              NaN
# 5                        Grad                              NaN
# 6                        Grad                              NaN
# 7                   Undergrad                              NaN
# 8                   Undergrad                              NaN
# 9                   Undergrad                              NaN
# 10                       Grad                              NaN
# 11                       Grad                              NaN
# 12                  Undergrad                              NaN
# 13                  Undergrad                              NaN
# 14                   Graduate                              NaN
# 15                   Graduate                              NaN
# 16                        PhD                              NaN
# 17                        MSc                              NaN
# 18                        BSc                              NaN
# 19  BSc (fastracked from MSc)                              NaN
# 20  BSc (fastracked from MSc)                              NaN
# 21                      Cegep                              NaN
#
#    EMU admission date(dd-mm-yy) Language  Dx at EMU discharge   \
# 0                           NaN       en                   NaN
# 1                           NaN       en                   NaN
# 2                           NaN       en                   NaN
# 3                           NaN       en                   NaN
# 4                           NaN       en                   NaN
# 5                           NaN       en                   NaN
# 6                           NaN       en                   NaN
# 7                           NaN       en                   NaN
# 8                           NaN       en                   NaN
# 9                           NaN       en                   NaN
# 10                          NaN       en                   NaN
# 11                          NaN       en                   NaN
# 12                          NaN       en                   NaN
# 13                          NaN       en                   NaN
# 14                          NaN       fr                   NaN
# 15                          NaN       fr                   NaN
# 16                          NaN       en                   NaN
# 17                          NaN       en                   NaN
# 18                          NaN       en                   NaN
# 19                          NaN       en                   NaN
# 20                          NaN       en                   NaN
# 21                          NaN       en                   NaN
#
#     Drug resistant epilepsy at time of EMU admission        AGE   grp  \
# 0                                                NaN  33.106092  CTRL
# 1                                                NaN  33.144422  CTRL
# 2                                                NaN  35.080082  CTRL
# 3                                                NaN  30.349076  CTRL
# 4                                                NaN  30.981520  CTRL
# 5                                                NaN  32.342231  CTRL
# 6                                                NaN  33.535934  CTRL
# 7                                                NaN  24.432580  CTRL
# 8                                                NaN  25.007529  CTRL
# 9                                                NaN  25.927447  CTRL
# 10                                               NaN  24.605065  CTRL
# 11                                               NaN  25.683778  CTRL
# 12                                               NaN  26.165640  CTRL
# 13                                               NaN  28.714579  CTRL
# 14                                               NaN  27.321013  CTRL
# 15                                               NaN  28.605065  CTRL
# 16                                               NaN  40.783025  CTRL
# 17                                               NaN  25.472964  CTRL
# 18                                               NaN  27.953457  CTRL
# 19                                               NaN  28.024641  CTRL
# 20                                               NaN  28.544832  CTRL
# 21                                               NaN   0.555784  CTRL
#
#     grp_detailed
# 0           CTRL
# 1           CTRL
# 2           CTRL
# 3           CTRL
# 4           CTRL
# 5           CTRL
# 6           CTRL
# 7           CTRL
# 8           CTRL
# 9           CTRL
# 10          CTRL
# 11          CTRL
# 12          CTRL
# 13          CTRL
# 14          CTRL
# 15          CTRL
# 16          CTRL
# 17          CTRL
# 18          CTRL
# 19          CTRL
# 20          CTRL
# 21          CTRL
#
# [22 rows x 41 columns]
# ['sub-PNC', 'sub-PNE']
#
# =====================================
# PNI
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_1.csv (47 rows)sub-PNC: 47
# [split] Saved: /host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_2.csv (26 rows)sub-PNE: 26
# Demo path:  ['/host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_1.csv', '/host/verges/tank/data/daniel/3T7T/z/outputs/tmp/demo_2.csv']
#    MICS_ID  PNI_ID          ID study     SES        Date    ethnicity SEX  \
# 0    PX071  PNE001  sub-PNE001    7T  ses-01  26.01.2023     Canadian   M
# 1    PX071  PNE001  sub-PNE001    7T  ses-01  26.01.2023     Canadian   M
# 2    PX071  PNE001  sub-PNE001    7T  ses-01  01.02.2023     Canadian   M
# 3    PX071  PNE001  sub-PNE001    7T  ses-01  01.02.2023     Canadian   M
# 4    PX119  PNE016  sub-PNE016    7T  ses-a1  16.01.2025     Canadian   F
# 5    PX137  PNE003  sub-PNE003    7T  ses-a1  14.11.2024    Caucasian   M
# 6    PX148  PNE013  sub-PNE013    7T  ses-a1  13.01.2025     Canadian   F
# 7    PX152  PNE014  sub-PNE014    7T  ses-a1  13.01.2025     Canadian   M
# 8    PX153  PNE009  sub-PNE009    7T  ses-a1  08.01.2025     Canadian   M
# 9    PX153  PNE009  sub-PNE009    7T  ses-a2  20.03.2025     Canadian   M
# 10   PX158  PNE007  sub-PNE007    7T  ses-a1  11.12.2024     Canadian   M
# 11   PX158  PNE007  sub-PNE007    7T  ses-a2  25.03.2025     Canadian   M
# 12   PX168  PNE010  sub-PNE010    7T  ses-a1  09.01.2025     Canadian   M
# 13   PX173  PNE006  sub-PNE006    7T  ses-a1  04.12.2024     Canadian   F
# 14   PX174  PNE017  sub-PNE017    7T  ses-a1  20.02.2025      Mexican   M
# 15   PX176  PNE004  sub-PNE004    7T  ses-a1  20.11.2024       Indian   M
# 16   PX183  PNE002  sub-PNE002    7T  ses-a1  14.11.2024        Black   M
# 17   PX189  PNE012  sub-PNE012    7T  ses-a1  10.01.2025     Canadian   F
# 18   PX190  PNE011  sub-PNE011    7T  ses-a1  10.01.2025     Canadian   F
# 19   PX194  PNE005  sub-PNE005    7T  ses-a1  29.11.2024    Caucasian   M
# 20   PX198  PNE018  sub-PNE018    7T  ses-a1  12.03.2025     Canadian   M
# 21   PX199  PNE008  sub-PNE008    7T  ses-a1  18.12.2024  Middle East   F
# 22   PX200  PNE015  sub-PNE015    7T  ses-a1  15.01.2025     Canadian   F
# 23   PX204  PNE019  sub-PNE019    7T  ses-a1  18.03.2025     Canadian   F
# 24   PX215  PNE020  sub-PNE020    7T  ses-a1  27.03.2025     Lebanese   F
# 25   PX216  PNE021  sub-PNE021    7T  ses-a1  02.04.2025       French   F
#
#                   gender                                         employment  \
# 0                    NaN                                           Post Doc
# 1                    NaN                                           Post Doc
# 2                    NaN                                           Post Doc
# 3                    NaN                                           Post Doc
# 4                    NaN                                      No employment
# 5                      M                           Musician/Content creator
# 6                    NaN                                      pharmacy tech
# 7   M (Transgender,AFAB)                                         Unemployed
# 8                      M                                         Consultant
# 9                      M                                         Unemployed
# 10                     M                                           Mechanic
# 11                     M                                           Mechanic
# 12                     M                                         Unemployed
# 13                     F                                         Unemployed
# 14                     M                                    quality control
# 15                     M                                      No employment
# 16                     M                                           Musician
# 17                     F  On medical leave (used to work as studio assis...
# 18                     F        Adminstrative worker at a start up company
# 19                     M                                      AI consultant
# 20                   NaN                                                NaN
# 21                     F                                  Call center agent
# 22                   NaN                                 speech pathologist
# 23                   NaN                                 Software Developer
# 24                   NaN                                         Unemployed
# 25                   NaN                                         Unemployed
#
#     ...                              Duration of admission  \
# 0   ...  No EMU admission  , ROUTINE  EEG during wakefu...
# 1   ...  No EMU admission  , ROUTINE  EEG during wakefu...
# 2   ...  No EMU admission  , ROUTINE  EEG during wakefu...
# 3   ...  No EMU admission  , ROUTINE  EEG during wakefu...
# 4   ...                                             7 days
# 5   ...                                  No EMU admission
# 6   ...                                             5 days
# 7   ...                                             6 days
# 8   ...                                             4 days
# 9   ...                                             4 days
# 10  ...                                             4 days
# 11  ...                                             4 days
# 12  ...                                  No EMU admission
# 13  ...                                            10 days
# 14  ...                                             8 days
# 15  ...                                              9days
# 16  ...      No available EMU dicharge summery  in oacis ?
# 17  ...                                   No EMU admission
# 18  ...                                   No EMU admission
# 19  ...                                             6 days
# 20  ...                                            11 days
# 21  ...                                            11 days
# 22  ...                                             7 days
# 23  ...                                             8 days
# 24  ...                                             9 days
# 25  ...                                            15 days
#
#                                             Education  \
# 0                                                 PhD
# 1                                                 PhD
# 2                                                 PhD
# 3                                                 PhD
# 4                             finished primary school
# 5                                   Bachelor's degree
# 6                                                 DEP
# 7                                           DEC cegep
# 8                                       DEC technique
# 9                                       DEC technique
# 10                    High school + mechanical course
# 11                    High school + mechanical course
# 12                 High school + went to trade school
# 13                                        High school
# 14                                                  ?
# 15                                                  ?
# 16                                Bachelor's in Music
# 17  Completed CEGEP (then started but did not fini...
# 18                                         Bachelor's
# 19                                         bachelor's
# 20                                                NaN
# 21                                    Bachelor of art
# 22                                                NaN
# 23                                Bachelor of science
# 24                                        Bachelor's
# 25                          DEP et ASP en secretariat
#
#    Epilepsy diagnosis based on ILAE  \
# 0                         definite
# 1                         definite
# 2                         definite
# 3                         definite
# 4                         definite
# 5                         definite
# 6                         definite
# 7                         definite
# 8                         definite
# 9                         definite
# 10                        definite
# 11                        definite
# 12                        definite
# 13                        definite
# 14                        definite
# 15                        definite
# 16                        definite
# 17                        definite
# 18                        definite
# 19                        definite
# 20                        definite
# 21                        definite
# 22                        definite
# 23                        definite
# 24                        definite
# 25                        definite
#
#                          EMU admission date(dd-mm-yy) Language  \
# 0   No EMU admission  , ROUTINE  EEG during wakefu...       en
# 1   No EMU admission  , ROUTINE  EEG during wakefu...       en
# 2   No EMU admission  , ROUTINE  EEG during wakefu...       en
# 3   No EMU admission  , ROUTINE  EEG during wakefu...       en
# 4                                 2023-08-24 00:00:00       fr
# 5                                    No EMU admission       en
# 6                                 2024-02-27 00:00:00       fr
# 7                                          25.10.2024       en
# 8                                 2024-03-28 00:00:00       fr
# 9                                 2024-03-28 00:00:00       fr
# 10                                         03.05.2024       en
# 11                                         03.05.2024       en
# 12  No EMU admission but there 2 days of EEG recor...       en
# 13                                         12.08.2024       en
# 14                                         21.08.2024       en
# 15                                         26.08.2024       fr
# 16      No available EMU dicharge summery  in oacis ?       en
# 17                                   No EMU admission       en
# 18                                   No EMU admission       en
# 19                                         05.04.2023       fr
# 20                                         01.11.2024       fr
# 21                                         24.01.2021       en
# 22                                         12.11.2024       en
# 23                                         28.11.2024       en
# 24                                         05.02.2025       en
# 25                                         16.01.2025       fr
#
#                                  Dx at EMU discharge   \
# 0             TLE, no lateralization from the history
# 1             TLE, no lateralization from the history
# 2             TLE, no lateralization from the history
# 3             TLE, no lateralization from the history
# 4                      probable frontal lobe epilepsy
# 5               right rolandic seizures, M1 dysplasia
# 6                                               R TLE
# 7        possible  TLE vs posterior quadrant epilepsy
# 8               sleep related temporal epilepsy (R>L)
# 9               sleep related temporal epilepsy (R>L)
# 10  left frontal lobe epilepsy associated with pro...
# 11  left frontal lobe epilepsy associated with pro...
# 12                                           left TLE
# 13                       right temporal lobe epilepsy
# 14              left nocturnal temporal lobe epilepsy
# 15                                        BL (R>L)TLE
# 16  Multifocal epilepsy with possible left basal t...
# 17                   Left post temporal DNET epilepsy
# 18  mesiotemporal lobe epilepsy with family histor...
# 19                    TLE vs fronto-temporal epilepsy
# 20  Left temporal lobe epilepsy possible lesion du...
# 21  insular vs multifocal, lateralization unclear ...
# 22                                             BL TLE
# 23                        left temporal lobe epilepsy
# 24  diffuse epilepsy with suspected left focality ...
# 25                      right temporal lobe epilepsy
#
#    Drug resistant epilepsy at time of EMU admission        AGE   grp  \
# 0                                                 N  30.765229   TLE
# 1                                                 N  30.765229   TLE
# 2                                                 N  30.781656   TLE
# 3                                                 N  30.781656   TLE
# 4                                                 N  42.937714   FLE
# 5                                                 Y  34.212183   FLE
# 6                                                 Y  24.407940   TLE
# 7                                                 Y  29.426420   UKN
# 8                                                 Y  27.340178   TLE
# 9                                                 Y  27.534565   TLE
# 10                                                N  23.441478   FLE
# 11                                                N  23.726215   FLE
# 12                                                Y  30.513347   TLE
# 13                                                Y  30.628337   TLE
# 14                                                Y  31.693361   TLE
# 15                                                Y  36.153320   TLE
# 16    No available EMU dicharge summery  in oacis ?  34.214921  MFCL
# 17                                                N  32.016427   TLE
# 18                                 No EMU admission  31.545517   TLE
# 19                                                Y  34.146475   UKN
# 20                                                Y  35.299110   TLE
# 21                                                Y  29.374401   UKN
# 22                                                Y  46.976044   TLE
# 23                                                Y  29.782341   TLE
# 24                                                Y  58.143737   UKN
# 25                                                Y  49.741273   TLE
#
#    grp_detailed
# 0         TLE_U
# 1         TLE_U
# 2         TLE_U
# 3         TLE_U
# 4         FLE_L
# 5         FLE_R
# 6         TLE_R
# 7         UKN_R
# 8        bTLE_R
# 9        bTLE_R
# 10        FLE_L
# 11        FLE_L
# 12        TLE_L
# 13       mTLE_R
# 14        TLE_L
# 15       bTLE_R
# 16         MFCL
# 17        TLE_L
# 18        TLE_U
# 19        UKN_L
# 20        TLE_L
# 21        UKN_U
# 22         bTLE
# 23        TLE_L
# 24        UKN_U
# 25        TLE_R
#
# [26 rows x 41 columns]
